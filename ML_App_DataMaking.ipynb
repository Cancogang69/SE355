# %% [markdown]
# Call data from open-meteo.com api

# %%
# !pip install openmeteo-requests
# !pip install requests-cache retry-requests numpy pandas
# Out:
# Collecting openmeteo-requests
#   Downloading openmeteo_requests-1.1.0-py3-none-any.whl (5.5 kB)
# Collecting openmeteo-sdk>=1.4.0 (from openmeteo-requests)
#   Downloading openmeteo_sdk-1.7.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openmeteo-requests) (2.31.0)
# Requirement already satisfied: flatbuffers>=23.0.0 in /usr/local/lib/python3.10/dist-packages (from openmeteo-sdk>=1.4.0->openmeteo-requests) (23.5.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->openmeteo-requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openmeteo-requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openmeteo-requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openmeteo-requests) (2023.11.17)
# Installing collected packages: openmeteo-sdk, openmeteo-requests
# Successfully installed openmeteo-requests-1.1.0 openmeteo-sdk-1.7.0
# Collecting requests-cache
#   Downloading requests_cache-1.1.1-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 821.4 kB/s eta 0:00:00
# Collecting retry-requests
#   Downloading retry_requests-2.0.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (23.1.0)
# Collecting cattrs>=22.2 (from requests-cache)
#   Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (4.1.0)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (2.31.0)
# Collecting url-normalize>=1.4 (from requests-cache)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: urllib3>=1.25.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache) (1.2.0)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->requests-cache) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->requests-cache) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->requests-cache) (2023.11.17)
# Installing collected packages: url-normalize, cattrs, retry-requests, requests-cache
# Successfully installed cattrs-23.2.3 requests-cache-1.1.1 retry-requests-2.0.0 url-normalize-1.4.3

# %%
import numpy as np
import openmeteo_requests
import requests_cache
import pandas as pd
from retry_requests import retry
from datetime import date, timedelta, datetime, timedelta
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from sklearn.preprocessing import StandardScaler

# %%
def get_weather_api(lat, long):
	# Setup the Open-Meteo API client with cache and retry on error
	cache_session = requests_cache.CachedSession('.cache', expire_after = -1)
	retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
	openmeteo = openmeteo_requests.Client(session = retry_session)

	# Make sure all required weather variables are listed here
	# The order of variables in hourly or daily is important to assign them correctly below
	url = "https://archive-api.open-meteo.com/v1/archive"
	params = {
		"latitude": lat,
		"longitude": long,
		"start_date": "2015-01-01",
		"end_date": "2023-10-31",
		"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "rain", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "wind_speed_10m", "wind_speed_100m", "wind_direction_10m", "wind_direction_100m", "wind_gusts_10m"]
	}
	responses = openmeteo.weather_api(url, params=params)

	# Process first location. Add a for-loop for multiple locations or weather models
	response = responses[0]
	print(f"Coordinates {response.Latitude()}°E {response.Longitude()}°N")
	print(f"Elevation {response.Elevation()} m asl")
	print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
	print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

	# Process hourly data. The order of variables needs to be the same as requested.
	hourly = response.Hourly()
	hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
	hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
	hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
	hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
	hourly_rain = hourly.Variables(4).ValuesAsNumpy()
	hourly_pressure_msl = hourly.Variables(5).ValuesAsNumpy()
	hourly_surface_pressure = hourly.Variables(6).ValuesAsNumpy()
	hourly_cloud_cover = hourly.Variables(7).ValuesAsNumpy()
	hourly_cloud_cover_low = hourly.Variables(8).ValuesAsNumpy()
	hourly_cloud_cover_mid = hourly.Variables(9).ValuesAsNumpy()
	hourly_cloud_cover_high = hourly.Variables(10).ValuesAsNumpy()
	hourly_wind_speed_10m = hourly.Variables(11).ValuesAsNumpy()
	hourly_wind_speed_100m = hourly.Variables(12).ValuesAsNumpy()
	hourly_wind_direction_10m = hourly.Variables(13).ValuesAsNumpy()
	hourly_wind_direction_100m = hourly.Variables(14).ValuesAsNumpy()
	hourly_wind_gusts_10m = hourly.Variables(15).ValuesAsNumpy()

	hourly_data = {"date": pd.date_range(
		start = pd.to_datetime(hourly.Time(), unit = "s"),
		end = pd.to_datetime(hourly.TimeEnd(), unit = "s"),
		freq = pd.Timedelta(seconds = hourly.Interval()),
		inclusive = "left"
	)}
	hourly_data["temperature_2m"] = hourly_temperature_2m
	hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
	hourly_data["dew_point_2m"] = hourly_dew_point_2m
	hourly_data["apparent_temperature"] = hourly_apparent_temperature
	hourly_data["rain"] = hourly_rain
	hourly_data["pressure_msl"] = hourly_pressure_msl
	hourly_data["surface_pressure"] = hourly_surface_pressure
	hourly_data["cloud_cover"] = hourly_cloud_cover
	hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
	hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
	hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
	hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
	hourly_data["wind_speed_100m"] = hourly_wind_speed_100m
	hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
	hourly_data["wind_direction_100m"] = hourly_wind_direction_100m
	hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m

	hourly_dataframe = pd.DataFrame(data = hourly_data)
	return hourly_dataframe

# %%
# get dataframe of district 1 with latitude = 10.7807 and longtitude = 106.6994
data_quan_1 = get_weather_api(10.7807, 106.6994)
# Out:
# Coordinates 10.790861129760742°E 106.71087646484375°N
# Elevation 18.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s

# %%
hourly_dataframe = pd.DataFrame(data_quan_1)

# %%
hourly_dataframe
# Out:
#                       date  temperature_2m  relative_humidity_2m  \
# 0      2015-01-01 00:00:00       21.489500             85.151405
# 1      2015-01-01 01:00:00       23.489500             69.282570
# 2      2015-01-01 02:00:00       24.889500             62.902657
# 3      2015-01-01 03:00:00       26.139500             59.517963
# 4      2015-01-01 04:00:00       27.339500             56.162460
# ...                    ...             ...                   ...
# 77419  2023-10-31 19:00:00       24.789499             98.516823
# 77420  2023-10-31 20:00:00       24.639500             97.926659
# 77421  2023-10-31 21:00:00       24.539499             97.339287
# 77422  2023-10-31 22:00:00       24.539499             96.176743
# 77423  2023-10-31 23:00:00       24.489500             95.024567
#
#        dew_point_2m  apparent_temperature  rain  pressure_msl  \
# 0         18.889500             23.705687   0.0   1013.700012
# 1         17.539499             24.984230   0.0   1014.200012
# 2         17.339500             26.351543   0.0   1014.500000
# 3         17.639500             28.154537   0.0   1014.599976
# 4         17.839500             30.580215   0.0   1014.000000
# ...             ...                   ...   ...           ...
# 77419     24.539499             30.363483   0.0   1009.799988
# 77420     24.289499             30.209759   0.0   1009.400024
# 77421     24.089500             30.015854   0.0   1009.500000
# 77422     23.889500             29.657166   0.0   1009.900024
# 77423     23.639500             29.548794   0.0   1010.500000
#
#        surface_pressure  cloud_cover  cloud_cover_low  cloud_cover_mid  \
# 0           1011.586792    28.799999             11.0              8.0
# 1           1012.100098    24.299999             12.0              3.0
# 2           1012.409302    27.000000              7.0              1.0
# 3           1012.517883    27.000000              1.0              0.0
# 4           1011.927429    27.900002              2.0              1.0
# ...                 ...          ...              ...              ...
# 77419       1007.718262    24.900000             23.0              1.0
# 77420       1007.318298     1.500000              1.0              1.0
# 77421       1007.417358    18.900000              2.0              0.0
# 77422       1007.816528    30.300001              1.0              1.0
# 77423       1008.415039    17.700001              3.0              0.0
#
#        cloud_cover_high  wind_speed_10m  wind_speed_100m  wind_direction_10m  \
# 0                  47.0        7.594207        13.679999          354.559753
# 1                  39.0        8.311245        11.183201          355.030334
# 2                  67.0        7.928178        10.464798            2.602512
# 3                  87.0        7.636753         9.826088            8.130019
# 4                  85.0        6.519877         8.311245            6.340100
# ...                 ...             ...              ...                 ...
# 77419              12.0        5.959060        12.758432          334.983124
# 77420               0.0        4.896529        10.853866          342.897186
# 77421              57.0        4.680000         9.255571          360.000000
# 77422              96.0        6.287130         9.504272           23.629398
# 77423              50.0        5.634891         9.449572           26.564985
#
#        wind_direction_100m  wind_gusts_10m  predict_rain  predict_heat  \
# 0               360.000000       13.679999             0             0
# 1               356.308685       19.080000             0             0
# 2                 3.945108       20.160000             0             0
# 3                 8.426887       19.799999             0             0
# 4                 4.969664       20.160000             0             0
# ...                    ...             ...           ...           ...
# 77419           343.610382       10.080000             0             0
# 77420           354.289490        8.280000             0             0
# 77421            13.495748        6.840000             0             0
# 77422            37.304039        7.559999             0             0
# 77423            40.364468        9.720000             0             0
#
#        predict_cloud
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 77419              0
# 77420              0
# 77421              0
# 77422              0
# 77423              0
#
# [77424 rows x 20 columns]

# %%
weather_data = hourly_dataframe.iloc[:,:].values

# %%
# labeling rain data
# no rain => 0 || rainy => 1 || heavy rain => 2
predict_rain = []

for element in weather_data:
  rain = element[5]
  rain_label = -1
  if rain < 0.3:
    rain_label = 0
  else: rain_label = 1
  predict_rain.append(rain_label)

# %%
# check if exist any element mislabeled in rain data
nprain = np.array(predict_rain)
print('Rain label:', np.unique(nprain))
unique, counts = np.unique(nprain, return_counts=True)

infor_rain = dict(zip(unique, counts))
data_len = len(weather_data)
for i in range(2):
  print(f'Number of sample in label {i}:', infor_rain[i], '||\t||', ' Account', counts[i]/data_len*100, '% of total data.')
# Out:
# Rain label: [0 1]
# Number of sample in label 0: 66155 ||	||  Account 85.44508162843563 % of total data.
# Number of sample in label 1: 11269 ||	||  Account 14.554918371564373 % of total data.

# %%
# labeling heat data
# cool => 0 || hot => 1 || scorching => 2
predict_heat = []

for element in weather_data:
  heat = element[4]
  heat_label = -1
  if heat < 35:
    heat_label = 0
  elif heat < 37:
    heat_label = 1
  else: heat_label = 2
  predict_heat.append(heat_label)

# %%
# check if exist any element mislabeled in heat data
npheat = np.array(predict_heat)
print('Heat label:', np.unique(npheat))
unique, counts = np.unique(npheat, return_counts=True)

infor_heat = dict(zip(unique, counts))
for i in range(3):
  print(f'Number of sample in label {i}:', infor_heat[i], '||\t||', ' Account', counts[i]/data_len*100, '% of total data.')
# Out:
# Heat label: [0 1 2]
# Number of sample in label 0: 65639 ||	||  Account 84.77862161603638 % of total data.
# Number of sample in label 1: 7094 ||	||  Account 9.162533581318453 % of total data.
# Number of sample in label 2: 4691 ||	||  Account 6.058844802645175 % of total data.

# %%
# labeling cloud data
# less cloud => 0 || much cloud => 1
predict_cloud = []

for element in weather_data:
  cloud = element[8]
  cloud_label = -1
  if cloud < 50:
    cloud_label = 0
  else: cloud_label = 1
  predict_cloud.append(cloud_label)

# %%
# check if exist any element mislabeled in cloud data
npcloud = np.array(predict_cloud)
print('cloud label:', np.unique(npcloud))
unique, counts = np.unique(npcloud, return_counts=True)

infor_cloud = dict(zip(unique, counts))
for i in range(2):
  print(f'Number of sample in label {i}:', infor_cloud[i], '||\t||', ' Account', counts[i]/data_len*100, '% of total data.')
# Out:
# cloud label: [0 1]
# Number of sample in label 0: 50865 ||	||  Account 65.69668319900805 % of total data.
# Number of sample in label 1: 26559 ||	||  Account 34.30331680099194 % of total data.

# %%
hourly_dataframe['predict_rain'] = nprain
hourly_dataframe['predict_heat'] = npheat
hourly_dataframe['predict_cloud'] = npcloud

# %%
hourly_dataframe['date'] = hourly_dataframe['date'].astype('string')

# %%
datetime = datetime.fromisoformat(hourly_dataframe.iloc[15000, 0])

# %%
# define a function to get feature date and target date
def get_date(datetime):
  feature_date = []
  target_date = []
  date = str(datetime)
  for i in range(1, 169):
    # calculate time and add it to list
    last_year_before = datetime.fromisoformat(date) - timedelta(days=365, hours=i)
    last_year_after = datetime.fromisoformat(date) + timedelta(hours=i) - timedelta(days=365)
    last_week_time = datetime.fromisoformat(date) - timedelta(hours=i)
    next_week_time = datetime.fromisoformat(date) + timedelta(hours=i)
    feature_date.append(str(last_year_before))
    feature_date.append(str(last_year_after))
    feature_date.append(str(last_week_time))
    target_date.append(str(next_week_time))
  return feature_date, target_date

# %%
feature_date, target_date = get_date(datetime)

# %%
print(len(feature_date), len(target_date))
# Out:
# 504 168

# %%
datetime
# Out:
# datetime.datetime(2016, 9, 17, 0, 0)

# %%
print(feature_date[0],feature_date[1],feature_date[2])
# Out:
# 2015-09-17 23:00:00 2015-09-18 01:00:00 2016-09-16 23:00:00

# %%
columns_rain=['relative_humidity_2m', 'apparent_temperature', 'surface_pressure', 'rain', 'cloud_cover']
columns_heat=['relative_humidity_2m', 'wind_gusts_10m', 'apparent_temperature', 'temperature_2m']
columns_cloud=['rain', 'cloud_cover', 'cloud_cover_low', 'cloud_cover_mid', 'cloud_cover_high']
target_rain=['predict_rain']
target_heat=['predict_heat']
target_cloud=['predict_cloud']

# %% [markdown]
# tuần trước năm trước (168h) + tuần sau năm trước (168h) + tuần sau năm này (168h)</br>
# => 1 tuần sau năm này (168h)

# %%
def get_data(feature_time, target_time, feature, target):
  data_feat = []
  target_feat = []

  # iterate through feature_time
  for time in feature_time:
    # append found data in list (feature got include week before-later of last year, one week before of this year)
    data = hourly_dataframe[feature].to_numpy()[hourly_dataframe['date'].to_numpy() == time]
    data_feat.append(data)

  # iterate through target_time
  for time in target_time:
    # append found data in list (feature got include one week after of this year)
    data = hourly_dataframe[target].to_numpy()[hourly_dataframe['date'].to_numpy() == time]
    target_feat.append(data)

  # convert the two list to numpy array and flatten them
  data_feat = np.array(data_feat).flatten()
  target_feat = np.array(target_feat).flatten()

  return data_feat, target_feat

# %%
feature_data, target_data = get_data(feature_date, target_date, columns_heat, target_heat)

# %%
print(feature_data.shape) # 2016 mean 504*4 -> 504 hours total * 4 feature (because i flatten it)
print(target_data.shape)
# Out:
# (2016,)
# (168,)

# %%
def get_all_of_type(feature_type, target_type):
  feature = []
  target = []
  for i in range(len(hourly_dataframe)):
    date = datetime.fromisoformat(hourly_dataframe.iloc[i, 0])
    feature_date, target_date = get_date(date)
    feature_data, target_data = get_data(feature_date, target_date, feature_type, target_type)
    feature.append(feature_data)
    target.append(target_data)
  feature = np.array(feature)
  target = np.array(target)
  return feature, target

# %%
#heat_feature, heat_target = get_all_of_type(columns_heat, target_heat)

# %%
print(datetime.fromisoformat(hourly_dataframe.iloc[8783, 0]))
# Out:
# 2016-01-01 23:00:00

# %%
print(hourly_dataframe[columns_heat].iloc[8784-365*24-1:8784-365*24-169])
# Out:
#        relative_humidity_2m  wind_gusts_10m  apparent_temperature  \
# 23                74.365158        9.360000             21.157446
# 24                73.224449       12.959999             21.143343
# 25                61.944687       18.359999             22.991415
# 26                59.036236       20.160000             24.965498
# 27                57.523548       20.519999             27.074623
# ...                     ...             ...                   ...
# 77274             94.477852       10.799999             30.268993
# 77275             95.326515        9.360000             30.236565
# 77276             96.470146        8.640000             30.163628
# 77277             95.604889        6.120000             30.331520
# 77278             96.175339        5.400000             29.808720
#
#        temperature_2m
# 23          20.039499
# 24          20.289499
# 25          22.389500
# 26          24.089500
# 27          25.539499
# ...               ...
# 77274       25.089500
# 77275       24.939499
# 77276       24.689499
# 77277       24.689499
# 77278       24.489500
#
# [77256 rows x 4 columns]

# %%
hourly_dataframe.index[hourly_dataframe['date'].values == str(datetime.fromisoformat('2023-10-01 23:00:00') + timedelta(days=i))]
# Out:
# Int64Index([76727], dtype='int64')

# %%
def get_train_test_data(start, end, feature_type, target_type):
  feature = []
  target = []
  start = datetime.fromisoformat(start)
  end = datetime.fromisoformat(end)
  for i in range((end-start).days+1):
    print('----------------------------------')
    print(f'Get {i}...')
    date = start + timedelta(days=i)
    print(f'Checking date:', date)

    # get prev week
    last_week_end = date - timedelta(hours=1)
    last_week_start = date - timedelta(hours=24*7)

    # get prev year
    last_year_start = date - timedelta(days=365, hours=24*7)
    last_year_end = date - timedelta(days=365) + timedelta(hours=24*7)

    # get index of those feature
    last_week_start_index = np.where(hourly_dataframe['date'].values == str(last_week_start))
    last_week_end_index = np.where(hourly_dataframe['date'].values == str(last_week_end))
    last_year_start_index = np.where(hourly_dataframe['date'].values == str(last_year_start))
    last_year_end_index = np.where(hourly_dataframe['date'].values == str(last_year_end))

    # get index of those target
    next_week_index = np.where(hourly_dataframe['date'].values == str(date))

    # error checking
    print('Check indexing:', last_year_start_index[0],last_year_end_index[0],last_week_start_index[0],last_week_end_index[0],next_week_index[0])

    # get data of those feature
    feature_year = hourly_dataframe.loc[int(last_year_start_index[0]):int(last_year_end_index[0]), feature_type].to_numpy(copy=True).flatten()
    feature_week = hourly_dataframe.loc[int(last_week_start_index[0]):int(last_week_end_index[0]), feature_type].to_numpy(copy=True).flatten()

    # target
    target_week = hourly_dataframe.loc[int(next_week_index[0]), target_type].to_numpy(copy=True).flatten()

    feature_np = np.concatenate((feature_year, feature_week), axis=None)
    print('Feature shape:', feature_np.shape)
    print('Target shape:', target_week.shape)
    #target_temp.clear()
    feature.append(feature_np)
    target.append(target_week)
    print('Done!')

  return feature, target

# %%
x_heat, y_heat = get_train_test_data('2016-05-01 00:00:00', '2023-10-01 23:00:00', columns_heat, target_heat)
x_heat = np.array(x_heat)
y_heat = np.array(y_heat).astype('int').reshape(-1,)
# Out:
# Streaming output truncated to the last 5000 lines.
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1996...
# Checking date: 2021-10-18 00:00:00
# Check indexing: [50640] [50976] [59400] [59567] [59568]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1997...
# Checking date: 2021-10-19 00:00:00
# Check indexing: [50664] [51000] [59424] [59591] [59592]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1998...
# Checking date: 2021-10-20 00:00:00
# Check indexing: [50688] [51024] [59448] [59615] [59616]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1999...
# Checking date: 2021-10-21 00:00:00
# Check indexing: [50712] [51048] [59472] [59639] [59640]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2000...
# Checking date: 2021-10-22 00:00:00
# Check indexing: [50736] [51072] [59496] [59663] [59664]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2001...
# Checking date: 2021-10-23 00:00:00
# Check indexing: [50760] [51096] [59520] [59687] [59688]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2002...
# Checking date: 2021-10-24 00:00:00
# Check indexing: [50784] [51120] [59544] [59711] [59712]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2003...
# Checking date: 2021-10-25 00:00:00
# Check indexing: [50808] [51144] [59568] [59735] [59736]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2004...
# Checking date: 2021-10-26 00:00:00
# Check indexing: [50832] [51168] [59592] [59759] [59760]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2005...
# Checking date: 2021-10-27 00:00:00
# Check indexing: [50856] [51192] [59616] [59783] [59784]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2006...
# Checking date: 2021-10-28 00:00:00
# Check indexing: [50880] [51216] [59640] [59807] [59808]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2007...
# Checking date: 2021-10-29 00:00:00
# Check indexing: [50904] [51240] [59664] [59831] [59832]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2008...
# Checking date: 2021-10-30 00:00:00
# Check indexing: [50928] [51264] [59688] [59855] [59856]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2009...
# Checking date: 2021-10-31 00:00:00
# Check indexing: [50952] [51288] [59712] [59879] [59880]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2010...
# Checking date: 2021-11-01 00:00:00
# Check indexing: [50976] [51312] [59736] [59903] [59904]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2011...
# Checking date: 2021-11-02 00:00:00
# Check indexing: [51000] [51336] [59760] [59927] [59928]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2012...
# Checking date: 2021-11-03 00:00:00
# Check indexing: [51024] [51360] [59784] [59951] [59952]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2013...
# Checking date: 2021-11-04 00:00:00
# Check indexing: [51048] [51384] [59808] [59975] [59976]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2014...
# Checking date: 2021-11-05 00:00:00
# Check indexing: [51072] [51408] [59832] [59999] [60000]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2015...
# Checking date: 2021-11-06 00:00:00
# Check indexing: [51096] [51432] [59856] [60023] [60024]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2016...
# Checking date: 2021-11-07 00:00:00
# Check indexing: [51120] [51456] [59880] [60047] [60048]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2017...
# Checking date: 2021-11-08 00:00:00
# Check indexing: [51144] [51480] [59904] [60071] [60072]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2018...
# Checking date: 2021-11-09 00:00:00
# Check indexing: [51168] [51504] [59928] [60095] [60096]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2019...
# Checking date: 2021-11-10 00:00:00
# Check indexing: [51192] [51528] [59952] [60119] [60120]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2020...
# Checking date: 2021-11-11 00:00:00
# Check indexing: [51216] [51552] [59976] [60143] [60144]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2021...
# Checking date: 2021-11-12 00:00:00
# Check indexing: [51240] [51576] [60000] [60167] [60168]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2022...
# Checking date: 2021-11-13 00:00:00
# Check indexing: [51264] [51600] [60024] [60191] [60192]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2023...
# Checking date: 2021-11-14 00:00:00
# Check indexing: [51288] [51624] [60048] [60215] [60216]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2024...
# Checking date: 2021-11-15 00:00:00
# Check indexing: [51312] [51648] [60072] [60239] [60240]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2025...
# Checking date: 2021-11-16 00:00:00
# Check indexing: [51336] [51672] [60096] [60263] [60264]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2026...
# Checking date: 2021-11-17 00:00:00
# Check indexing: [51360] [51696] [60120] [60287] [60288]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2027...
# Checking date: 2021-11-18 00:00:00
# Check indexing: [51384] [51720] [60144] [60311] [60312]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2028...
# Checking date: 2021-11-19 00:00:00
# Check indexing: [51408] [51744] [60168] [60335] [60336]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2029...
# Checking date: 2021-11-20 00:00:00
# Check indexing: [51432] [51768] [60192] [60359] [60360]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2030...
# Checking date: 2021-11-21 00:00:00
# Check indexing: [51456] [51792] [60216] [60383] [60384]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2031...
# Checking date: 2021-11-22 00:00:00
# Check indexing: [51480] [51816] [60240] [60407] [60408]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2032...
# Checking date: 2021-11-23 00:00:00
# Check indexing: [51504] [51840] [60264] [60431] [60432]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2033...
# Checking date: 2021-11-24 00:00:00
# Check indexing: [51528] [51864] [60288] [60455] [60456]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2034...
# Checking date: 2021-11-25 00:00:00
# Check indexing: [51552] [51888] [60312] [60479] [60480]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2035...
# Checking date: 2021-11-26 00:00:00
# Check indexing: [51576] [51912] [60336] [60503] [60504]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2036...
# Checking date: 2021-11-27 00:00:00
# Check indexing: [51600] [51936] [60360] [60527] [60528]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2037...
# Checking date: 2021-11-28 00:00:00
# Check indexing: [51624] [51960] [60384] [60551] [60552]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2038...
# Checking date: 2021-11-29 00:00:00
# Check indexing: [51648] [51984] [60408] [60575] [60576]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2039...
# Checking date: 2021-11-30 00:00:00
# Check indexing: [51672] [52008] [60432] [60599] [60600]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2040...
# Checking date: 2021-12-01 00:00:00
# Check indexing: [51696] [52032] [60456] [60623] [60624]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2041...
# Checking date: 2021-12-02 00:00:00
# Check indexing: [51720] [52056] [60480] [60647] [60648]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2042...
# Checking date: 2021-12-03 00:00:00
# Check indexing: [51744] [52080] [60504] [60671] [60672]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2043...
# Checking date: 2021-12-04 00:00:00
# Check indexing: [51768] [52104] [60528] [60695] [60696]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2044...
# Checking date: 2021-12-05 00:00:00
# Check indexing: [51792] [52128] [60552] [60719] [60720]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2045...
# Checking date: 2021-12-06 00:00:00
# Check indexing: [51816] [52152] [60576] [60743] [60744]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2046...
# Checking date: 2021-12-07 00:00:00
# Check indexing: [51840] [52176] [60600] [60767] [60768]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2047...
# Checking date: 2021-12-08 00:00:00
# Check indexing: [51864] [52200] [60624] [60791] [60792]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2048...
# Checking date: 2021-12-09 00:00:00
# Check indexing: [51888] [52224] [60648] [60815] [60816]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2049...
# Checking date: 2021-12-10 00:00:00
# Check indexing: [51912] [52248] [60672] [60839] [60840]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2050...
# Checking date: 2021-12-11 00:00:00
# Check indexing: [51936] [52272] [60696] [60863] [60864]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2051...
# Checking date: 2021-12-12 00:00:00
# Check indexing: [51960] [52296] [60720] [60887] [60888]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2052...
# Checking date: 2021-12-13 00:00:00
# Check indexing: [51984] [52320] [60744] [60911] [60912]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2053...
# Checking date: 2021-12-14 00:00:00
# Check indexing: [52008] [52344] [60768] [60935] [60936]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2054...
# Checking date: 2021-12-15 00:00:00
# Check indexing: [52032] [52368] [60792] [60959] [60960]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2055...
# Checking date: 2021-12-16 00:00:00
# Check indexing: [52056] [52392] [60816] [60983] [60984]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2056...
# Checking date: 2021-12-17 00:00:00
# Check indexing: [52080] [52416] [60840] [61007] [61008]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2057...
# Checking date: 2021-12-18 00:00:00
# Check indexing: [52104] [52440] [60864] [61031] [61032]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2058...
# Checking date: 2021-12-19 00:00:00
# Check indexing: [52128] [52464] [60888] [61055] [61056]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2059...
# Checking date: 2021-12-20 00:00:00
# Check indexing: [52152] [52488] [60912] [61079] [61080]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2060...
# Checking date: 2021-12-21 00:00:00
# Check indexing: [52176] [52512] [60936] [61103] [61104]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2061...
# Checking date: 2021-12-22 00:00:00
# Check indexing: [52200] [52536] [60960] [61127] [61128]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2062...
# Checking date: 2021-12-23 00:00:00
# Check indexing: [52224] [52560] [60984] [61151] [61152]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2063...
# Checking date: 2021-12-24 00:00:00
# Check indexing: [52248] [52584] [61008] [61175] [61176]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2064...
# Checking date: 2021-12-25 00:00:00
# Check indexing: [52272] [52608] [61032] [61199] [61200]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2065...
# Checking date: 2021-12-26 00:00:00
# Check indexing: [52296] [52632] [61056] [61223] [61224]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2066...
# Checking date: 2021-12-27 00:00:00
# Check indexing: [52320] [52656] [61080] [61247] [61248]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2067...
# Checking date: 2021-12-28 00:00:00
# Check indexing: [52344] [52680] [61104] [61271] [61272]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2068...
# Checking date: 2021-12-29 00:00:00
# Check indexing: [52368] [52704] [61128] [61295] [61296]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2069...
# Checking date: 2021-12-30 00:00:00
# Check indexing: [52392] [52728] [61152] [61319] [61320]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2070...
# Checking date: 2021-12-31 00:00:00
# Check indexing: [52416] [52752] [61176] [61343] [61344]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2071...
# Checking date: 2022-01-01 00:00:00
# Check indexing: [52440] [52776] [61200] [61367] [61368]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2072...
# Checking date: 2022-01-02 00:00:00
# Check indexing: [52464] [52800] [61224] [61391] [61392]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2073...
# Checking date: 2022-01-03 00:00:00
# Check indexing: [52488] [52824] [61248] [61415] [61416]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2074...
# Checking date: 2022-01-04 00:00:00
# Check indexing: [52512] [52848] [61272] [61439] [61440]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2075...
# Checking date: 2022-01-05 00:00:00
# Check indexing: [52536] [52872] [61296] [61463] [61464]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2076...
# Checking date: 2022-01-06 00:00:00
# Check indexing: [52560] [52896] [61320] [61487] [61488]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2077...
# Checking date: 2022-01-07 00:00:00
# Check indexing: [52584] [52920] [61344] [61511] [61512]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2078...
# Checking date: 2022-01-08 00:00:00
# Check indexing: [52608] [52944] [61368] [61535] [61536]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2079...
# Checking date: 2022-01-09 00:00:00
# Check indexing: [52632] [52968] [61392] [61559] [61560]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2080...
# Checking date: 2022-01-10 00:00:00
# Check indexing: [52656] [52992] [61416] [61583] [61584]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2081...
# Checking date: 2022-01-11 00:00:00
# Check indexing: [52680] [53016] [61440] [61607] [61608]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2082...
# Checking date: 2022-01-12 00:00:00
# Check indexing: [52704] [53040] [61464] [61631] [61632]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2083...
# Checking date: 2022-01-13 00:00:00
# Check indexing: [52728] [53064] [61488] [61655] [61656]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2084...
# Checking date: 2022-01-14 00:00:00
# Check indexing: [52752] [53088] [61512] [61679] [61680]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2085...
# Checking date: 2022-01-15 00:00:00
# Check indexing: [52776] [53112] [61536] [61703] [61704]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2086...
# Checking date: 2022-01-16 00:00:00
# Check indexing: [52800] [53136] [61560] [61727] [61728]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2087...
# Checking date: 2022-01-17 00:00:00
# Check indexing: [52824] [53160] [61584] [61751] [61752]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2088...
# Checking date: 2022-01-18 00:00:00
# Check indexing: [52848] [53184] [61608] [61775] [61776]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2089...
# Checking date: 2022-01-19 00:00:00
# Check indexing: [52872] [53208] [61632] [61799] [61800]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2090...
# Checking date: 2022-01-20 00:00:00
# Check indexing: [52896] [53232] [61656] [61823] [61824]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2091...
# Checking date: 2022-01-21 00:00:00
# Check indexing: [52920] [53256] [61680] [61847] [61848]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2092...
# Checking date: 2022-01-22 00:00:00
# Check indexing: [52944] [53280] [61704] [61871] [61872]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2093...
# Checking date: 2022-01-23 00:00:00
# Check indexing: [52968] [53304] [61728] [61895] [61896]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2094...
# Checking date: 2022-01-24 00:00:00
# Check indexing: [52992] [53328] [61752] [61919] [61920]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2095...
# Checking date: 2022-01-25 00:00:00
# Check indexing: [53016] [53352] [61776] [61943] [61944]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2096...
# Checking date: 2022-01-26 00:00:00
# Check indexing: [53040] [53376] [61800] [61967] [61968]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2097...
# Checking date: 2022-01-27 00:00:00
# Check indexing: [53064] [53400] [61824] [61991] [61992]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2098...
# Checking date: 2022-01-28 00:00:00
# Check indexing: [53088] [53424] [61848] [62015] [62016]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2099...
# Checking date: 2022-01-29 00:00:00
# Check indexing: [53112] [53448] [61872] [62039] [62040]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2100...
# Checking date: 2022-01-30 00:00:00
# Check indexing: [53136] [53472] [61896] [62063] [62064]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2101...
# Checking date: 2022-01-31 00:00:00
# Check indexing: [53160] [53496] [61920] [62087] [62088]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2102...
# Checking date: 2022-02-01 00:00:00
# Check indexing: [53184] [53520] [61944] [62111] [62112]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2103...
# Checking date: 2022-02-02 00:00:00
# Check indexing: [53208] [53544] [61968] [62135] [62136]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2104...
# Checking date: 2022-02-03 00:00:00
# Check indexing: [53232] [53568] [61992] [62159] [62160]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2105...
# Checking date: 2022-02-04 00:00:00
# Check indexing: [53256] [53592] [62016] [62183] [62184]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2106...
# Checking date: 2022-02-05 00:00:00
# Check indexing: [53280] [53616] [62040] [62207] [62208]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2107...
# Checking date: 2022-02-06 00:00:00
# Check indexing: [53304] [53640] [62064] [62231] [62232]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2108...
# Checking date: 2022-02-07 00:00:00
# Check indexing: [53328] [53664] [62088] [62255] [62256]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2109...
# Checking date: 2022-02-08 00:00:00
# Check indexing: [53352] [53688] [62112] [62279] [62280]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2110...
# Checking date: 2022-02-09 00:00:00
# Check indexing: [53376] [53712] [62136] [62303] [62304]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2111...
# Checking date: 2022-02-10 00:00:00
# Check indexing: [53400] [53736] [62160] [62327] [62328]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2112...
# Checking date: 2022-02-11 00:00:00
# Check indexing: [53424] [53760] [62184] [62351] [62352]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2113...
# Checking date: 2022-02-12 00:00:00
# Check indexing: [53448] [53784] [62208] [62375] [62376]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2114...
# Checking date: 2022-02-13 00:00:00
# Check indexing: [53472] [53808] [62232] [62399] [62400]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2115...
# Checking date: 2022-02-14 00:00:00
# Check indexing: [53496] [53832] [62256] [62423] [62424]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2116...
# Checking date: 2022-02-15 00:00:00
# Check indexing: [53520] [53856] [62280] [62447] [62448]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2117...
# Checking date: 2022-02-16 00:00:00
# Check indexing: [53544] [53880] [62304] [62471] [62472]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2118...
# Checking date: 2022-02-17 00:00:00
# Check indexing: [53568] [53904] [62328] [62495] [62496]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2119...
# Checking date: 2022-02-18 00:00:00
# Check indexing: [53592] [53928] [62352] [62519] [62520]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2120...
# Checking date: 2022-02-19 00:00:00
# Check indexing: [53616] [53952] [62376] [62543] [62544]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2121...
# Checking date: 2022-02-20 00:00:00
# Check indexing: [53640] [53976] [62400] [62567] [62568]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2122...
# Checking date: 2022-02-21 00:00:00
# Check indexing: [53664] [54000] [62424] [62591] [62592]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2123...
# Checking date: 2022-02-22 00:00:00
# Check indexing: [53688] [54024] [62448] [62615] [62616]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2124...
# Checking date: 2022-02-23 00:00:00
# Check indexing: [53712] [54048] [62472] [62639] [62640]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2125...
# Checking date: 2022-02-24 00:00:00
# Check indexing: [53736] [54072] [62496] [62663] [62664]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2126...
# Checking date: 2022-02-25 00:00:00
# Check indexing: [53760] [54096] [62520] [62687] [62688]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2127...
# Checking date: 2022-02-26 00:00:00
# Check indexing: [53784] [54120] [62544] [62711] [62712]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2128...
# Checking date: 2022-02-27 00:00:00
# Check indexing: [53808] [54144] [62568] [62735] [62736]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2129...
# Checking date: 2022-02-28 00:00:00
# Check indexing: [53832] [54168] [62592] [62759] [62760]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2130...
# Checking date: 2022-03-01 00:00:00
# Check indexing: [53856] [54192] [62616] [62783] [62784]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2131...
# Checking date: 2022-03-02 00:00:00
# Check indexing: [53880] [54216] [62640] [62807] [62808]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2132...
# Checking date: 2022-03-03 00:00:00
# Check indexing: [53904] [54240] [62664] [62831] [62832]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2133...
# Checking date: 2022-03-04 00:00:00
# Check indexing: [53928] [54264] [62688] [62855] [62856]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2134...
# Checking date: 2022-03-05 00:00:00
# Check indexing: [53952] [54288] [62712] [62879] [62880]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2135...
# Checking date: 2022-03-06 00:00:00
# Check indexing: [53976] [54312] [62736] [62903] [62904]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2136...
# Checking date: 2022-03-07 00:00:00
# Check indexing: [54000] [54336] [62760] [62927] [62928]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2137...
# Checking date: 2022-03-08 00:00:00
# Check indexing: [54024] [54360] [62784] [62951] [62952]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2138...
# Checking date: 2022-03-09 00:00:00
# Check indexing: [54048] [54384] [62808] [62975] [62976]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2139...
# Checking date: 2022-03-10 00:00:00
# Check indexing: [54072] [54408] [62832] [62999] [63000]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2140...
# Checking date: 2022-03-11 00:00:00
# Check indexing: [54096] [54432] [62856] [63023] [63024]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2141...
# Checking date: 2022-03-12 00:00:00
# Check indexing: [54120] [54456] [62880] [63047] [63048]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2142...
# Checking date: 2022-03-13 00:00:00
# Check indexing: [54144] [54480] [62904] [63071] [63072]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2143...
# Checking date: 2022-03-14 00:00:00
# Check indexing: [54168] [54504] [62928] [63095] [63096]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2144...
# Checking date: 2022-03-15 00:00:00
# Check indexing: [54192] [54528] [62952] [63119] [63120]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2145...
# Checking date: 2022-03-16 00:00:00
# Check indexing: [54216] [54552] [62976] [63143] [63144]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2146...
# Checking date: 2022-03-17 00:00:00
# Check indexing: [54240] [54576] [63000] [63167] [63168]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2147...
# Checking date: 2022-03-18 00:00:00
# Check indexing: [54264] [54600] [63024] [63191] [63192]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2148...
# Checking date: 2022-03-19 00:00:00
# Check indexing: [54288] [54624] [63048] [63215] [63216]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2149...
# Checking date: 2022-03-20 00:00:00
# Check indexing: [54312] [54648] [63072] [63239] [63240]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2150...
# Checking date: 2022-03-21 00:00:00
# Check indexing: [54336] [54672] [63096] [63263] [63264]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2151...
# Checking date: 2022-03-22 00:00:00
# Check indexing: [54360] [54696] [63120] [63287] [63288]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2152...
# Checking date: 2022-03-23 00:00:00
# Check indexing: [54384] [54720] [63144] [63311] [63312]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2153...
# Checking date: 2022-03-24 00:00:00
# Check indexing: [54408] [54744] [63168] [63335] [63336]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2154...
# Checking date: 2022-03-25 00:00:00
# Check indexing: [54432] [54768] [63192] [63359] [63360]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2155...
# Checking date: 2022-03-26 00:00:00
# Check indexing: [54456] [54792] [63216] [63383] [63384]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2156...
# Checking date: 2022-03-27 00:00:00
# Check indexing: [54480] [54816] [63240] [63407] [63408]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2157...
# Checking date: 2022-03-28 00:00:00
# Check indexing: [54504] [54840] [63264] [63431] [63432]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2158...
# Checking date: 2022-03-29 00:00:00
# Check indexing: [54528] [54864] [63288] [63455] [63456]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2159...
# Checking date: 2022-03-30 00:00:00
# Check indexing: [54552] [54888] [63312] [63479] [63480]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2160...
# Checking date: 2022-03-31 00:00:00
# Check indexing: [54576] [54912] [63336] [63503] [63504]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2161...
# Checking date: 2022-04-01 00:00:00
# Check indexing: [54600] [54936] [63360] [63527] [63528]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2162...
# Checking date: 2022-04-02 00:00:00
# Check indexing: [54624] [54960] [63384] [63551] [63552]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2163...
# Checking date: 2022-04-03 00:00:00
# Check indexing: [54648] [54984] [63408] [63575] [63576]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2164...
# Checking date: 2022-04-04 00:00:00
# Check indexing: [54672] [55008] [63432] [63599] [63600]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2165...
# Checking date: 2022-04-05 00:00:00
# Check indexing: [54696] [55032] [63456] [63623] [63624]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2166...
# Checking date: 2022-04-06 00:00:00
# Check indexing: [54720] [55056] [63480] [63647] [63648]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2167...
# Checking date: 2022-04-07 00:00:00
# Check indexing: [54744] [55080] [63504] [63671] [63672]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2168...
# Checking date: 2022-04-08 00:00:00
# Check indexing: [54768] [55104] [63528] [63695] [63696]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2169...
# Checking date: 2022-04-09 00:00:00
# Check indexing: [54792] [55128] [63552] [63719] [63720]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2170...
# Checking date: 2022-04-10 00:00:00
# Check indexing: [54816] [55152] [63576] [63743] [63744]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2171...
# Checking date: 2022-04-11 00:00:00
# Check indexing: [54840] [55176] [63600] [63767] [63768]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2172...
# Checking date: 2022-04-12 00:00:00
# Check indexing: [54864] [55200] [63624] [63791] [63792]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2173...
# Checking date: 2022-04-13 00:00:00
# Check indexing: [54888] [55224] [63648] [63815] [63816]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2174...
# Checking date: 2022-04-14 00:00:00
# Check indexing: [54912] [55248] [63672] [63839] [63840]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2175...
# Checking date: 2022-04-15 00:00:00
# Check indexing: [54936] [55272] [63696] [63863] [63864]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2176...
# Checking date: 2022-04-16 00:00:00
# Check indexing: [54960] [55296] [63720] [63887] [63888]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2177...
# Checking date: 2022-04-17 00:00:00
# Check indexing: [54984] [55320] [63744] [63911] [63912]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2178...
# Checking date: 2022-04-18 00:00:00
# Check indexing: [55008] [55344] [63768] [63935] [63936]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2179...
# Checking date: 2022-04-19 00:00:00
# Check indexing: [55032] [55368] [63792] [63959] [63960]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2180...
# Checking date: 2022-04-20 00:00:00
# Check indexing: [55056] [55392] [63816] [63983] [63984]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2181...
# Checking date: 2022-04-21 00:00:00
# Check indexing: [55080] [55416] [63840] [64007] [64008]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2182...
# Checking date: 2022-04-22 00:00:00
# Check indexing: [55104] [55440] [63864] [64031] [64032]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2183...
# Checking date: 2022-04-23 00:00:00
# Check indexing: [55128] [55464] [63888] [64055] [64056]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2184...
# Checking date: 2022-04-24 00:00:00
# Check indexing: [55152] [55488] [63912] [64079] [64080]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2185...
# Checking date: 2022-04-25 00:00:00
# Check indexing: [55176] [55512] [63936] [64103] [64104]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2186...
# Checking date: 2022-04-26 00:00:00
# Check indexing: [55200] [55536] [63960] [64127] [64128]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2187...
# Checking date: 2022-04-27 00:00:00
# Check indexing: [55224] [55560] [63984] [64151] [64152]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2188...
# Checking date: 2022-04-28 00:00:00
# Check indexing: [55248] [55584] [64008] [64175] [64176]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2189...
# Checking date: 2022-04-29 00:00:00
# Check indexing: [55272] [55608] [64032] [64199] [64200]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2190...
# Checking date: 2022-04-30 00:00:00
# Check indexing: [55296] [55632] [64056] [64223] [64224]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2191...
# Checking date: 2022-05-01 00:00:00
# Check indexing: [55320] [55656] [64080] [64247] [64248]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2192...
# Checking date: 2022-05-02 00:00:00
# Check indexing: [55344] [55680] [64104] [64271] [64272]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2193...
# Checking date: 2022-05-03 00:00:00
# Check indexing: [55368] [55704] [64128] [64295] [64296]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2194...
# Checking date: 2022-05-04 00:00:00
# Check indexing: [55392] [55728] [64152] [64319] [64320]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2195...
# Checking date: 2022-05-05 00:00:00
# Check indexing: [55416] [55752] [64176] [64343] [64344]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2196...
# Checking date: 2022-05-06 00:00:00
# Check indexing: [55440] [55776] [64200] [64367] [64368]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2197...
# Checking date: 2022-05-07 00:00:00
# Check indexing: [55464] [55800] [64224] [64391] [64392]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2198...
# Checking date: 2022-05-08 00:00:00
# Check indexing: [55488] [55824] [64248] [64415] [64416]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2199...
# Checking date: 2022-05-09 00:00:00
# Check indexing: [55512] [55848] [64272] [64439] [64440]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2200...
# Checking date: 2022-05-10 00:00:00
# Check indexing: [55536] [55872] [64296] [64463] [64464]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2201...
# Checking date: 2022-05-11 00:00:00
# Check indexing: [55560] [55896] [64320] [64487] [64488]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2202...
# Checking date: 2022-05-12 00:00:00
# Check indexing: [55584] [55920] [64344] [64511] [64512]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2203...
# Checking date: 2022-05-13 00:00:00
# Check indexing: [55608] [55944] [64368] [64535] [64536]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2204...
# Checking date: 2022-05-14 00:00:00
# Check indexing: [55632] [55968] [64392] [64559] [64560]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2205...
# Checking date: 2022-05-15 00:00:00
# Check indexing: [55656] [55992] [64416] [64583] [64584]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2206...
# Checking date: 2022-05-16 00:00:00
# Check indexing: [55680] [56016] [64440] [64607] [64608]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2207...
# Checking date: 2022-05-17 00:00:00
# Check indexing: [55704] [56040] [64464] [64631] [64632]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2208...
# Checking date: 2022-05-18 00:00:00
# Check indexing: [55728] [56064] [64488] [64655] [64656]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2209...
# Checking date: 2022-05-19 00:00:00
# Check indexing: [55752] [56088] [64512] [64679] [64680]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2210...
# Checking date: 2022-05-20 00:00:00
# Check indexing: [55776] [56112] [64536] [64703] [64704]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2211...
# Checking date: 2022-05-21 00:00:00
# Check indexing: [55800] [56136] [64560] [64727] [64728]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2212...
# Checking date: 2022-05-22 00:00:00
# Check indexing: [55824] [56160] [64584] [64751] [64752]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2213...
# Checking date: 2022-05-23 00:00:00
# Check indexing: [55848] [56184] [64608] [64775] [64776]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2214...
# Checking date: 2022-05-24 00:00:00
# Check indexing: [55872] [56208] [64632] [64799] [64800]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2215...
# Checking date: 2022-05-25 00:00:00
# Check indexing: [55896] [56232] [64656] [64823] [64824]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2216...
# Checking date: 2022-05-26 00:00:00
# Check indexing: [55920] [56256] [64680] [64847] [64848]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2217...
# Checking date: 2022-05-27 00:00:00
# Check indexing: [55944] [56280] [64704] [64871] [64872]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2218...
# Checking date: 2022-05-28 00:00:00
# Check indexing: [55968] [56304] [64728] [64895] [64896]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2219...
# Checking date: 2022-05-29 00:00:00
# Check indexing: [55992] [56328] [64752] [64919] [64920]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2220...
# Checking date: 2022-05-30 00:00:00
# Check indexing: [56016] [56352] [64776] [64943] [64944]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2221...
# Checking date: 2022-05-31 00:00:00
# Check indexing: [56040] [56376] [64800] [64967] [64968]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2222...
# Checking date: 2022-06-01 00:00:00
# Check indexing: [56064] [56400] [64824] [64991] [64992]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2223...
# Checking date: 2022-06-02 00:00:00
# Check indexing: [56088] [56424] [64848] [65015] [65016]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2224...
# Checking date: 2022-06-03 00:00:00
# Check indexing: [56112] [56448] [64872] [65039] [65040]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2225...
# Checking date: 2022-06-04 00:00:00
# Check indexing: [56136] [56472] [64896] [65063] [65064]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2226...
# Checking date: 2022-06-05 00:00:00
# Check indexing: [56160] [56496] [64920] [65087] [65088]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2227...
# Checking date: 2022-06-06 00:00:00
# Check indexing: [56184] [56520] [64944] [65111] [65112]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2228...
# Checking date: 2022-06-07 00:00:00
# Check indexing: [56208] [56544] [64968] [65135] [65136]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2229...
# Checking date: 2022-06-08 00:00:00
# Check indexing: [56232] [56568] [64992] [65159] [65160]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2230...
# Checking date: 2022-06-09 00:00:00
# Check indexing: [56256] [56592] [65016] [65183] [65184]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2231...
# Checking date: 2022-06-10 00:00:00
# Check indexing: [56280] [56616] [65040] [65207] [65208]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2232...
# Checking date: 2022-06-11 00:00:00
# Check indexing: [56304] [56640] [65064] [65231] [65232]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2233...
# Checking date: 2022-06-12 00:00:00
# Check indexing: [56328] [56664] [65088] [65255] [65256]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2234...
# Checking date: 2022-06-13 00:00:00
# Check indexing: [56352] [56688] [65112] [65279] [65280]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2235...
# Checking date: 2022-06-14 00:00:00
# Check indexing: [56376] [56712] [65136] [65303] [65304]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2236...
# Checking date: 2022-06-15 00:00:00
# Check indexing: [56400] [56736] [65160] [65327] [65328]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2237...
# Checking date: 2022-06-16 00:00:00
# Check indexing: [56424] [56760] [65184] [65351] [65352]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2238...
# Checking date: 2022-06-17 00:00:00
# Check indexing: [56448] [56784] [65208] [65375] [65376]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2239...
# Checking date: 2022-06-18 00:00:00
# Check indexing: [56472] [56808] [65232] [65399] [65400]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2240...
# Checking date: 2022-06-19 00:00:00
# Check indexing: [56496] [56832] [65256] [65423] [65424]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2241...
# Checking date: 2022-06-20 00:00:00
# Check indexing: [56520] [56856] [65280] [65447] [65448]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2242...
# Checking date: 2022-06-21 00:00:00
# Check indexing: [56544] [56880] [65304] [65471] [65472]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2243...
# Checking date: 2022-06-22 00:00:00
# Check indexing: [56568] [56904] [65328] [65495] [65496]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2244...
# Checking date: 2022-06-23 00:00:00
# Check indexing: [56592] [56928] [65352] [65519] [65520]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2245...
# Checking date: 2022-06-24 00:00:00
# Check indexing: [56616] [56952] [65376] [65543] [65544]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2246...
# Checking date: 2022-06-25 00:00:00
# Check indexing: [56640] [56976] [65400] [65567] [65568]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2247...
# Checking date: 2022-06-26 00:00:00
# Check indexing: [56664] [57000] [65424] [65591] [65592]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2248...
# Checking date: 2022-06-27 00:00:00
# Check indexing: [56688] [57024] [65448] [65615] [65616]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2249...
# Checking date: 2022-06-28 00:00:00
# Check indexing: [56712] [57048] [65472] [65639] [65640]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2250...
# Checking date: 2022-06-29 00:00:00
# Check indexing: [56736] [57072] [65496] [65663] [65664]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2251...
# Checking date: 2022-06-30 00:00:00
# Check indexing: [56760] [57096] [65520] [65687] [65688]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2252...
# Checking date: 2022-07-01 00:00:00
# Check indexing: [56784] [57120] [65544] [65711] [65712]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2253...
# Checking date: 2022-07-02 00:00:00
# ...
# ----------------------------------
# Get 2624...
# Checking date: 2023-07-08 00:00:00
# Check indexing: [65712] [66048] [74472] [74639] [74640]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2625...
# Checking date: 2023-07-09 00:00:00
# Check indexing: [65736] [66072] [74496] [74663] [74664]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2626...
# Checking date: 2023-07-10 00:00:00
# Check indexing: [65760] [66096] [74520] [74687] [74688]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2627...
# Checking date: 2023-07-11 00:00:00
# Check indexing: [65784] [66120] [74544] [74711] [74712]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2628...
# Checking date: 2023-07-12 00:00:00
# Check indexing: [65808] [66144] [74568] [74735] [74736]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2629...
# Checking date: 2023-07-13 00:00:00
# Check indexing: [65832] [66168] [74592] [74759] [74760]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2630...
# Checking date: 2023-07-14 00:00:00
# Check indexing: [65856] [66192] [74616] [74783] [74784]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2631...
# Checking date: 2023-07-15 00:00:00
# Check indexing: [65880] [66216] [74640] [74807] [74808]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2632...
# Checking date: 2023-07-16 00:00:00
# Check indexing: [65904] [66240] [74664] [74831] [74832]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2633...
# Checking date: 2023-07-17 00:00:00
# Check indexing: [65928] [66264] [74688] [74855] [74856]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2634...
# Checking date: 2023-07-18 00:00:00
# Check indexing: [65952] [66288] [74712] [74879] [74880]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2635...
# Checking date: 2023-07-19 00:00:00
# Check indexing: [65976] [66312] [74736] [74903] [74904]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2636...
# Checking date: 2023-07-20 00:00:00
# Check indexing: [66000] [66336] [74760] [74927] [74928]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2637...
# Checking date: 2023-07-21 00:00:00
# Check indexing: [66024] [66360] [74784] [74951] [74952]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2638...
# Checking date: 2023-07-22 00:00:00
# Check indexing: [66048] [66384] [74808] [74975] [74976]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2639...
# Checking date: 2023-07-23 00:00:00
# Check indexing: [66072] [66408] [74832] [74999] [75000]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2640...
# Checking date: 2023-07-24 00:00:00
# Check indexing: [66096] [66432] [74856] [75023] [75024]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2641...
# Checking date: 2023-07-25 00:00:00
# Check indexing: [66120] [66456] [74880] [75047] [75048]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2642...
# Checking date: 2023-07-26 00:00:00
# Check indexing: [66144] [66480] [74904] [75071] [75072]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2643...
# Checking date: 2023-07-27 00:00:00
# Check indexing: [66168] [66504] [74928] [75095] [75096]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2644...
# Checking date: 2023-07-28 00:00:00
# Check indexing: [66192] [66528] [74952] [75119] [75120]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2645...
# Checking date: 2023-07-29 00:00:00
# Check indexing: [66216] [66552] [74976] [75143] [75144]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2646...
# Checking date: 2023-07-30 00:00:00
# Check indexing: [66240] [66576] [75000] [75167] [75168]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2647...
# Checking date: 2023-07-31 00:00:00
# Check indexing: [66264] [66600] [75024] [75191] [75192]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2648...
# Checking date: 2023-08-01 00:00:00
# Check indexing: [66288] [66624] [75048] [75215] [75216]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2649...
# Checking date: 2023-08-02 00:00:00
# Check indexing: [66312] [66648] [75072] [75239] [75240]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2650...
# Checking date: 2023-08-03 00:00:00
# Check indexing: [66336] [66672] [75096] [75263] [75264]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2651...
# Checking date: 2023-08-04 00:00:00
# Check indexing: [66360] [66696] [75120] [75287] [75288]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2652...
# Checking date: 2023-08-05 00:00:00
# Check indexing: [66384] [66720] [75144] [75311] [75312]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2653...
# Checking date: 2023-08-06 00:00:00
# Check indexing: [66408] [66744] [75168] [75335] [75336]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2654...
# Checking date: 2023-08-07 00:00:00
# Check indexing: [66432] [66768] [75192] [75359] [75360]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2655...
# Checking date: 2023-08-08 00:00:00
# Check indexing: [66456] [66792] [75216] [75383] [75384]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2656...
# Checking date: 2023-08-09 00:00:00
# Check indexing: [66480] [66816] [75240] [75407] [75408]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2657...
# Checking date: 2023-08-10 00:00:00
# Check indexing: [66504] [66840] [75264] [75431] [75432]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2658...
# Checking date: 2023-08-11 00:00:00
# Check indexing: [66528] [66864] [75288] [75455] [75456]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2659...
# Checking date: 2023-08-12 00:00:00
# Check indexing: [66552] [66888] [75312] [75479] [75480]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2660...
# Checking date: 2023-08-13 00:00:00
# Check indexing: [66576] [66912] [75336] [75503] [75504]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2661...
# Checking date: 2023-08-14 00:00:00
# Check indexing: [66600] [66936] [75360] [75527] [75528]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2662...
# Checking date: 2023-08-15 00:00:00
# Check indexing: [66624] [66960] [75384] [75551] [75552]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2663...
# Checking date: 2023-08-16 00:00:00
# Check indexing: [66648] [66984] [75408] [75575] [75576]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2664...
# Checking date: 2023-08-17 00:00:00
# Check indexing: [66672] [67008] [75432] [75599] [75600]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2665...
# Checking date: 2023-08-18 00:00:00
# Check indexing: [66696] [67032] [75456] [75623] [75624]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2666...
# Checking date: 2023-08-19 00:00:00
# Check indexing: [66720] [67056] [75480] [75647] [75648]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2667...
# Checking date: 2023-08-20 00:00:00
# Check indexing: [66744] [67080] [75504] [75671] [75672]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2668...
# Checking date: 2023-08-21 00:00:00
# Check indexing: [66768] [67104] [75528] [75695] [75696]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2669...
# Checking date: 2023-08-22 00:00:00
# Check indexing: [66792] [67128] [75552] [75719] [75720]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2670...
# Checking date: 2023-08-23 00:00:00
# Check indexing: [66816] [67152] [75576] [75743] [75744]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2671...
# Checking date: 2023-08-24 00:00:00
# Check indexing: [66840] [67176] [75600] [75767] [75768]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2672...
# Checking date: 2023-08-25 00:00:00
# Check indexing: [66864] [67200] [75624] [75791] [75792]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2673...
# Checking date: 2023-08-26 00:00:00
# Check indexing: [66888] [67224] [75648] [75815] [75816]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2674...
# Checking date: 2023-08-27 00:00:00
# Check indexing: [66912] [67248] [75672] [75839] [75840]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2675...
# Checking date: 2023-08-28 00:00:00
# Check indexing: [66936] [67272] [75696] [75863] [75864]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2676...
# Checking date: 2023-08-29 00:00:00
# Check indexing: [66960] [67296] [75720] [75887] [75888]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2677...
# Checking date: 2023-08-30 00:00:00
# Check indexing: [66984] [67320] [75744] [75911] [75912]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2678...
# Checking date: 2023-08-31 00:00:00
# Check indexing: [67008] [67344] [75768] [75935] [75936]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2679...
# Checking date: 2023-09-01 00:00:00
# Check indexing: [67032] [67368] [75792] [75959] [75960]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2680...
# Checking date: 2023-09-02 00:00:00
# Check indexing: [67056] [67392] [75816] [75983] [75984]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2681...
# Checking date: 2023-09-03 00:00:00
# Check indexing: [67080] [67416] [75840] [76007] [76008]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2682...
# Checking date: 2023-09-04 00:00:00
# Check indexing: [67104] [67440] [75864] [76031] [76032]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2683...
# Checking date: 2023-09-05 00:00:00
# Check indexing: [67128] [67464] [75888] [76055] [76056]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2684...
# Checking date: 2023-09-06 00:00:00
# Check indexing: [67152] [67488] [75912] [76079] [76080]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2685...
# Checking date: 2023-09-07 00:00:00
# Check indexing: [67176] [67512] [75936] [76103] [76104]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2686...
# Checking date: 2023-09-08 00:00:00
# Check indexing: [67200] [67536] [75960] [76127] [76128]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2687...
# Checking date: 2023-09-09 00:00:00
# Check indexing: [67224] [67560] [75984] [76151] [76152]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2688...
# Checking date: 2023-09-10 00:00:00
# Check indexing: [67248] [67584] [76008] [76175] [76176]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2689...
# Checking date: 2023-09-11 00:00:00
# Check indexing: [67272] [67608] [76032] [76199] [76200]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2690...
# Checking date: 2023-09-12 00:00:00
# Check indexing: [67296] [67632] [76056] [76223] [76224]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2691...
# Checking date: 2023-09-13 00:00:00
# Check indexing: [67320] [67656] [76080] [76247] [76248]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2692...
# Checking date: 2023-09-14 00:00:00
# Check indexing: [67344] [67680] [76104] [76271] [76272]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2693...
# Checking date: 2023-09-15 00:00:00
# Check indexing: [67368] [67704] [76128] [76295] [76296]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2694...
# Checking date: 2023-09-16 00:00:00
# Check indexing: [67392] [67728] [76152] [76319] [76320]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2695...
# Checking date: 2023-09-17 00:00:00
# Check indexing: [67416] [67752] [76176] [76343] [76344]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2696...
# Checking date: 2023-09-18 00:00:00
# Check indexing: [67440] [67776] [76200] [76367] [76368]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2697...
# Checking date: 2023-09-19 00:00:00
# Check indexing: [67464] [67800] [76224] [76391] [76392]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2698...
# Checking date: 2023-09-20 00:00:00
# Check indexing: [67488] [67824] [76248] [76415] [76416]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2699...
# Checking date: 2023-09-21 00:00:00
# Check indexing: [67512] [67848] [76272] [76439] [76440]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2700...
# Checking date: 2023-09-22 00:00:00
# Check indexing: [67536] [67872] [76296] [76463] [76464]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2701...
# Checking date: 2023-09-23 00:00:00
# Check indexing: [67560] [67896] [76320] [76487] [76488]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2702...
# Checking date: 2023-09-24 00:00:00
# Check indexing: [67584] [67920] [76344] [76511] [76512]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2703...
# Checking date: 2023-09-25 00:00:00
# Check indexing: [67608] [67944] [76368] [76535] [76536]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2704...
# Checking date: 2023-09-26 00:00:00
# Check indexing: [67632] [67968] [76392] [76559] [76560]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2705...
# Checking date: 2023-09-27 00:00:00
# Check indexing: [67656] [67992] [76416] [76583] [76584]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2706...
# Checking date: 2023-09-28 00:00:00
# Check indexing: [67680] [68016] [76440] [76607] [76608]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2707...
# Checking date: 2023-09-29 00:00:00
# Check indexing: [67704] [68040] [76464] [76631] [76632]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2708...
# Checking date: 2023-09-30 00:00:00
# Check indexing: [67728] [68064] [76488] [76655] [76656]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2709...
# Checking date: 2023-10-01 00:00:00
# Check indexing: [67752] [68088] [76512] [76679] [76680]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!

# %%
print(x_heat.shape)
print(y_heat.shape)
# Out:
# (2710, 2020)
# (2710,)

# %%
scaler = StandardScaler()
scaler.fit_transform(x_heat)
uniq_heat, count_heat = np.unique(y_heat, return_counts=True)
print(dict(zip(uniq_heat, count_heat)))
# Out:
# {0: 2705, 1: 5}

# %%
x_train_heat, x_test_heat, y_train_heat, y_test_heat = train_test_split(x_heat, y_heat, test_size=0.2, random_state=0)

# %%
heat_model = SVC()
heat_model.fit(x_train_heat, y_train_heat)
y_pred_heat = heat_model.predict(x_test_heat)
print(accuracy_score(y_test_heat, y_pred_heat))
print(f1_score(y_test_heat, y_pred_heat))
# Out:
# 0.996309963099631
# 0.0

# %%
confusion_matrix(y_test_heat, y_pred_heat)
# Out:
# array([[540,   0],
#        [  2,   0]])

# %%
x_rain, y_rain = get_train_test_data('2016-05-01 00:00:00', '2023-10-01 23:00:00', columns_rain, target_rain)
x_rain = np.array(x_rain)
y_rain = np.array(y_rain).astype('int').reshape(-1,)
x_train_rain, x_test_rain, y_train_rain, y_test_rain = train_test_split(x_rain, y_rain, test_size=0.2, random_state=0)
# Out:
# Streaming output truncated to the last 5000 lines.
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1996...
# Checking date: 2021-10-18 00:00:00
# Check indexing: [50640] [50976] [59400] [59567] [59568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1997...
# Checking date: 2021-10-19 00:00:00
# Check indexing: [50664] [51000] [59424] [59591] [59592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1998...
# Checking date: 2021-10-20 00:00:00
# Check indexing: [50688] [51024] [59448] [59615] [59616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1999...
# Checking date: 2021-10-21 00:00:00
# Check indexing: [50712] [51048] [59472] [59639] [59640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2000...
# Checking date: 2021-10-22 00:00:00
# Check indexing: [50736] [51072] [59496] [59663] [59664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2001...
# Checking date: 2021-10-23 00:00:00
# Check indexing: [50760] [51096] [59520] [59687] [59688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2002...
# Checking date: 2021-10-24 00:00:00
# Check indexing: [50784] [51120] [59544] [59711] [59712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2003...
# Checking date: 2021-10-25 00:00:00
# Check indexing: [50808] [51144] [59568] [59735] [59736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2004...
# Checking date: 2021-10-26 00:00:00
# Check indexing: [50832] [51168] [59592] [59759] [59760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2005...
# Checking date: 2021-10-27 00:00:00
# Check indexing: [50856] [51192] [59616] [59783] [59784]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2006...
# Checking date: 2021-10-28 00:00:00
# Check indexing: [50880] [51216] [59640] [59807] [59808]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2007...
# Checking date: 2021-10-29 00:00:00
# Check indexing: [50904] [51240] [59664] [59831] [59832]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2008...
# Checking date: 2021-10-30 00:00:00
# Check indexing: [50928] [51264] [59688] [59855] [59856]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2009...
# Checking date: 2021-10-31 00:00:00
# Check indexing: [50952] [51288] [59712] [59879] [59880]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2010...
# Checking date: 2021-11-01 00:00:00
# Check indexing: [50976] [51312] [59736] [59903] [59904]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2011...
# Checking date: 2021-11-02 00:00:00
# Check indexing: [51000] [51336] [59760] [59927] [59928]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2012...
# Checking date: 2021-11-03 00:00:00
# Check indexing: [51024] [51360] [59784] [59951] [59952]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2013...
# Checking date: 2021-11-04 00:00:00
# Check indexing: [51048] [51384] [59808] [59975] [59976]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2014...
# Checking date: 2021-11-05 00:00:00
# Check indexing: [51072] [51408] [59832] [59999] [60000]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2015...
# Checking date: 2021-11-06 00:00:00
# Check indexing: [51096] [51432] [59856] [60023] [60024]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2016...
# Checking date: 2021-11-07 00:00:00
# Check indexing: [51120] [51456] [59880] [60047] [60048]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2017...
# Checking date: 2021-11-08 00:00:00
# Check indexing: [51144] [51480] [59904] [60071] [60072]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2018...
# Checking date: 2021-11-09 00:00:00
# Check indexing: [51168] [51504] [59928] [60095] [60096]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2019...
# Checking date: 2021-11-10 00:00:00
# Check indexing: [51192] [51528] [59952] [60119] [60120]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2020...
# Checking date: 2021-11-11 00:00:00
# Check indexing: [51216] [51552] [59976] [60143] [60144]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2021...
# Checking date: 2021-11-12 00:00:00
# Check indexing: [51240] [51576] [60000] [60167] [60168]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2022...
# Checking date: 2021-11-13 00:00:00
# Check indexing: [51264] [51600] [60024] [60191] [60192]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2023...
# Checking date: 2021-11-14 00:00:00
# Check indexing: [51288] [51624] [60048] [60215] [60216]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2024...
# Checking date: 2021-11-15 00:00:00
# Check indexing: [51312] [51648] [60072] [60239] [60240]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2025...
# Checking date: 2021-11-16 00:00:00
# Check indexing: [51336] [51672] [60096] [60263] [60264]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2026...
# Checking date: 2021-11-17 00:00:00
# Check indexing: [51360] [51696] [60120] [60287] [60288]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2027...
# Checking date: 2021-11-18 00:00:00
# Check indexing: [51384] [51720] [60144] [60311] [60312]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2028...
# Checking date: 2021-11-19 00:00:00
# Check indexing: [51408] [51744] [60168] [60335] [60336]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2029...
# Checking date: 2021-11-20 00:00:00
# Check indexing: [51432] [51768] [60192] [60359] [60360]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2030...
# Checking date: 2021-11-21 00:00:00
# Check indexing: [51456] [51792] [60216] [60383] [60384]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2031...
# Checking date: 2021-11-22 00:00:00
# Check indexing: [51480] [51816] [60240] [60407] [60408]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2032...
# Checking date: 2021-11-23 00:00:00
# Check indexing: [51504] [51840] [60264] [60431] [60432]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2033...
# Checking date: 2021-11-24 00:00:00
# Check indexing: [51528] [51864] [60288] [60455] [60456]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2034...
# Checking date: 2021-11-25 00:00:00
# Check indexing: [51552] [51888] [60312] [60479] [60480]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2035...
# Checking date: 2021-11-26 00:00:00
# Check indexing: [51576] [51912] [60336] [60503] [60504]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2036...
# Checking date: 2021-11-27 00:00:00
# Check indexing: [51600] [51936] [60360] [60527] [60528]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2037...
# Checking date: 2021-11-28 00:00:00
# Check indexing: [51624] [51960] [60384] [60551] [60552]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2038...
# Checking date: 2021-11-29 00:00:00
# Check indexing: [51648] [51984] [60408] [60575] [60576]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2039...
# Checking date: 2021-11-30 00:00:00
# Check indexing: [51672] [52008] [60432] [60599] [60600]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2040...
# Checking date: 2021-12-01 00:00:00
# Check indexing: [51696] [52032] [60456] [60623] [60624]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2041...
# Checking date: 2021-12-02 00:00:00
# Check indexing: [51720] [52056] [60480] [60647] [60648]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2042...
# Checking date: 2021-12-03 00:00:00
# Check indexing: [51744] [52080] [60504] [60671] [60672]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2043...
# Checking date: 2021-12-04 00:00:00
# Check indexing: [51768] [52104] [60528] [60695] [60696]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2044...
# Checking date: 2021-12-05 00:00:00
# Check indexing: [51792] [52128] [60552] [60719] [60720]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2045...
# Checking date: 2021-12-06 00:00:00
# Check indexing: [51816] [52152] [60576] [60743] [60744]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2046...
# Checking date: 2021-12-07 00:00:00
# Check indexing: [51840] [52176] [60600] [60767] [60768]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2047...
# Checking date: 2021-12-08 00:00:00
# Check indexing: [51864] [52200] [60624] [60791] [60792]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2048...
# Checking date: 2021-12-09 00:00:00
# Check indexing: [51888] [52224] [60648] [60815] [60816]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2049...
# Checking date: 2021-12-10 00:00:00
# Check indexing: [51912] [52248] [60672] [60839] [60840]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2050...
# Checking date: 2021-12-11 00:00:00
# Check indexing: [51936] [52272] [60696] [60863] [60864]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2051...
# Checking date: 2021-12-12 00:00:00
# Check indexing: [51960] [52296] [60720] [60887] [60888]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2052...
# Checking date: 2021-12-13 00:00:00
# Check indexing: [51984] [52320] [60744] [60911] [60912]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2053...
# Checking date: 2021-12-14 00:00:00
# Check indexing: [52008] [52344] [60768] [60935] [60936]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2054...
# Checking date: 2021-12-15 00:00:00
# Check indexing: [52032] [52368] [60792] [60959] [60960]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2055...
# Checking date: 2021-12-16 00:00:00
# Check indexing: [52056] [52392] [60816] [60983] [60984]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2056...
# Checking date: 2021-12-17 00:00:00
# Check indexing: [52080] [52416] [60840] [61007] [61008]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2057...
# Checking date: 2021-12-18 00:00:00
# Check indexing: [52104] [52440] [60864] [61031] [61032]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2058...
# Checking date: 2021-12-19 00:00:00
# Check indexing: [52128] [52464] [60888] [61055] [61056]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2059...
# Checking date: 2021-12-20 00:00:00
# Check indexing: [52152] [52488] [60912] [61079] [61080]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2060...
# Checking date: 2021-12-21 00:00:00
# Check indexing: [52176] [52512] [60936] [61103] [61104]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2061...
# Checking date: 2021-12-22 00:00:00
# Check indexing: [52200] [52536] [60960] [61127] [61128]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2062...
# Checking date: 2021-12-23 00:00:00
# Check indexing: [52224] [52560] [60984] [61151] [61152]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2063...
# Checking date: 2021-12-24 00:00:00
# Check indexing: [52248] [52584] [61008] [61175] [61176]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2064...
# Checking date: 2021-12-25 00:00:00
# Check indexing: [52272] [52608] [61032] [61199] [61200]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2065...
# Checking date: 2021-12-26 00:00:00
# Check indexing: [52296] [52632] [61056] [61223] [61224]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2066...
# Checking date: 2021-12-27 00:00:00
# Check indexing: [52320] [52656] [61080] [61247] [61248]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2067...
# Checking date: 2021-12-28 00:00:00
# Check indexing: [52344] [52680] [61104] [61271] [61272]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2068...
# Checking date: 2021-12-29 00:00:00
# Check indexing: [52368] [52704] [61128] [61295] [61296]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2069...
# Checking date: 2021-12-30 00:00:00
# Check indexing: [52392] [52728] [61152] [61319] [61320]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2070...
# Checking date: 2021-12-31 00:00:00
# Check indexing: [52416] [52752] [61176] [61343] [61344]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2071...
# Checking date: 2022-01-01 00:00:00
# Check indexing: [52440] [52776] [61200] [61367] [61368]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2072...
# Checking date: 2022-01-02 00:00:00
# Check indexing: [52464] [52800] [61224] [61391] [61392]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2073...
# Checking date: 2022-01-03 00:00:00
# Check indexing: [52488] [52824] [61248] [61415] [61416]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2074...
# Checking date: 2022-01-04 00:00:00
# Check indexing: [52512] [52848] [61272] [61439] [61440]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2075...
# Checking date: 2022-01-05 00:00:00
# Check indexing: [52536] [52872] [61296] [61463] [61464]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2076...
# Checking date: 2022-01-06 00:00:00
# Check indexing: [52560] [52896] [61320] [61487] [61488]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2077...
# Checking date: 2022-01-07 00:00:00
# Check indexing: [52584] [52920] [61344] [61511] [61512]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2078...
# Checking date: 2022-01-08 00:00:00
# Check indexing: [52608] [52944] [61368] [61535] [61536]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2079...
# Checking date: 2022-01-09 00:00:00
# Check indexing: [52632] [52968] [61392] [61559] [61560]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2080...
# Checking date: 2022-01-10 00:00:00
# Check indexing: [52656] [52992] [61416] [61583] [61584]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2081...
# Checking date: 2022-01-11 00:00:00
# Check indexing: [52680] [53016] [61440] [61607] [61608]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2082...
# Checking date: 2022-01-12 00:00:00
# Check indexing: [52704] [53040] [61464] [61631] [61632]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2083...
# Checking date: 2022-01-13 00:00:00
# Check indexing: [52728] [53064] [61488] [61655] [61656]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2084...
# Checking date: 2022-01-14 00:00:00
# Check indexing: [52752] [53088] [61512] [61679] [61680]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2085...
# Checking date: 2022-01-15 00:00:00
# Check indexing: [52776] [53112] [61536] [61703] [61704]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2086...
# Checking date: 2022-01-16 00:00:00
# Check indexing: [52800] [53136] [61560] [61727] [61728]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2087...
# Checking date: 2022-01-17 00:00:00
# Check indexing: [52824] [53160] [61584] [61751] [61752]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2088...
# Checking date: 2022-01-18 00:00:00
# Check indexing: [52848] [53184] [61608] [61775] [61776]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2089...
# Checking date: 2022-01-19 00:00:00
# Check indexing: [52872] [53208] [61632] [61799] [61800]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2090...
# Checking date: 2022-01-20 00:00:00
# Check indexing: [52896] [53232] [61656] [61823] [61824]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2091...
# Checking date: 2022-01-21 00:00:00
# Check indexing: [52920] [53256] [61680] [61847] [61848]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2092...
# Checking date: 2022-01-22 00:00:00
# Check indexing: [52944] [53280] [61704] [61871] [61872]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2093...
# Checking date: 2022-01-23 00:00:00
# Check indexing: [52968] [53304] [61728] [61895] [61896]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2094...
# Checking date: 2022-01-24 00:00:00
# Check indexing: [52992] [53328] [61752] [61919] [61920]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2095...
# Checking date: 2022-01-25 00:00:00
# Check indexing: [53016] [53352] [61776] [61943] [61944]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2096...
# Checking date: 2022-01-26 00:00:00
# Check indexing: [53040] [53376] [61800] [61967] [61968]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2097...
# Checking date: 2022-01-27 00:00:00
# Check indexing: [53064] [53400] [61824] [61991] [61992]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2098...
# Checking date: 2022-01-28 00:00:00
# Check indexing: [53088] [53424] [61848] [62015] [62016]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2099...
# Checking date: 2022-01-29 00:00:00
# Check indexing: [53112] [53448] [61872] [62039] [62040]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2100...
# Checking date: 2022-01-30 00:00:00
# Check indexing: [53136] [53472] [61896] [62063] [62064]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2101...
# Checking date: 2022-01-31 00:00:00
# Check indexing: [53160] [53496] [61920] [62087] [62088]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2102...
# Checking date: 2022-02-01 00:00:00
# Check indexing: [53184] [53520] [61944] [62111] [62112]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2103...
# Checking date: 2022-02-02 00:00:00
# Check indexing: [53208] [53544] [61968] [62135] [62136]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2104...
# Checking date: 2022-02-03 00:00:00
# Check indexing: [53232] [53568] [61992] [62159] [62160]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2105...
# Checking date: 2022-02-04 00:00:00
# Check indexing: [53256] [53592] [62016] [62183] [62184]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2106...
# Checking date: 2022-02-05 00:00:00
# Check indexing: [53280] [53616] [62040] [62207] [62208]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2107...
# Checking date: 2022-02-06 00:00:00
# Check indexing: [53304] [53640] [62064] [62231] [62232]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2108...
# Checking date: 2022-02-07 00:00:00
# Check indexing: [53328] [53664] [62088] [62255] [62256]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2109...
# Checking date: 2022-02-08 00:00:00
# Check indexing: [53352] [53688] [62112] [62279] [62280]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2110...
# Checking date: 2022-02-09 00:00:00
# Check indexing: [53376] [53712] [62136] [62303] [62304]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2111...
# Checking date: 2022-02-10 00:00:00
# Check indexing: [53400] [53736] [62160] [62327] [62328]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2112...
# Checking date: 2022-02-11 00:00:00
# Check indexing: [53424] [53760] [62184] [62351] [62352]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2113...
# Checking date: 2022-02-12 00:00:00
# Check indexing: [53448] [53784] [62208] [62375] [62376]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2114...
# Checking date: 2022-02-13 00:00:00
# Check indexing: [53472] [53808] [62232] [62399] [62400]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2115...
# Checking date: 2022-02-14 00:00:00
# Check indexing: [53496] [53832] [62256] [62423] [62424]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2116...
# Checking date: 2022-02-15 00:00:00
# Check indexing: [53520] [53856] [62280] [62447] [62448]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2117...
# Checking date: 2022-02-16 00:00:00
# Check indexing: [53544] [53880] [62304] [62471] [62472]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2118...
# Checking date: 2022-02-17 00:00:00
# Check indexing: [53568] [53904] [62328] [62495] [62496]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2119...
# Checking date: 2022-02-18 00:00:00
# Check indexing: [53592] [53928] [62352] [62519] [62520]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2120...
# Checking date: 2022-02-19 00:00:00
# Check indexing: [53616] [53952] [62376] [62543] [62544]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2121...
# Checking date: 2022-02-20 00:00:00
# Check indexing: [53640] [53976] [62400] [62567] [62568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2122...
# Checking date: 2022-02-21 00:00:00
# Check indexing: [53664] [54000] [62424] [62591] [62592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2123...
# Checking date: 2022-02-22 00:00:00
# Check indexing: [53688] [54024] [62448] [62615] [62616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2124...
# Checking date: 2022-02-23 00:00:00
# Check indexing: [53712] [54048] [62472] [62639] [62640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2125...
# Checking date: 2022-02-24 00:00:00
# Check indexing: [53736] [54072] [62496] [62663] [62664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2126...
# Checking date: 2022-02-25 00:00:00
# Check indexing: [53760] [54096] [62520] [62687] [62688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2127...
# Checking date: 2022-02-26 00:00:00
# Check indexing: [53784] [54120] [62544] [62711] [62712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2128...
# Checking date: 2022-02-27 00:00:00
# Check indexing: [53808] [54144] [62568] [62735] [62736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2129...
# Checking date: 2022-02-28 00:00:00
# Check indexing: [53832] [54168] [62592] [62759] [62760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2130...
# Checking date: 2022-03-01 00:00:00
# Check indexing: [53856] [54192] [62616] [62783] [62784]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2131...
# Checking date: 2022-03-02 00:00:00
# Check indexing: [53880] [54216] [62640] [62807] [62808]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2132...
# Checking date: 2022-03-03 00:00:00
# Check indexing: [53904] [54240] [62664] [62831] [62832]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2133...
# Checking date: 2022-03-04 00:00:00
# Check indexing: [53928] [54264] [62688] [62855] [62856]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2134...
# Checking date: 2022-03-05 00:00:00
# Check indexing: [53952] [54288] [62712] [62879] [62880]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2135...
# Checking date: 2022-03-06 00:00:00
# Check indexing: [53976] [54312] [62736] [62903] [62904]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2136...
# Checking date: 2022-03-07 00:00:00
# Check indexing: [54000] [54336] [62760] [62927] [62928]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2137...
# Checking date: 2022-03-08 00:00:00
# Check indexing: [54024] [54360] [62784] [62951] [62952]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2138...
# Checking date: 2022-03-09 00:00:00
# Check indexing: [54048] [54384] [62808] [62975] [62976]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2139...
# Checking date: 2022-03-10 00:00:00
# Check indexing: [54072] [54408] [62832] [62999] [63000]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2140...
# Checking date: 2022-03-11 00:00:00
# Check indexing: [54096] [54432] [62856] [63023] [63024]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2141...
# Checking date: 2022-03-12 00:00:00
# Check indexing: [54120] [54456] [62880] [63047] [63048]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2142...
# Checking date: 2022-03-13 00:00:00
# Check indexing: [54144] [54480] [62904] [63071] [63072]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2143...
# Checking date: 2022-03-14 00:00:00
# Check indexing: [54168] [54504] [62928] [63095] [63096]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2144...
# Checking date: 2022-03-15 00:00:00
# Check indexing: [54192] [54528] [62952] [63119] [63120]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2145...
# Checking date: 2022-03-16 00:00:00
# Check indexing: [54216] [54552] [62976] [63143] [63144]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2146...
# Checking date: 2022-03-17 00:00:00
# Check indexing: [54240] [54576] [63000] [63167] [63168]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2147...
# Checking date: 2022-03-18 00:00:00
# Check indexing: [54264] [54600] [63024] [63191] [63192]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2148...
# Checking date: 2022-03-19 00:00:00
# Check indexing: [54288] [54624] [63048] [63215] [63216]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2149...
# Checking date: 2022-03-20 00:00:00
# Check indexing: [54312] [54648] [63072] [63239] [63240]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2150...
# Checking date: 2022-03-21 00:00:00
# Check indexing: [54336] [54672] [63096] [63263] [63264]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2151...
# Checking date: 2022-03-22 00:00:00
# Check indexing: [54360] [54696] [63120] [63287] [63288]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2152...
# Checking date: 2022-03-23 00:00:00
# Check indexing: [54384] [54720] [63144] [63311] [63312]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2153...
# Checking date: 2022-03-24 00:00:00
# Check indexing: [54408] [54744] [63168] [63335] [63336]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2154...
# Checking date: 2022-03-25 00:00:00
# Check indexing: [54432] [54768] [63192] [63359] [63360]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2155...
# Checking date: 2022-03-26 00:00:00
# Check indexing: [54456] [54792] [63216] [63383] [63384]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2156...
# Checking date: 2022-03-27 00:00:00
# Check indexing: [54480] [54816] [63240] [63407] [63408]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2157...
# Checking date: 2022-03-28 00:00:00
# Check indexing: [54504] [54840] [63264] [63431] [63432]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2158...
# Checking date: 2022-03-29 00:00:00
# Check indexing: [54528] [54864] [63288] [63455] [63456]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2159...
# Checking date: 2022-03-30 00:00:00
# Check indexing: [54552] [54888] [63312] [63479] [63480]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2160...
# Checking date: 2022-03-31 00:00:00
# Check indexing: [54576] [54912] [63336] [63503] [63504]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2161...
# Checking date: 2022-04-01 00:00:00
# Check indexing: [54600] [54936] [63360] [63527] [63528]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2162...
# Checking date: 2022-04-02 00:00:00
# Check indexing: [54624] [54960] [63384] [63551] [63552]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2163...
# Checking date: 2022-04-03 00:00:00
# Check indexing: [54648] [54984] [63408] [63575] [63576]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2164...
# Checking date: 2022-04-04 00:00:00
# Check indexing: [54672] [55008] [63432] [63599] [63600]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2165...
# Checking date: 2022-04-05 00:00:00
# Check indexing: [54696] [55032] [63456] [63623] [63624]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2166...
# Checking date: 2022-04-06 00:00:00
# Check indexing: [54720] [55056] [63480] [63647] [63648]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2167...
# Checking date: 2022-04-07 00:00:00
# Check indexing: [54744] [55080] [63504] [63671] [63672]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2168...
# Checking date: 2022-04-08 00:00:00
# Check indexing: [54768] [55104] [63528] [63695] [63696]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2169...
# Checking date: 2022-04-09 00:00:00
# Check indexing: [54792] [55128] [63552] [63719] [63720]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2170...
# Checking date: 2022-04-10 00:00:00
# Check indexing: [54816] [55152] [63576] [63743] [63744]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2171...
# Checking date: 2022-04-11 00:00:00
# Check indexing: [54840] [55176] [63600] [63767] [63768]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2172...
# Checking date: 2022-04-12 00:00:00
# Check indexing: [54864] [55200] [63624] [63791] [63792]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2173...
# Checking date: 2022-04-13 00:00:00
# Check indexing: [54888] [55224] [63648] [63815] [63816]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2174...
# Checking date: 2022-04-14 00:00:00
# Check indexing: [54912] [55248] [63672] [63839] [63840]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2175...
# Checking date: 2022-04-15 00:00:00
# Check indexing: [54936] [55272] [63696] [63863] [63864]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2176...
# Checking date: 2022-04-16 00:00:00
# Check indexing: [54960] [55296] [63720] [63887] [63888]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2177...
# Checking date: 2022-04-17 00:00:00
# Check indexing: [54984] [55320] [63744] [63911] [63912]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2178...
# Checking date: 2022-04-18 00:00:00
# Check indexing: [55008] [55344] [63768] [63935] [63936]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2179...
# Checking date: 2022-04-19 00:00:00
# Check indexing: [55032] [55368] [63792] [63959] [63960]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2180...
# Checking date: 2022-04-20 00:00:00
# Check indexing: [55056] [55392] [63816] [63983] [63984]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2181...
# Checking date: 2022-04-21 00:00:00
# Check indexing: [55080] [55416] [63840] [64007] [64008]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2182...
# Checking date: 2022-04-22 00:00:00
# Check indexing: [55104] [55440] [63864] [64031] [64032]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2183...
# Checking date: 2022-04-23 00:00:00
# Check indexing: [55128] [55464] [63888] [64055] [64056]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2184...
# Checking date: 2022-04-24 00:00:00
# Check indexing: [55152] [55488] [63912] [64079] [64080]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2185...
# Checking date: 2022-04-25 00:00:00
# Check indexing: [55176] [55512] [63936] [64103] [64104]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2186...
# Checking date: 2022-04-26 00:00:00
# Check indexing: [55200] [55536] [63960] [64127] [64128]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2187...
# Checking date: 2022-04-27 00:00:00
# Check indexing: [55224] [55560] [63984] [64151] [64152]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2188...
# Checking date: 2022-04-28 00:00:00
# Check indexing: [55248] [55584] [64008] [64175] [64176]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2189...
# Checking date: 2022-04-29 00:00:00
# Check indexing: [55272] [55608] [64032] [64199] [64200]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2190...
# Checking date: 2022-04-30 00:00:00
# Check indexing: [55296] [55632] [64056] [64223] [64224]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2191...
# Checking date: 2022-05-01 00:00:00
# Check indexing: [55320] [55656] [64080] [64247] [64248]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2192...
# Checking date: 2022-05-02 00:00:00
# Check indexing: [55344] [55680] [64104] [64271] [64272]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2193...
# Checking date: 2022-05-03 00:00:00
# Check indexing: [55368] [55704] [64128] [64295] [64296]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2194...
# Checking date: 2022-05-04 00:00:00
# Check indexing: [55392] [55728] [64152] [64319] [64320]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2195...
# Checking date: 2022-05-05 00:00:00
# Check indexing: [55416] [55752] [64176] [64343] [64344]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2196...
# Checking date: 2022-05-06 00:00:00
# Check indexing: [55440] [55776] [64200] [64367] [64368]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2197...
# Checking date: 2022-05-07 00:00:00
# Check indexing: [55464] [55800] [64224] [64391] [64392]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2198...
# Checking date: 2022-05-08 00:00:00
# Check indexing: [55488] [55824] [64248] [64415] [64416]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2199...
# Checking date: 2022-05-09 00:00:00
# Check indexing: [55512] [55848] [64272] [64439] [64440]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2200...
# Checking date: 2022-05-10 00:00:00
# Check indexing: [55536] [55872] [64296] [64463] [64464]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2201...
# Checking date: 2022-05-11 00:00:00
# Check indexing: [55560] [55896] [64320] [64487] [64488]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2202...
# Checking date: 2022-05-12 00:00:00
# Check indexing: [55584] [55920] [64344] [64511] [64512]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2203...
# Checking date: 2022-05-13 00:00:00
# Check indexing: [55608] [55944] [64368] [64535] [64536]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2204...
# Checking date: 2022-05-14 00:00:00
# Check indexing: [55632] [55968] [64392] [64559] [64560]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2205...
# Checking date: 2022-05-15 00:00:00
# Check indexing: [55656] [55992] [64416] [64583] [64584]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2206...
# Checking date: 2022-05-16 00:00:00
# Check indexing: [55680] [56016] [64440] [64607] [64608]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2207...
# Checking date: 2022-05-17 00:00:00
# Check indexing: [55704] [56040] [64464] [64631] [64632]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2208...
# Checking date: 2022-05-18 00:00:00
# Check indexing: [55728] [56064] [64488] [64655] [64656]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2209...
# Checking date: 2022-05-19 00:00:00
# Check indexing: [55752] [56088] [64512] [64679] [64680]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2210...
# Checking date: 2022-05-20 00:00:00
# Check indexing: [55776] [56112] [64536] [64703] [64704]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2211...
# Checking date: 2022-05-21 00:00:00
# Check indexing: [55800] [56136] [64560] [64727] [64728]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2212...
# Checking date: 2022-05-22 00:00:00
# Check indexing: [55824] [56160] [64584] [64751] [64752]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2213...
# Checking date: 2022-05-23 00:00:00
# Check indexing: [55848] [56184] [64608] [64775] [64776]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2214...
# Checking date: 2022-05-24 00:00:00
# Check indexing: [55872] [56208] [64632] [64799] [64800]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2215...
# Checking date: 2022-05-25 00:00:00
# Check indexing: [55896] [56232] [64656] [64823] [64824]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2216...
# Checking date: 2022-05-26 00:00:00
# Check indexing: [55920] [56256] [64680] [64847] [64848]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2217...
# Checking date: 2022-05-27 00:00:00
# Check indexing: [55944] [56280] [64704] [64871] [64872]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2218...
# Checking date: 2022-05-28 00:00:00
# Check indexing: [55968] [56304] [64728] [64895] [64896]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2219...
# Checking date: 2022-05-29 00:00:00
# Check indexing: [55992] [56328] [64752] [64919] [64920]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2220...
# Checking date: 2022-05-30 00:00:00
# Check indexing: [56016] [56352] [64776] [64943] [64944]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2221...
# Checking date: 2022-05-31 00:00:00
# Check indexing: [56040] [56376] [64800] [64967] [64968]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2222...
# Checking date: 2022-06-01 00:00:00
# Check indexing: [56064] [56400] [64824] [64991] [64992]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2223...
# Checking date: 2022-06-02 00:00:00
# Check indexing: [56088] [56424] [64848] [65015] [65016]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2224...
# Checking date: 2022-06-03 00:00:00
# Check indexing: [56112] [56448] [64872] [65039] [65040]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2225...
# Checking date: 2022-06-04 00:00:00
# Check indexing: [56136] [56472] [64896] [65063] [65064]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2226...
# Checking date: 2022-06-05 00:00:00
# Check indexing: [56160] [56496] [64920] [65087] [65088]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2227...
# Checking date: 2022-06-06 00:00:00
# Check indexing: [56184] [56520] [64944] [65111] [65112]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2228...
# Checking date: 2022-06-07 00:00:00
# Check indexing: [56208] [56544] [64968] [65135] [65136]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2229...
# Checking date: 2022-06-08 00:00:00
# Check indexing: [56232] [56568] [64992] [65159] [65160]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2230...
# Checking date: 2022-06-09 00:00:00
# Check indexing: [56256] [56592] [65016] [65183] [65184]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2231...
# Checking date: 2022-06-10 00:00:00
# Check indexing: [56280] [56616] [65040] [65207] [65208]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2232...
# Checking date: 2022-06-11 00:00:00
# Check indexing: [56304] [56640] [65064] [65231] [65232]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2233...
# Checking date: 2022-06-12 00:00:00
# Check indexing: [56328] [56664] [65088] [65255] [65256]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2234...
# Checking date: 2022-06-13 00:00:00
# Check indexing: [56352] [56688] [65112] [65279] [65280]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2235...
# Checking date: 2022-06-14 00:00:00
# Check indexing: [56376] [56712] [65136] [65303] [65304]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2236...
# Checking date: 2022-06-15 00:00:00
# Check indexing: [56400] [56736] [65160] [65327] [65328]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2237...
# Checking date: 2022-06-16 00:00:00
# Check indexing: [56424] [56760] [65184] [65351] [65352]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2238...
# Checking date: 2022-06-17 00:00:00
# Check indexing: [56448] [56784] [65208] [65375] [65376]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2239...
# Checking date: 2022-06-18 00:00:00
# Check indexing: [56472] [56808] [65232] [65399] [65400]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2240...
# Checking date: 2022-06-19 00:00:00
# Check indexing: [56496] [56832] [65256] [65423] [65424]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2241...
# Checking date: 2022-06-20 00:00:00
# Check indexing: [56520] [56856] [65280] [65447] [65448]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2242...
# Checking date: 2022-06-21 00:00:00
# Check indexing: [56544] [56880] [65304] [65471] [65472]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2243...
# Checking date: 2022-06-22 00:00:00
# Check indexing: [56568] [56904] [65328] [65495] [65496]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2244...
# Checking date: 2022-06-23 00:00:00
# Check indexing: [56592] [56928] [65352] [65519] [65520]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2245...
# Checking date: 2022-06-24 00:00:00
# Check indexing: [56616] [56952] [65376] [65543] [65544]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2246...
# Checking date: 2022-06-25 00:00:00
# Check indexing: [56640] [56976] [65400] [65567] [65568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2247...
# Checking date: 2022-06-26 00:00:00
# Check indexing: [56664] [57000] [65424] [65591] [65592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2248...
# Checking date: 2022-06-27 00:00:00
# Check indexing: [56688] [57024] [65448] [65615] [65616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2249...
# Checking date: 2022-06-28 00:00:00
# Check indexing: [56712] [57048] [65472] [65639] [65640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2250...
# Checking date: 2022-06-29 00:00:00
# Check indexing: [56736] [57072] [65496] [65663] [65664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2251...
# Checking date: 2022-06-30 00:00:00
# Check indexing: [56760] [57096] [65520] [65687] [65688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2252...
# Checking date: 2022-07-01 00:00:00
# Check indexing: [56784] [57120] [65544] [65711] [65712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2253...
# Checking date: 2022-07-02 00:00:00
# ...
# ----------------------------------
# Get 2624...
# Checking date: 2023-07-08 00:00:00
# Check indexing: [65712] [66048] [74472] [74639] [74640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2625...
# Checking date: 2023-07-09 00:00:00
# Check indexing: [65736] [66072] [74496] [74663] [74664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2626...
# Checking date: 2023-07-10 00:00:00
# Check indexing: [65760] [66096] [74520] [74687] [74688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2627...
# Checking date: 2023-07-11 00:00:00
# Check indexing: [65784] [66120] [74544] [74711] [74712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2628...
# Checking date: 2023-07-12 00:00:00
# Check indexing: [65808] [66144] [74568] [74735] [74736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2629...
# Checking date: 2023-07-13 00:00:00
# Check indexing: [65832] [66168] [74592] [74759] [74760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2630...
# Checking date: 2023-07-14 00:00:00
# Check indexing: [65856] [66192] [74616] [74783] [74784]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2631...
# Checking date: 2023-07-15 00:00:00
# Check indexing: [65880] [66216] [74640] [74807] [74808]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2632...
# Checking date: 2023-07-16 00:00:00
# Check indexing: [65904] [66240] [74664] [74831] [74832]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2633...
# Checking date: 2023-07-17 00:00:00
# Check indexing: [65928] [66264] [74688] [74855] [74856]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2634...
# Checking date: 2023-07-18 00:00:00
# Check indexing: [65952] [66288] [74712] [74879] [74880]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2635...
# Checking date: 2023-07-19 00:00:00
# Check indexing: [65976] [66312] [74736] [74903] [74904]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2636...
# Checking date: 2023-07-20 00:00:00
# Check indexing: [66000] [66336] [74760] [74927] [74928]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2637...
# Checking date: 2023-07-21 00:00:00
# Check indexing: [66024] [66360] [74784] [74951] [74952]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2638...
# Checking date: 2023-07-22 00:00:00
# Check indexing: [66048] [66384] [74808] [74975] [74976]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2639...
# Checking date: 2023-07-23 00:00:00
# Check indexing: [66072] [66408] [74832] [74999] [75000]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2640...
# Checking date: 2023-07-24 00:00:00
# Check indexing: [66096] [66432] [74856] [75023] [75024]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2641...
# Checking date: 2023-07-25 00:00:00
# Check indexing: [66120] [66456] [74880] [75047] [75048]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2642...
# Checking date: 2023-07-26 00:00:00
# Check indexing: [66144] [66480] [74904] [75071] [75072]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2643...
# Checking date: 2023-07-27 00:00:00
# Check indexing: [66168] [66504] [74928] [75095] [75096]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2644...
# Checking date: 2023-07-28 00:00:00
# Check indexing: [66192] [66528] [74952] [75119] [75120]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2645...
# Checking date: 2023-07-29 00:00:00
# Check indexing: [66216] [66552] [74976] [75143] [75144]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2646...
# Checking date: 2023-07-30 00:00:00
# Check indexing: [66240] [66576] [75000] [75167] [75168]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2647...
# Checking date: 2023-07-31 00:00:00
# Check indexing: [66264] [66600] [75024] [75191] [75192]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2648...
# Checking date: 2023-08-01 00:00:00
# Check indexing: [66288] [66624] [75048] [75215] [75216]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2649...
# Checking date: 2023-08-02 00:00:00
# Check indexing: [66312] [66648] [75072] [75239] [75240]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2650...
# Checking date: 2023-08-03 00:00:00
# Check indexing: [66336] [66672] [75096] [75263] [75264]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2651...
# Checking date: 2023-08-04 00:00:00
# Check indexing: [66360] [66696] [75120] [75287] [75288]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2652...
# Checking date: 2023-08-05 00:00:00
# Check indexing: [66384] [66720] [75144] [75311] [75312]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2653...
# Checking date: 2023-08-06 00:00:00
# Check indexing: [66408] [66744] [75168] [75335] [75336]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2654...
# Checking date: 2023-08-07 00:00:00
# Check indexing: [66432] [66768] [75192] [75359] [75360]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2655...
# Checking date: 2023-08-08 00:00:00
# Check indexing: [66456] [66792] [75216] [75383] [75384]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2656...
# Checking date: 2023-08-09 00:00:00
# Check indexing: [66480] [66816] [75240] [75407] [75408]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2657...
# Checking date: 2023-08-10 00:00:00
# Check indexing: [66504] [66840] [75264] [75431] [75432]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2658...
# Checking date: 2023-08-11 00:00:00
# Check indexing: [66528] [66864] [75288] [75455] [75456]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2659...
# Checking date: 2023-08-12 00:00:00
# Check indexing: [66552] [66888] [75312] [75479] [75480]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2660...
# Checking date: 2023-08-13 00:00:00
# Check indexing: [66576] [66912] [75336] [75503] [75504]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2661...
# Checking date: 2023-08-14 00:00:00
# Check indexing: [66600] [66936] [75360] [75527] [75528]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2662...
# Checking date: 2023-08-15 00:00:00
# Check indexing: [66624] [66960] [75384] [75551] [75552]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2663...
# Checking date: 2023-08-16 00:00:00
# Check indexing: [66648] [66984] [75408] [75575] [75576]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2664...
# Checking date: 2023-08-17 00:00:00
# Check indexing: [66672] [67008] [75432] [75599] [75600]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2665...
# Checking date: 2023-08-18 00:00:00
# Check indexing: [66696] [67032] [75456] [75623] [75624]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2666...
# Checking date: 2023-08-19 00:00:00
# Check indexing: [66720] [67056] [75480] [75647] [75648]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2667...
# Checking date: 2023-08-20 00:00:00
# Check indexing: [66744] [67080] [75504] [75671] [75672]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2668...
# Checking date: 2023-08-21 00:00:00
# Check indexing: [66768] [67104] [75528] [75695] [75696]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2669...
# Checking date: 2023-08-22 00:00:00
# Check indexing: [66792] [67128] [75552] [75719] [75720]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2670...
# Checking date: 2023-08-23 00:00:00
# Check indexing: [66816] [67152] [75576] [75743] [75744]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2671...
# Checking date: 2023-08-24 00:00:00
# Check indexing: [66840] [67176] [75600] [75767] [75768]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2672...
# Checking date: 2023-08-25 00:00:00
# Check indexing: [66864] [67200] [75624] [75791] [75792]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2673...
# Checking date: 2023-08-26 00:00:00
# Check indexing: [66888] [67224] [75648] [75815] [75816]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2674...
# Checking date: 2023-08-27 00:00:00
# Check indexing: [66912] [67248] [75672] [75839] [75840]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2675...
# Checking date: 2023-08-28 00:00:00
# Check indexing: [66936] [67272] [75696] [75863] [75864]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2676...
# Checking date: 2023-08-29 00:00:00
# Check indexing: [66960] [67296] [75720] [75887] [75888]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2677...
# Checking date: 2023-08-30 00:00:00
# Check indexing: [66984] [67320] [75744] [75911] [75912]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2678...
# Checking date: 2023-08-31 00:00:00
# Check indexing: [67008] [67344] [75768] [75935] [75936]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2679...
# Checking date: 2023-09-01 00:00:00
# Check indexing: [67032] [67368] [75792] [75959] [75960]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2680...
# Checking date: 2023-09-02 00:00:00
# Check indexing: [67056] [67392] [75816] [75983] [75984]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2681...
# Checking date: 2023-09-03 00:00:00
# Check indexing: [67080] [67416] [75840] [76007] [76008]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2682...
# Checking date: 2023-09-04 00:00:00
# Check indexing: [67104] [67440] [75864] [76031] [76032]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2683...
# Checking date: 2023-09-05 00:00:00
# Check indexing: [67128] [67464] [75888] [76055] [76056]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2684...
# Checking date: 2023-09-06 00:00:00
# Check indexing: [67152] [67488] [75912] [76079] [76080]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2685...
# Checking date: 2023-09-07 00:00:00
# Check indexing: [67176] [67512] [75936] [76103] [76104]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2686...
# Checking date: 2023-09-08 00:00:00
# Check indexing: [67200] [67536] [75960] [76127] [76128]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2687...
# Checking date: 2023-09-09 00:00:00
# Check indexing: [67224] [67560] [75984] [76151] [76152]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2688...
# Checking date: 2023-09-10 00:00:00
# Check indexing: [67248] [67584] [76008] [76175] [76176]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2689...
# Checking date: 2023-09-11 00:00:00
# Check indexing: [67272] [67608] [76032] [76199] [76200]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2690...
# Checking date: 2023-09-12 00:00:00
# Check indexing: [67296] [67632] [76056] [76223] [76224]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2691...
# Checking date: 2023-09-13 00:00:00
# Check indexing: [67320] [67656] [76080] [76247] [76248]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2692...
# Checking date: 2023-09-14 00:00:00
# Check indexing: [67344] [67680] [76104] [76271] [76272]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2693...
# Checking date: 2023-09-15 00:00:00
# Check indexing: [67368] [67704] [76128] [76295] [76296]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2694...
# Checking date: 2023-09-16 00:00:00
# Check indexing: [67392] [67728] [76152] [76319] [76320]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2695...
# Checking date: 2023-09-17 00:00:00
# Check indexing: [67416] [67752] [76176] [76343] [76344]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2696...
# Checking date: 2023-09-18 00:00:00
# Check indexing: [67440] [67776] [76200] [76367] [76368]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2697...
# Checking date: 2023-09-19 00:00:00
# Check indexing: [67464] [67800] [76224] [76391] [76392]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2698...
# Checking date: 2023-09-20 00:00:00
# Check indexing: [67488] [67824] [76248] [76415] [76416]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2699...
# Checking date: 2023-09-21 00:00:00
# Check indexing: [67512] [67848] [76272] [76439] [76440]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2700...
# Checking date: 2023-09-22 00:00:00
# Check indexing: [67536] [67872] [76296] [76463] [76464]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2701...
# Checking date: 2023-09-23 00:00:00
# Check indexing: [67560] [67896] [76320] [76487] [76488]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2702...
# Checking date: 2023-09-24 00:00:00
# Check indexing: [67584] [67920] [76344] [76511] [76512]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2703...
# Checking date: 2023-09-25 00:00:00
# Check indexing: [67608] [67944] [76368] [76535] [76536]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2704...
# Checking date: 2023-09-26 00:00:00
# Check indexing: [67632] [67968] [76392] [76559] [76560]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2705...
# Checking date: 2023-09-27 00:00:00
# Check indexing: [67656] [67992] [76416] [76583] [76584]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2706...
# Checking date: 2023-09-28 00:00:00
# Check indexing: [67680] [68016] [76440] [76607] [76608]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2707...
# Checking date: 2023-09-29 00:00:00
# Check indexing: [67704] [68040] [76464] [76631] [76632]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2708...
# Checking date: 2023-09-30 00:00:00
# Check indexing: [67728] [68064] [76488] [76655] [76656]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2709...
# Checking date: 2023-10-01 00:00:00
# Check indexing: [67752] [68088] [76512] [76679] [76680]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!

# %%
scaler.fit_transform(x_rain)
uniq_rain, count_rain = np.unique(y_rain, return_counts=True)
print(dict(zip(uniq_rain, count_rain)))
# Out:
# {0: 2527, 1: 183}

# %%
rain_model = SVC()
rain_model.fit(x_train_rain, y_train_rain)
y_pred_rain = rain_model.predict(x_test_rain)
print(accuracy_score(y_test_rain, y_pred_rain))
print(f1_score(y_test_rain, y_pred_rain))
# Out:
# 0.9391143911439115
# 0.0

# %%
confusion_matrix(y_test_rain, y_pred_rain)
# Out:
# array([[509,   0],
#        [ 33,   0]])

# %%
x_cloud, y_cloud = get_train_test_data('2016-05-01 00:00:00', '2023-10-01 23:00:00', columns_cloud, target_cloud)
x_cloud = np.array(x_cloud)
y_cloud = np.array(y_cloud).astype('int').reshape(-1,)
x_train_cloud, x_test_cloud, y_train_cloud, y_test_cloud = train_test_split(x_cloud, y_cloud, test_size=0.2, random_state=0)
# Out:
# Streaming output truncated to the last 5000 lines.
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1996...
# Checking date: 2021-10-18 00:00:00
# Check indexing: [50640] [50976] [59400] [59567] [59568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1997...
# Checking date: 2021-10-19 00:00:00
# Check indexing: [50664] [51000] [59424] [59591] [59592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1998...
# Checking date: 2021-10-20 00:00:00
# Check indexing: [50688] [51024] [59448] [59615] [59616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1999...
# Checking date: 2021-10-21 00:00:00
# Check indexing: [50712] [51048] [59472] [59639] [59640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2000...
# Checking date: 2021-10-22 00:00:00
# Check indexing: [50736] [51072] [59496] [59663] [59664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2001...
# Checking date: 2021-10-23 00:00:00
# Check indexing: [50760] [51096] [59520] [59687] [59688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2002...
# Checking date: 2021-10-24 00:00:00
# Check indexing: [50784] [51120] [59544] [59711] [59712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2003...
# Checking date: 2021-10-25 00:00:00
# Check indexing: [50808] [51144] [59568] [59735] [59736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2004...
# Checking date: 2021-10-26 00:00:00
# Check indexing: [50832] [51168] [59592] [59759] [59760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2005...
# Checking date: 2021-10-27 00:00:00
# Check indexing: [50856] [51192] [59616] [59783] [59784]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2006...
# Checking date: 2021-10-28 00:00:00
# Check indexing: [50880] [51216] [59640] [59807] [59808]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2007...
# Checking date: 2021-10-29 00:00:00
# Check indexing: [50904] [51240] [59664] [59831] [59832]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2008...
# Checking date: 2021-10-30 00:00:00
# Check indexing: [50928] [51264] [59688] [59855] [59856]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2009...
# Checking date: 2021-10-31 00:00:00
# Check indexing: [50952] [51288] [59712] [59879] [59880]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2010...
# Checking date: 2021-11-01 00:00:00
# Check indexing: [50976] [51312] [59736] [59903] [59904]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2011...
# Checking date: 2021-11-02 00:00:00
# Check indexing: [51000] [51336] [59760] [59927] [59928]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2012...
# Checking date: 2021-11-03 00:00:00
# Check indexing: [51024] [51360] [59784] [59951] [59952]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2013...
# Checking date: 2021-11-04 00:00:00
# Check indexing: [51048] [51384] [59808] [59975] [59976]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2014...
# Checking date: 2021-11-05 00:00:00
# Check indexing: [51072] [51408] [59832] [59999] [60000]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2015...
# Checking date: 2021-11-06 00:00:00
# Check indexing: [51096] [51432] [59856] [60023] [60024]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2016...
# Checking date: 2021-11-07 00:00:00
# Check indexing: [51120] [51456] [59880] [60047] [60048]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2017...
# Checking date: 2021-11-08 00:00:00
# Check indexing: [51144] [51480] [59904] [60071] [60072]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2018...
# Checking date: 2021-11-09 00:00:00
# Check indexing: [51168] [51504] [59928] [60095] [60096]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2019...
# Checking date: 2021-11-10 00:00:00
# Check indexing: [51192] [51528] [59952] [60119] [60120]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2020...
# Checking date: 2021-11-11 00:00:00
# Check indexing: [51216] [51552] [59976] [60143] [60144]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2021...
# Checking date: 2021-11-12 00:00:00
# Check indexing: [51240] [51576] [60000] [60167] [60168]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2022...
# Checking date: 2021-11-13 00:00:00
# Check indexing: [51264] [51600] [60024] [60191] [60192]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2023...
# Checking date: 2021-11-14 00:00:00
# Check indexing: [51288] [51624] [60048] [60215] [60216]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2024...
# Checking date: 2021-11-15 00:00:00
# Check indexing: [51312] [51648] [60072] [60239] [60240]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2025...
# Checking date: 2021-11-16 00:00:00
# Check indexing: [51336] [51672] [60096] [60263] [60264]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2026...
# Checking date: 2021-11-17 00:00:00
# Check indexing: [51360] [51696] [60120] [60287] [60288]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2027...
# Checking date: 2021-11-18 00:00:00
# Check indexing: [51384] [51720] [60144] [60311] [60312]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2028...
# Checking date: 2021-11-19 00:00:00
# Check indexing: [51408] [51744] [60168] [60335] [60336]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2029...
# Checking date: 2021-11-20 00:00:00
# Check indexing: [51432] [51768] [60192] [60359] [60360]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2030...
# Checking date: 2021-11-21 00:00:00
# Check indexing: [51456] [51792] [60216] [60383] [60384]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2031...
# Checking date: 2021-11-22 00:00:00
# Check indexing: [51480] [51816] [60240] [60407] [60408]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2032...
# Checking date: 2021-11-23 00:00:00
# Check indexing: [51504] [51840] [60264] [60431] [60432]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2033...
# Checking date: 2021-11-24 00:00:00
# Check indexing: [51528] [51864] [60288] [60455] [60456]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2034...
# Checking date: 2021-11-25 00:00:00
# Check indexing: [51552] [51888] [60312] [60479] [60480]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2035...
# Checking date: 2021-11-26 00:00:00
# Check indexing: [51576] [51912] [60336] [60503] [60504]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2036...
# Checking date: 2021-11-27 00:00:00
# Check indexing: [51600] [51936] [60360] [60527] [60528]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2037...
# Checking date: 2021-11-28 00:00:00
# Check indexing: [51624] [51960] [60384] [60551] [60552]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2038...
# Checking date: 2021-11-29 00:00:00
# Check indexing: [51648] [51984] [60408] [60575] [60576]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2039...
# Checking date: 2021-11-30 00:00:00
# Check indexing: [51672] [52008] [60432] [60599] [60600]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2040...
# Checking date: 2021-12-01 00:00:00
# Check indexing: [51696] [52032] [60456] [60623] [60624]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2041...
# Checking date: 2021-12-02 00:00:00
# Check indexing: [51720] [52056] [60480] [60647] [60648]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2042...
# Checking date: 2021-12-03 00:00:00
# Check indexing: [51744] [52080] [60504] [60671] [60672]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2043...
# Checking date: 2021-12-04 00:00:00
# Check indexing: [51768] [52104] [60528] [60695] [60696]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2044...
# Checking date: 2021-12-05 00:00:00
# Check indexing: [51792] [52128] [60552] [60719] [60720]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2045...
# Checking date: 2021-12-06 00:00:00
# Check indexing: [51816] [52152] [60576] [60743] [60744]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2046...
# Checking date: 2021-12-07 00:00:00
# Check indexing: [51840] [52176] [60600] [60767] [60768]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2047...
# Checking date: 2021-12-08 00:00:00
# Check indexing: [51864] [52200] [60624] [60791] [60792]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2048...
# Checking date: 2021-12-09 00:00:00
# Check indexing: [51888] [52224] [60648] [60815] [60816]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2049...
# Checking date: 2021-12-10 00:00:00
# Check indexing: [51912] [52248] [60672] [60839] [60840]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2050...
# Checking date: 2021-12-11 00:00:00
# Check indexing: [51936] [52272] [60696] [60863] [60864]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2051...
# Checking date: 2021-12-12 00:00:00
# Check indexing: [51960] [52296] [60720] [60887] [60888]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2052...
# Checking date: 2021-12-13 00:00:00
# Check indexing: [51984] [52320] [60744] [60911] [60912]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2053...
# Checking date: 2021-12-14 00:00:00
# Check indexing: [52008] [52344] [60768] [60935] [60936]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2054...
# Checking date: 2021-12-15 00:00:00
# Check indexing: [52032] [52368] [60792] [60959] [60960]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2055...
# Checking date: 2021-12-16 00:00:00
# Check indexing: [52056] [52392] [60816] [60983] [60984]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2056...
# Checking date: 2021-12-17 00:00:00
# Check indexing: [52080] [52416] [60840] [61007] [61008]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2057...
# Checking date: 2021-12-18 00:00:00
# Check indexing: [52104] [52440] [60864] [61031] [61032]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2058...
# Checking date: 2021-12-19 00:00:00
# Check indexing: [52128] [52464] [60888] [61055] [61056]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2059...
# Checking date: 2021-12-20 00:00:00
# Check indexing: [52152] [52488] [60912] [61079] [61080]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2060...
# Checking date: 2021-12-21 00:00:00
# Check indexing: [52176] [52512] [60936] [61103] [61104]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2061...
# Checking date: 2021-12-22 00:00:00
# Check indexing: [52200] [52536] [60960] [61127] [61128]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2062...
# Checking date: 2021-12-23 00:00:00
# Check indexing: [52224] [52560] [60984] [61151] [61152]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2063...
# Checking date: 2021-12-24 00:00:00
# Check indexing: [52248] [52584] [61008] [61175] [61176]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2064...
# Checking date: 2021-12-25 00:00:00
# Check indexing: [52272] [52608] [61032] [61199] [61200]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2065...
# Checking date: 2021-12-26 00:00:00
# Check indexing: [52296] [52632] [61056] [61223] [61224]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2066...
# Checking date: 2021-12-27 00:00:00
# Check indexing: [52320] [52656] [61080] [61247] [61248]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2067...
# Checking date: 2021-12-28 00:00:00
# Check indexing: [52344] [52680] [61104] [61271] [61272]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2068...
# Checking date: 2021-12-29 00:00:00
# Check indexing: [52368] [52704] [61128] [61295] [61296]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2069...
# Checking date: 2021-12-30 00:00:00
# Check indexing: [52392] [52728] [61152] [61319] [61320]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2070...
# Checking date: 2021-12-31 00:00:00
# Check indexing: [52416] [52752] [61176] [61343] [61344]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2071...
# Checking date: 2022-01-01 00:00:00
# Check indexing: [52440] [52776] [61200] [61367] [61368]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2072...
# Checking date: 2022-01-02 00:00:00
# Check indexing: [52464] [52800] [61224] [61391] [61392]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2073...
# Checking date: 2022-01-03 00:00:00
# Check indexing: [52488] [52824] [61248] [61415] [61416]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2074...
# Checking date: 2022-01-04 00:00:00
# Check indexing: [52512] [52848] [61272] [61439] [61440]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2075...
# Checking date: 2022-01-05 00:00:00
# Check indexing: [52536] [52872] [61296] [61463] [61464]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2076...
# Checking date: 2022-01-06 00:00:00
# Check indexing: [52560] [52896] [61320] [61487] [61488]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2077...
# Checking date: 2022-01-07 00:00:00
# Check indexing: [52584] [52920] [61344] [61511] [61512]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2078...
# Checking date: 2022-01-08 00:00:00
# Check indexing: [52608] [52944] [61368] [61535] [61536]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2079...
# Checking date: 2022-01-09 00:00:00
# Check indexing: [52632] [52968] [61392] [61559] [61560]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2080...
# Checking date: 2022-01-10 00:00:00
# Check indexing: [52656] [52992] [61416] [61583] [61584]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2081...
# Checking date: 2022-01-11 00:00:00
# Check indexing: [52680] [53016] [61440] [61607] [61608]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2082...
# Checking date: 2022-01-12 00:00:00
# Check indexing: [52704] [53040] [61464] [61631] [61632]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2083...
# Checking date: 2022-01-13 00:00:00
# Check indexing: [52728] [53064] [61488] [61655] [61656]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2084...
# Checking date: 2022-01-14 00:00:00
# Check indexing: [52752] [53088] [61512] [61679] [61680]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2085...
# Checking date: 2022-01-15 00:00:00
# Check indexing: [52776] [53112] [61536] [61703] [61704]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2086...
# Checking date: 2022-01-16 00:00:00
# Check indexing: [52800] [53136] [61560] [61727] [61728]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2087...
# Checking date: 2022-01-17 00:00:00
# Check indexing: [52824] [53160] [61584] [61751] [61752]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2088...
# Checking date: 2022-01-18 00:00:00
# Check indexing: [52848] [53184] [61608] [61775] [61776]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2089...
# Checking date: 2022-01-19 00:00:00
# Check indexing: [52872] [53208] [61632] [61799] [61800]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2090...
# Checking date: 2022-01-20 00:00:00
# Check indexing: [52896] [53232] [61656] [61823] [61824]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2091...
# Checking date: 2022-01-21 00:00:00
# Check indexing: [52920] [53256] [61680] [61847] [61848]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2092...
# Checking date: 2022-01-22 00:00:00
# Check indexing: [52944] [53280] [61704] [61871] [61872]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2093...
# Checking date: 2022-01-23 00:00:00
# Check indexing: [52968] [53304] [61728] [61895] [61896]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2094...
# Checking date: 2022-01-24 00:00:00
# Check indexing: [52992] [53328] [61752] [61919] [61920]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2095...
# Checking date: 2022-01-25 00:00:00
# Check indexing: [53016] [53352] [61776] [61943] [61944]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2096...
# Checking date: 2022-01-26 00:00:00
# Check indexing: [53040] [53376] [61800] [61967] [61968]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2097...
# Checking date: 2022-01-27 00:00:00
# Check indexing: [53064] [53400] [61824] [61991] [61992]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2098...
# Checking date: 2022-01-28 00:00:00
# Check indexing: [53088] [53424] [61848] [62015] [62016]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2099...
# Checking date: 2022-01-29 00:00:00
# Check indexing: [53112] [53448] [61872] [62039] [62040]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2100...
# Checking date: 2022-01-30 00:00:00
# Check indexing: [53136] [53472] [61896] [62063] [62064]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2101...
# Checking date: 2022-01-31 00:00:00
# Check indexing: [53160] [53496] [61920] [62087] [62088]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2102...
# Checking date: 2022-02-01 00:00:00
# Check indexing: [53184] [53520] [61944] [62111] [62112]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2103...
# Checking date: 2022-02-02 00:00:00
# Check indexing: [53208] [53544] [61968] [62135] [62136]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2104...
# Checking date: 2022-02-03 00:00:00
# Check indexing: [53232] [53568] [61992] [62159] [62160]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2105...
# Checking date: 2022-02-04 00:00:00
# Check indexing: [53256] [53592] [62016] [62183] [62184]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2106...
# Checking date: 2022-02-05 00:00:00
# Check indexing: [53280] [53616] [62040] [62207] [62208]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2107...
# Checking date: 2022-02-06 00:00:00
# Check indexing: [53304] [53640] [62064] [62231] [62232]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2108...
# Checking date: 2022-02-07 00:00:00
# Check indexing: [53328] [53664] [62088] [62255] [62256]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2109...
# Checking date: 2022-02-08 00:00:00
# Check indexing: [53352] [53688] [62112] [62279] [62280]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2110...
# Checking date: 2022-02-09 00:00:00
# Check indexing: [53376] [53712] [62136] [62303] [62304]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2111...
# Checking date: 2022-02-10 00:00:00
# Check indexing: [53400] [53736] [62160] [62327] [62328]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2112...
# Checking date: 2022-02-11 00:00:00
# Check indexing: [53424] [53760] [62184] [62351] [62352]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2113...
# Checking date: 2022-02-12 00:00:00
# Check indexing: [53448] [53784] [62208] [62375] [62376]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2114...
# Checking date: 2022-02-13 00:00:00
# Check indexing: [53472] [53808] [62232] [62399] [62400]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2115...
# Checking date: 2022-02-14 00:00:00
# Check indexing: [53496] [53832] [62256] [62423] [62424]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2116...
# Checking date: 2022-02-15 00:00:00
# Check indexing: [53520] [53856] [62280] [62447] [62448]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2117...
# Checking date: 2022-02-16 00:00:00
# Check indexing: [53544] [53880] [62304] [62471] [62472]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2118...
# Checking date: 2022-02-17 00:00:00
# Check indexing: [53568] [53904] [62328] [62495] [62496]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2119...
# Checking date: 2022-02-18 00:00:00
# Check indexing: [53592] [53928] [62352] [62519] [62520]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2120...
# Checking date: 2022-02-19 00:00:00
# Check indexing: [53616] [53952] [62376] [62543] [62544]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2121...
# Checking date: 2022-02-20 00:00:00
# Check indexing: [53640] [53976] [62400] [62567] [62568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2122...
# Checking date: 2022-02-21 00:00:00
# Check indexing: [53664] [54000] [62424] [62591] [62592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2123...
# Checking date: 2022-02-22 00:00:00
# Check indexing: [53688] [54024] [62448] [62615] [62616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2124...
# Checking date: 2022-02-23 00:00:00
# Check indexing: [53712] [54048] [62472] [62639] [62640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2125...
# Checking date: 2022-02-24 00:00:00
# Check indexing: [53736] [54072] [62496] [62663] [62664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2126...
# Checking date: 2022-02-25 00:00:00
# Check indexing: [53760] [54096] [62520] [62687] [62688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2127...
# Checking date: 2022-02-26 00:00:00
# Check indexing: [53784] [54120] [62544] [62711] [62712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2128...
# Checking date: 2022-02-27 00:00:00
# Check indexing: [53808] [54144] [62568] [62735] [62736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2129...
# Checking date: 2022-02-28 00:00:00
# Check indexing: [53832] [54168] [62592] [62759] [62760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2130...
# Checking date: 2022-03-01 00:00:00
# Check indexing: [53856] [54192] [62616] [62783] [62784]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2131...
# Checking date: 2022-03-02 00:00:00
# Check indexing: [53880] [54216] [62640] [62807] [62808]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2132...
# Checking date: 2022-03-03 00:00:00
# Check indexing: [53904] [54240] [62664] [62831] [62832]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2133...
# Checking date: 2022-03-04 00:00:00
# Check indexing: [53928] [54264] [62688] [62855] [62856]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2134...
# Checking date: 2022-03-05 00:00:00
# Check indexing: [53952] [54288] [62712] [62879] [62880]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2135...
# Checking date: 2022-03-06 00:00:00
# Check indexing: [53976] [54312] [62736] [62903] [62904]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2136...
# Checking date: 2022-03-07 00:00:00
# Check indexing: [54000] [54336] [62760] [62927] [62928]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2137...
# Checking date: 2022-03-08 00:00:00
# Check indexing: [54024] [54360] [62784] [62951] [62952]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2138...
# Checking date: 2022-03-09 00:00:00
# Check indexing: [54048] [54384] [62808] [62975] [62976]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2139...
# Checking date: 2022-03-10 00:00:00
# Check indexing: [54072] [54408] [62832] [62999] [63000]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2140...
# Checking date: 2022-03-11 00:00:00
# Check indexing: [54096] [54432] [62856] [63023] [63024]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2141...
# Checking date: 2022-03-12 00:00:00
# Check indexing: [54120] [54456] [62880] [63047] [63048]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2142...
# Checking date: 2022-03-13 00:00:00
# Check indexing: [54144] [54480] [62904] [63071] [63072]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2143...
# Checking date: 2022-03-14 00:00:00
# Check indexing: [54168] [54504] [62928] [63095] [63096]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2144...
# Checking date: 2022-03-15 00:00:00
# Check indexing: [54192] [54528] [62952] [63119] [63120]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2145...
# Checking date: 2022-03-16 00:00:00
# Check indexing: [54216] [54552] [62976] [63143] [63144]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2146...
# Checking date: 2022-03-17 00:00:00
# Check indexing: [54240] [54576] [63000] [63167] [63168]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2147...
# Checking date: 2022-03-18 00:00:00
# Check indexing: [54264] [54600] [63024] [63191] [63192]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2148...
# Checking date: 2022-03-19 00:00:00
# Check indexing: [54288] [54624] [63048] [63215] [63216]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2149...
# Checking date: 2022-03-20 00:00:00
# Check indexing: [54312] [54648] [63072] [63239] [63240]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2150...
# Checking date: 2022-03-21 00:00:00
# Check indexing: [54336] [54672] [63096] [63263] [63264]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2151...
# Checking date: 2022-03-22 00:00:00
# Check indexing: [54360] [54696] [63120] [63287] [63288]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2152...
# Checking date: 2022-03-23 00:00:00
# Check indexing: [54384] [54720] [63144] [63311] [63312]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2153...
# Checking date: 2022-03-24 00:00:00
# Check indexing: [54408] [54744] [63168] [63335] [63336]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2154...
# Checking date: 2022-03-25 00:00:00
# Check indexing: [54432] [54768] [63192] [63359] [63360]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2155...
# Checking date: 2022-03-26 00:00:00
# Check indexing: [54456] [54792] [63216] [63383] [63384]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2156...
# Checking date: 2022-03-27 00:00:00
# Check indexing: [54480] [54816] [63240] [63407] [63408]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2157...
# Checking date: 2022-03-28 00:00:00
# Check indexing: [54504] [54840] [63264] [63431] [63432]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2158...
# Checking date: 2022-03-29 00:00:00
# Check indexing: [54528] [54864] [63288] [63455] [63456]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2159...
# Checking date: 2022-03-30 00:00:00
# Check indexing: [54552] [54888] [63312] [63479] [63480]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2160...
# Checking date: 2022-03-31 00:00:00
# Check indexing: [54576] [54912] [63336] [63503] [63504]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2161...
# Checking date: 2022-04-01 00:00:00
# Check indexing: [54600] [54936] [63360] [63527] [63528]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2162...
# Checking date: 2022-04-02 00:00:00
# Check indexing: [54624] [54960] [63384] [63551] [63552]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2163...
# Checking date: 2022-04-03 00:00:00
# Check indexing: [54648] [54984] [63408] [63575] [63576]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2164...
# Checking date: 2022-04-04 00:00:00
# Check indexing: [54672] [55008] [63432] [63599] [63600]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2165...
# Checking date: 2022-04-05 00:00:00
# Check indexing: [54696] [55032] [63456] [63623] [63624]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2166...
# Checking date: 2022-04-06 00:00:00
# Check indexing: [54720] [55056] [63480] [63647] [63648]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2167...
# Checking date: 2022-04-07 00:00:00
# Check indexing: [54744] [55080] [63504] [63671] [63672]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2168...
# Checking date: 2022-04-08 00:00:00
# Check indexing: [54768] [55104] [63528] [63695] [63696]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2169...
# Checking date: 2022-04-09 00:00:00
# Check indexing: [54792] [55128] [63552] [63719] [63720]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2170...
# Checking date: 2022-04-10 00:00:00
# Check indexing: [54816] [55152] [63576] [63743] [63744]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2171...
# Checking date: 2022-04-11 00:00:00
# Check indexing: [54840] [55176] [63600] [63767] [63768]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2172...
# Checking date: 2022-04-12 00:00:00
# Check indexing: [54864] [55200] [63624] [63791] [63792]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2173...
# Checking date: 2022-04-13 00:00:00
# Check indexing: [54888] [55224] [63648] [63815] [63816]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2174...
# Checking date: 2022-04-14 00:00:00
# Check indexing: [54912] [55248] [63672] [63839] [63840]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2175...
# Checking date: 2022-04-15 00:00:00
# Check indexing: [54936] [55272] [63696] [63863] [63864]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2176...
# Checking date: 2022-04-16 00:00:00
# Check indexing: [54960] [55296] [63720] [63887] [63888]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2177...
# Checking date: 2022-04-17 00:00:00
# Check indexing: [54984] [55320] [63744] [63911] [63912]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2178...
# Checking date: 2022-04-18 00:00:00
# Check indexing: [55008] [55344] [63768] [63935] [63936]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2179...
# Checking date: 2022-04-19 00:00:00
# Check indexing: [55032] [55368] [63792] [63959] [63960]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2180...
# Checking date: 2022-04-20 00:00:00
# Check indexing: [55056] [55392] [63816] [63983] [63984]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2181...
# Checking date: 2022-04-21 00:00:00
# Check indexing: [55080] [55416] [63840] [64007] [64008]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2182...
# Checking date: 2022-04-22 00:00:00
# Check indexing: [55104] [55440] [63864] [64031] [64032]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2183...
# Checking date: 2022-04-23 00:00:00
# Check indexing: [55128] [55464] [63888] [64055] [64056]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2184...
# Checking date: 2022-04-24 00:00:00
# Check indexing: [55152] [55488] [63912] [64079] [64080]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2185...
# Checking date: 2022-04-25 00:00:00
# Check indexing: [55176] [55512] [63936] [64103] [64104]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2186...
# Checking date: 2022-04-26 00:00:00
# Check indexing: [55200] [55536] [63960] [64127] [64128]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2187...
# Checking date: 2022-04-27 00:00:00
# Check indexing: [55224] [55560] [63984] [64151] [64152]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2188...
# Checking date: 2022-04-28 00:00:00
# Check indexing: [55248] [55584] [64008] [64175] [64176]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2189...
# Checking date: 2022-04-29 00:00:00
# Check indexing: [55272] [55608] [64032] [64199] [64200]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2190...
# Checking date: 2022-04-30 00:00:00
# Check indexing: [55296] [55632] [64056] [64223] [64224]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2191...
# Checking date: 2022-05-01 00:00:00
# Check indexing: [55320] [55656] [64080] [64247] [64248]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2192...
# Checking date: 2022-05-02 00:00:00
# Check indexing: [55344] [55680] [64104] [64271] [64272]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2193...
# Checking date: 2022-05-03 00:00:00
# Check indexing: [55368] [55704] [64128] [64295] [64296]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2194...
# Checking date: 2022-05-04 00:00:00
# Check indexing: [55392] [55728] [64152] [64319] [64320]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2195...
# Checking date: 2022-05-05 00:00:00
# Check indexing: [55416] [55752] [64176] [64343] [64344]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2196...
# Checking date: 2022-05-06 00:00:00
# Check indexing: [55440] [55776] [64200] [64367] [64368]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2197...
# Checking date: 2022-05-07 00:00:00
# Check indexing: [55464] [55800] [64224] [64391] [64392]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2198...
# Checking date: 2022-05-08 00:00:00
# Check indexing: [55488] [55824] [64248] [64415] [64416]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2199...
# Checking date: 2022-05-09 00:00:00
# Check indexing: [55512] [55848] [64272] [64439] [64440]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2200...
# Checking date: 2022-05-10 00:00:00
# Check indexing: [55536] [55872] [64296] [64463] [64464]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2201...
# Checking date: 2022-05-11 00:00:00
# Check indexing: [55560] [55896] [64320] [64487] [64488]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2202...
# Checking date: 2022-05-12 00:00:00
# Check indexing: [55584] [55920] [64344] [64511] [64512]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2203...
# Checking date: 2022-05-13 00:00:00
# Check indexing: [55608] [55944] [64368] [64535] [64536]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2204...
# Checking date: 2022-05-14 00:00:00
# Check indexing: [55632] [55968] [64392] [64559] [64560]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2205...
# Checking date: 2022-05-15 00:00:00
# Check indexing: [55656] [55992] [64416] [64583] [64584]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2206...
# Checking date: 2022-05-16 00:00:00
# Check indexing: [55680] [56016] [64440] [64607] [64608]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2207...
# Checking date: 2022-05-17 00:00:00
# Check indexing: [55704] [56040] [64464] [64631] [64632]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2208...
# Checking date: 2022-05-18 00:00:00
# Check indexing: [55728] [56064] [64488] [64655] [64656]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2209...
# Checking date: 2022-05-19 00:00:00
# Check indexing: [55752] [56088] [64512] [64679] [64680]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2210...
# Checking date: 2022-05-20 00:00:00
# Check indexing: [55776] [56112] [64536] [64703] [64704]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2211...
# Checking date: 2022-05-21 00:00:00
# Check indexing: [55800] [56136] [64560] [64727] [64728]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2212...
# Checking date: 2022-05-22 00:00:00
# Check indexing: [55824] [56160] [64584] [64751] [64752]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2213...
# Checking date: 2022-05-23 00:00:00
# Check indexing: [55848] [56184] [64608] [64775] [64776]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2214...
# Checking date: 2022-05-24 00:00:00
# Check indexing: [55872] [56208] [64632] [64799] [64800]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2215...
# Checking date: 2022-05-25 00:00:00
# Check indexing: [55896] [56232] [64656] [64823] [64824]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2216...
# Checking date: 2022-05-26 00:00:00
# Check indexing: [55920] [56256] [64680] [64847] [64848]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2217...
# Checking date: 2022-05-27 00:00:00
# Check indexing: [55944] [56280] [64704] [64871] [64872]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2218...
# Checking date: 2022-05-28 00:00:00
# Check indexing: [55968] [56304] [64728] [64895] [64896]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2219...
# Checking date: 2022-05-29 00:00:00
# Check indexing: [55992] [56328] [64752] [64919] [64920]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2220...
# Checking date: 2022-05-30 00:00:00
# Check indexing: [56016] [56352] [64776] [64943] [64944]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2221...
# Checking date: 2022-05-31 00:00:00
# Check indexing: [56040] [56376] [64800] [64967] [64968]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2222...
# Checking date: 2022-06-01 00:00:00
# Check indexing: [56064] [56400] [64824] [64991] [64992]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2223...
# Checking date: 2022-06-02 00:00:00
# Check indexing: [56088] [56424] [64848] [65015] [65016]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2224...
# Checking date: 2022-06-03 00:00:00
# Check indexing: [56112] [56448] [64872] [65039] [65040]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2225...
# Checking date: 2022-06-04 00:00:00
# Check indexing: [56136] [56472] [64896] [65063] [65064]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2226...
# Checking date: 2022-06-05 00:00:00
# Check indexing: [56160] [56496] [64920] [65087] [65088]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2227...
# Checking date: 2022-06-06 00:00:00
# Check indexing: [56184] [56520] [64944] [65111] [65112]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2228...
# Checking date: 2022-06-07 00:00:00
# Check indexing: [56208] [56544] [64968] [65135] [65136]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2229...
# Checking date: 2022-06-08 00:00:00
# Check indexing: [56232] [56568] [64992] [65159] [65160]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2230...
# Checking date: 2022-06-09 00:00:00
# Check indexing: [56256] [56592] [65016] [65183] [65184]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2231...
# Checking date: 2022-06-10 00:00:00
# Check indexing: [56280] [56616] [65040] [65207] [65208]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2232...
# Checking date: 2022-06-11 00:00:00
# Check indexing: [56304] [56640] [65064] [65231] [65232]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2233...
# Checking date: 2022-06-12 00:00:00
# Check indexing: [56328] [56664] [65088] [65255] [65256]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2234...
# Checking date: 2022-06-13 00:00:00
# Check indexing: [56352] [56688] [65112] [65279] [65280]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2235...
# Checking date: 2022-06-14 00:00:00
# Check indexing: [56376] [56712] [65136] [65303] [65304]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2236...
# Checking date: 2022-06-15 00:00:00
# Check indexing: [56400] [56736] [65160] [65327] [65328]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2237...
# Checking date: 2022-06-16 00:00:00
# Check indexing: [56424] [56760] [65184] [65351] [65352]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2238...
# Checking date: 2022-06-17 00:00:00
# Check indexing: [56448] [56784] [65208] [65375] [65376]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2239...
# Checking date: 2022-06-18 00:00:00
# Check indexing: [56472] [56808] [65232] [65399] [65400]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2240...
# Checking date: 2022-06-19 00:00:00
# Check indexing: [56496] [56832] [65256] [65423] [65424]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2241...
# Checking date: 2022-06-20 00:00:00
# Check indexing: [56520] [56856] [65280] [65447] [65448]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2242...
# Checking date: 2022-06-21 00:00:00
# Check indexing: [56544] [56880] [65304] [65471] [65472]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2243...
# Checking date: 2022-06-22 00:00:00
# Check indexing: [56568] [56904] [65328] [65495] [65496]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2244...
# Checking date: 2022-06-23 00:00:00
# Check indexing: [56592] [56928] [65352] [65519] [65520]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2245...
# Checking date: 2022-06-24 00:00:00
# Check indexing: [56616] [56952] [65376] [65543] [65544]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2246...
# Checking date: 2022-06-25 00:00:00
# Check indexing: [56640] [56976] [65400] [65567] [65568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2247...
# Checking date: 2022-06-26 00:00:00
# Check indexing: [56664] [57000] [65424] [65591] [65592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2248...
# Checking date: 2022-06-27 00:00:00
# Check indexing: [56688] [57024] [65448] [65615] [65616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2249...
# Checking date: 2022-06-28 00:00:00
# Check indexing: [56712] [57048] [65472] [65639] [65640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2250...
# Checking date: 2022-06-29 00:00:00
# Check indexing: [56736] [57072] [65496] [65663] [65664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2251...
# Checking date: 2022-06-30 00:00:00
# Check indexing: [56760] [57096] [65520] [65687] [65688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2252...
# Checking date: 2022-07-01 00:00:00
# Check indexing: [56784] [57120] [65544] [65711] [65712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2253...
# Checking date: 2022-07-02 00:00:00
# ...
# ----------------------------------
# Get 2624...
# Checking date: 2023-07-08 00:00:00
# Check indexing: [65712] [66048] [74472] [74639] [74640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2625...
# Checking date: 2023-07-09 00:00:00
# Check indexing: [65736] [66072] [74496] [74663] [74664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2626...
# Checking date: 2023-07-10 00:00:00
# Check indexing: [65760] [66096] [74520] [74687] [74688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2627...
# Checking date: 2023-07-11 00:00:00
# Check indexing: [65784] [66120] [74544] [74711] [74712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2628...
# Checking date: 2023-07-12 00:00:00
# Check indexing: [65808] [66144] [74568] [74735] [74736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2629...
# Checking date: 2023-07-13 00:00:00
# Check indexing: [65832] [66168] [74592] [74759] [74760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2630...
# Checking date: 2023-07-14 00:00:00
# Check indexing: [65856] [66192] [74616] [74783] [74784]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2631...
# Checking date: 2023-07-15 00:00:00
# Check indexing: [65880] [66216] [74640] [74807] [74808]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2632...
# Checking date: 2023-07-16 00:00:00
# Check indexing: [65904] [66240] [74664] [74831] [74832]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2633...
# Checking date: 2023-07-17 00:00:00
# Check indexing: [65928] [66264] [74688] [74855] [74856]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2634...
# Checking date: 2023-07-18 00:00:00
# Check indexing: [65952] [66288] [74712] [74879] [74880]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2635...
# Checking date: 2023-07-19 00:00:00
# Check indexing: [65976] [66312] [74736] [74903] [74904]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2636...
# Checking date: 2023-07-20 00:00:00
# Check indexing: [66000] [66336] [74760] [74927] [74928]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2637...
# Checking date: 2023-07-21 00:00:00
# Check indexing: [66024] [66360] [74784] [74951] [74952]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2638...
# Checking date: 2023-07-22 00:00:00
# Check indexing: [66048] [66384] [74808] [74975] [74976]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2639...
# Checking date: 2023-07-23 00:00:00
# Check indexing: [66072] [66408] [74832] [74999] [75000]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2640...
# Checking date: 2023-07-24 00:00:00
# Check indexing: [66096] [66432] [74856] [75023] [75024]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2641...
# Checking date: 2023-07-25 00:00:00
# Check indexing: [66120] [66456] [74880] [75047] [75048]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2642...
# Checking date: 2023-07-26 00:00:00
# Check indexing: [66144] [66480] [74904] [75071] [75072]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2643...
# Checking date: 2023-07-27 00:00:00
# Check indexing: [66168] [66504] [74928] [75095] [75096]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2644...
# Checking date: 2023-07-28 00:00:00
# Check indexing: [66192] [66528] [74952] [75119] [75120]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2645...
# Checking date: 2023-07-29 00:00:00
# Check indexing: [66216] [66552] [74976] [75143] [75144]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2646...
# Checking date: 2023-07-30 00:00:00
# Check indexing: [66240] [66576] [75000] [75167] [75168]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2647...
# Checking date: 2023-07-31 00:00:00
# Check indexing: [66264] [66600] [75024] [75191] [75192]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2648...
# Checking date: 2023-08-01 00:00:00
# Check indexing: [66288] [66624] [75048] [75215] [75216]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2649...
# Checking date: 2023-08-02 00:00:00
# Check indexing: [66312] [66648] [75072] [75239] [75240]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2650...
# Checking date: 2023-08-03 00:00:00
# Check indexing: [66336] [66672] [75096] [75263] [75264]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2651...
# Checking date: 2023-08-04 00:00:00
# Check indexing: [66360] [66696] [75120] [75287] [75288]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2652...
# Checking date: 2023-08-05 00:00:00
# Check indexing: [66384] [66720] [75144] [75311] [75312]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2653...
# Checking date: 2023-08-06 00:00:00
# Check indexing: [66408] [66744] [75168] [75335] [75336]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2654...
# Checking date: 2023-08-07 00:00:00
# Check indexing: [66432] [66768] [75192] [75359] [75360]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2655...
# Checking date: 2023-08-08 00:00:00
# Check indexing: [66456] [66792] [75216] [75383] [75384]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2656...
# Checking date: 2023-08-09 00:00:00
# Check indexing: [66480] [66816] [75240] [75407] [75408]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2657...
# Checking date: 2023-08-10 00:00:00
# Check indexing: [66504] [66840] [75264] [75431] [75432]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2658...
# Checking date: 2023-08-11 00:00:00
# Check indexing: [66528] [66864] [75288] [75455] [75456]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2659...
# Checking date: 2023-08-12 00:00:00
# Check indexing: [66552] [66888] [75312] [75479] [75480]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2660...
# Checking date: 2023-08-13 00:00:00
# Check indexing: [66576] [66912] [75336] [75503] [75504]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2661...
# Checking date: 2023-08-14 00:00:00
# Check indexing: [66600] [66936] [75360] [75527] [75528]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2662...
# Checking date: 2023-08-15 00:00:00
# Check indexing: [66624] [66960] [75384] [75551] [75552]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2663...
# Checking date: 2023-08-16 00:00:00
# Check indexing: [66648] [66984] [75408] [75575] [75576]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2664...
# Checking date: 2023-08-17 00:00:00
# Check indexing: [66672] [67008] [75432] [75599] [75600]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2665...
# Checking date: 2023-08-18 00:00:00
# Check indexing: [66696] [67032] [75456] [75623] [75624]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2666...
# Checking date: 2023-08-19 00:00:00
# Check indexing: [66720] [67056] [75480] [75647] [75648]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2667...
# Checking date: 2023-08-20 00:00:00
# Check indexing: [66744] [67080] [75504] [75671] [75672]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2668...
# Checking date: 2023-08-21 00:00:00
# Check indexing: [66768] [67104] [75528] [75695] [75696]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2669...
# Checking date: 2023-08-22 00:00:00
# Check indexing: [66792] [67128] [75552] [75719] [75720]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2670...
# Checking date: 2023-08-23 00:00:00
# Check indexing: [66816] [67152] [75576] [75743] [75744]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2671...
# Checking date: 2023-08-24 00:00:00
# Check indexing: [66840] [67176] [75600] [75767] [75768]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2672...
# Checking date: 2023-08-25 00:00:00
# Check indexing: [66864] [67200] [75624] [75791] [75792]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2673...
# Checking date: 2023-08-26 00:00:00
# Check indexing: [66888] [67224] [75648] [75815] [75816]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2674...
# Checking date: 2023-08-27 00:00:00
# Check indexing: [66912] [67248] [75672] [75839] [75840]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2675...
# Checking date: 2023-08-28 00:00:00
# Check indexing: [66936] [67272] [75696] [75863] [75864]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2676...
# Checking date: 2023-08-29 00:00:00
# Check indexing: [66960] [67296] [75720] [75887] [75888]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2677...
# Checking date: 2023-08-30 00:00:00
# Check indexing: [66984] [67320] [75744] [75911] [75912]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2678...
# Checking date: 2023-08-31 00:00:00
# Check indexing: [67008] [67344] [75768] [75935] [75936]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2679...
# Checking date: 2023-09-01 00:00:00
# Check indexing: [67032] [67368] [75792] [75959] [75960]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2680...
# Checking date: 2023-09-02 00:00:00
# Check indexing: [67056] [67392] [75816] [75983] [75984]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2681...
# Checking date: 2023-09-03 00:00:00
# Check indexing: [67080] [67416] [75840] [76007] [76008]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2682...
# Checking date: 2023-09-04 00:00:00
# Check indexing: [67104] [67440] [75864] [76031] [76032]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2683...
# Checking date: 2023-09-05 00:00:00
# Check indexing: [67128] [67464] [75888] [76055] [76056]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2684...
# Checking date: 2023-09-06 00:00:00
# Check indexing: [67152] [67488] [75912] [76079] [76080]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2685...
# Checking date: 2023-09-07 00:00:00
# Check indexing: [67176] [67512] [75936] [76103] [76104]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2686...
# Checking date: 2023-09-08 00:00:00
# Check indexing: [67200] [67536] [75960] [76127] [76128]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2687...
# Checking date: 2023-09-09 00:00:00
# Check indexing: [67224] [67560] [75984] [76151] [76152]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2688...
# Checking date: 2023-09-10 00:00:00
# Check indexing: [67248] [67584] [76008] [76175] [76176]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2689...
# Checking date: 2023-09-11 00:00:00
# Check indexing: [67272] [67608] [76032] [76199] [76200]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2690...
# Checking date: 2023-09-12 00:00:00
# Check indexing: [67296] [67632] [76056] [76223] [76224]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2691...
# Checking date: 2023-09-13 00:00:00
# Check indexing: [67320] [67656] [76080] [76247] [76248]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2692...
# Checking date: 2023-09-14 00:00:00
# Check indexing: [67344] [67680] [76104] [76271] [76272]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2693...
# Checking date: 2023-09-15 00:00:00
# Check indexing: [67368] [67704] [76128] [76295] [76296]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2694...
# Checking date: 2023-09-16 00:00:00
# Check indexing: [67392] [67728] [76152] [76319] [76320]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2695...
# Checking date: 2023-09-17 00:00:00
# Check indexing: [67416] [67752] [76176] [76343] [76344]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2696...
# Checking date: 2023-09-18 00:00:00
# Check indexing: [67440] [67776] [76200] [76367] [76368]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2697...
# Checking date: 2023-09-19 00:00:00
# Check indexing: [67464] [67800] [76224] [76391] [76392]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2698...
# Checking date: 2023-09-20 00:00:00
# Check indexing: [67488] [67824] [76248] [76415] [76416]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2699...
# Checking date: 2023-09-21 00:00:00
# Check indexing: [67512] [67848] [76272] [76439] [76440]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2700...
# Checking date: 2023-09-22 00:00:00
# Check indexing: [67536] [67872] [76296] [76463] [76464]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2701...
# Checking date: 2023-09-23 00:00:00
# Check indexing: [67560] [67896] [76320] [76487] [76488]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2702...
# Checking date: 2023-09-24 00:00:00
# Check indexing: [67584] [67920] [76344] [76511] [76512]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2703...
# Checking date: 2023-09-25 00:00:00
# Check indexing: [67608] [67944] [76368] [76535] [76536]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2704...
# Checking date: 2023-09-26 00:00:00
# Check indexing: [67632] [67968] [76392] [76559] [76560]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2705...
# Checking date: 2023-09-27 00:00:00
# Check indexing: [67656] [67992] [76416] [76583] [76584]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2706...
# Checking date: 2023-09-28 00:00:00
# Check indexing: [67680] [68016] [76440] [76607] [76608]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2707...
# Checking date: 2023-09-29 00:00:00
# Check indexing: [67704] [68040] [76464] [76631] [76632]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2708...
# Checking date: 2023-09-30 00:00:00
# Check indexing: [67728] [68064] [76488] [76655] [76656]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2709...
# Checking date: 2023-10-01 00:00:00
# Check indexing: [67752] [68088] [76512] [76679] [76680]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!

# %%
scaler.fit_transform(x_cloud)
uniq_cloud, count_cloud = np.unique(y_cloud, return_counts=True)
print(dict(zip(uniq_cloud, count_cloud)))
remove_index = np.where(y_cloud==0)[0:1055]
x_cloud_new = np.delete(x_cloud, remove_index, 0)
y_cloud_new = np.delete(y_cloud, remove_index, 0)
uniq_cloud_new, count_cloud_new = np.unique(y_cloud_new, return_counts=True)
print(dict(zip(uniq_cloud_new, count_cloud_new)))
# Out:
# {0: 1882, 1: 828}
# {1: 828}

# %%
cloud_model = SVC()
cloud_model.fit(x_train_cloud, y_train_cloud)
y_pred_cloud = cloud_model.predict(x_test_cloud)
print(accuracy_score(y_test_cloud, y_pred_cloud))
print(f1_score(y_test_cloud,y_pred_cloud))
# Out:
# 0.7878228782287823
# 0.4843049327354261

# %%
confusion_matrix(y_test_cloud, y_pred_cloud)
# Out:
# array([[373,  23],
#        [ 92,  54]])

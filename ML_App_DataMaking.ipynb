# %% [markdown]
# Call data from open-meteo.com api

# %%
# !pip install openmeteo-requests
# !pip install requests-cache retry-requests numpy pandas
# Out:
# Requirement already satisfied: openmeteo-requests in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: openmeteo-sdk>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from openmeteo-requests) (1.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openmeteo-requests) (2.31.0)
# Requirement already satisfied: flatbuffers>=23.0.0 in /usr/local/lib/python3.10/dist-packages (from openmeteo-sdk>=1.4.0->openmeteo-requests) (23.5.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->openmeteo-requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openmeteo-requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openmeteo-requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openmeteo-requests) (2023.11.17)
# Requirement already satisfied: requests-cache in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: retry-requests in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (23.1.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (23.2.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (4.1.0)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (2.31.0)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (1.4.3)
# Requirement already satisfied: urllib3>=1.25.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache) (1.2.0)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->requests-cache) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->requests-cache) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->requests-cache) (2023.11.17)

# %%
import numpy as np
import openmeteo_requests
import requests_cache
import pandas as pd
from retry_requests import retry
from datetime import date, timedelta, datetime, timedelta
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import f1_score

# %%
def get_weather_api(lat, long):
	# Setup the Open-Meteo API client with cache and retry on error
	cache_session = requests_cache.CachedSession('.cache', expire_after = -1)
	retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
	openmeteo = openmeteo_requests.Client(session = retry_session)

	# Make sure all required weather variables are listed here
	# The order of variables in hourly or daily is important to assign them correctly below
	url = "https://archive-api.open-meteo.com/v1/archive"
	params = {
		"latitude": lat,
		"longitude": long,
		"start_date": "2020-01-01",
		"end_date": "2023-10-31",
		"hourly": ["temperature_2m", "relative_humidity_2m", "dew_point_2m", "apparent_temperature", "rain", "pressure_msl", "surface_pressure", "cloud_cover", "cloud_cover_low", "cloud_cover_mid", "cloud_cover_high", "wind_speed_10m", "wind_speed_100m", "wind_direction_10m", "wind_direction_100m", "wind_gusts_10m"]
	}
	responses = openmeteo.weather_api(url, params=params)

	# Process first location. Add a for-loop for multiple locations or weather models
	response = responses[0]
	print(f"Coordinates {response.Latitude()}°E {response.Longitude()}°N")
	print(f"Elevation {response.Elevation()} m asl")
	print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
	print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

	# Process hourly data. The order of variables needs to be the same as requested.
	hourly = response.Hourly()
	hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
	hourly_relative_humidity_2m = hourly.Variables(1).ValuesAsNumpy()
	hourly_dew_point_2m = hourly.Variables(2).ValuesAsNumpy()
	hourly_apparent_temperature = hourly.Variables(3).ValuesAsNumpy()
	hourly_rain = hourly.Variables(4).ValuesAsNumpy()
	hourly_pressure_msl = hourly.Variables(5).ValuesAsNumpy()
	hourly_surface_pressure = hourly.Variables(6).ValuesAsNumpy()
	hourly_cloud_cover = hourly.Variables(7).ValuesAsNumpy()
	hourly_cloud_cover_low = hourly.Variables(8).ValuesAsNumpy()
	hourly_cloud_cover_mid = hourly.Variables(9).ValuesAsNumpy()
	hourly_cloud_cover_high = hourly.Variables(10).ValuesAsNumpy()
	hourly_wind_speed_10m = hourly.Variables(11).ValuesAsNumpy()
	hourly_wind_speed_100m = hourly.Variables(12).ValuesAsNumpy()
	hourly_wind_direction_10m = hourly.Variables(13).ValuesAsNumpy()
	hourly_wind_direction_100m = hourly.Variables(14).ValuesAsNumpy()
	hourly_wind_gusts_10m = hourly.Variables(15).ValuesAsNumpy()

	hourly_data = {"date": pd.date_range(
		start = pd.to_datetime(hourly.Time(), unit = "s"),
		end = pd.to_datetime(hourly.TimeEnd(), unit = "s"),
		freq = pd.Timedelta(seconds = hourly.Interval()),
		inclusive = "left"
	)}
	hourly_data["temperature_2m"] = hourly_temperature_2m
	hourly_data["relative_humidity_2m"] = hourly_relative_humidity_2m
	hourly_data["dew_point_2m"] = hourly_dew_point_2m
	hourly_data["apparent_temperature"] = hourly_apparent_temperature
	hourly_data["rain"] = hourly_rain
	hourly_data["pressure_msl"] = hourly_pressure_msl
	hourly_data["surface_pressure"] = hourly_surface_pressure
	hourly_data["cloud_cover"] = hourly_cloud_cover
	hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
	hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
	hourly_data["cloud_cover_high"] = hourly_cloud_cover_high
	hourly_data["wind_speed_10m"] = hourly_wind_speed_10m
	hourly_data["wind_speed_100m"] = hourly_wind_speed_100m
	hourly_data["wind_direction_10m"] = hourly_wind_direction_10m
	hourly_data["wind_direction_100m"] = hourly_wind_direction_100m
	hourly_data["wind_gusts_10m"] = hourly_wind_gusts_10m

	hourly_dataframe = pd.DataFrame(data = hourly_data)
	return hourly_dataframe

# %%
# get dataframe of district 1 with latitude = 10.7807 and longtitude = 106.6994
data_quan_1 = get_weather_api(10.7807, 106.6994)
# Out:
# Coordinates 10.790861129760742°E 106.71087646484375°N
# Elevation 18.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s

# %%
hourly_dataframe = pd.DataFrame(data_quan_1)

# %%
hourly_dataframe
# Out:
#                      date  temperature_2m  relative_humidity_2m  dew_point_2m  \
# 0     2020-01-01 00:00:00       24.039499             71.374519     18.539499
# 1     2020-01-01 01:00:00       25.839500             64.712624     18.689499
# 2     2020-01-01 02:00:00       27.689499             58.037663     18.689499
# 3     2020-01-01 03:00:00       29.739500             49.473461     18.039499
# 4     2020-01-01 04:00:00       31.689499             39.616940     16.289499
# ...                   ...             ...                   ...           ...
# 33595 2023-10-31 19:00:00       24.789499             98.516823     24.539499
# 33596 2023-10-31 20:00:00       24.639500             97.926659     24.289499
# 33597 2023-10-31 21:00:00       24.539499             97.339287     24.089500
# 33598 2023-10-31 22:00:00       24.539499             96.176743     23.889500
# 33599 2023-10-31 23:00:00       24.489500             95.024567     23.639500
#
#        apparent_temperature  rain  pressure_msl  surface_pressure  \
# 0                 25.566103   0.0   1015.299988       1013.201843
# 1                 26.984768   0.0   1016.099976       1014.012634
# 2                 29.050800   0.0   1016.400024       1014.325073
# 3                 31.584839   0.0   1016.099976       1014.039673
# 4                 33.300831   0.0   1015.500000       1013.453918
# ...                     ...   ...           ...               ...
# 33595             30.363483   0.0   1009.799988       1007.718262
# 33596             30.209759   0.0   1009.400024       1007.318298
# 33597             30.015854   0.0   1009.500000       1007.417358
# 33598             29.657166   0.0   1009.900024       1007.816528
# 33599             29.548794   0.0   1010.500000       1008.415039
#
#        cloud_cover  cloud_cover_low  cloud_cover_mid  cloud_cover_high  \
# 0        24.000000              0.0              0.0              80.0
# 1         9.000000              0.0              0.0              30.0
# 2         5.400000              0.0              0.0              18.0
# 3         9.300000              0.0              0.0              31.0
# 4        24.300001              0.0              0.0              81.0
# ...            ...              ...              ...               ...
# 33595    24.900000             23.0              1.0              12.0
# 33596     1.500000              1.0              1.0               0.0
# 33597    18.900000              2.0              0.0              57.0
# 33598    30.300001              1.0              1.0              96.0
# 33599    17.700001              3.0              0.0              50.0
#
#        wind_speed_10m  wind_speed_100m  wind_direction_10m  \
# 0           11.183201        23.400000           33.178535
# 1           14.264361        19.881649           47.045418
# 2           12.768586        16.087610           49.574005
# 3           11.200571        13.746156           44.999897
# 4           12.768586        15.580141           40.425995
# ...               ...              ...                 ...
# 33595        5.959060        12.758432          334.983124
# 33596        4.896529        10.853866          342.897186
# 33597        4.680000         9.255571          360.000000
# 33598        6.287130         9.504272           23.629398
# 33599        5.634891         9.449572           26.564985
#
#        wind_direction_100m  wind_gusts_10m
# 0                36.869991       18.000000
# 1                47.935760       24.119999
# 2                49.537849       25.559999
# 3                44.999897       24.840000
# 4                40.314034       26.280001
# ...                    ...             ...
# 33595           343.610382       10.080000
# 33596           354.289490        8.280000
# 33597            13.495748        6.840000
# 33598            37.304039        7.559999
# 33599            40.364468        9.720000
#
# [33600 rows x 17 columns]

# %%
weather_data = hourly_dataframe.iloc[:,:].values

# %%
# labeling rain data
# no rain => 0 || rainy => 1 || heavy rain => 2
predict_rain = []

for element in weather_data:
  rain = element[5]
  rain_label = -1
  if rain < 0.3:
    rain_label = 0
  else: rain_label = 1
  predict_rain.append(rain_label)

# %%
# check if exist any element mislabeled in rain data
nprain = np.array(predict_rain)
print('Rain label:', np.unique(nprain))
unique, counts = np.unique(nprain, return_counts=True)

infor_rain = dict(zip(unique, counts))
data_len = len(weather_data)
for i in range(2):
  print(f'Number of sample in label {i}:', infor_rain[i], '||\t||', ' Account', counts[i]/data_len*100, '% of total data.')
# Out:
# Rain label: [0 1]
# Number of sample in label 0: 28434 ||	||  Account 84.625 % of total data.
# Number of sample in label 1: 5166 ||	||  Account 15.375 % of total data.

# %%
# labeling heat data
# cool => 0 || hot => 1 || scorching => 2
predict_heat = []

for element in weather_data:
  heat = element[4]
  heat_label = -1
  if heat < 35:
    heat_label = 0
  elif heat < 37:
    heat_label = 1
  else: heat_label = 2
  predict_heat.append(heat_label)

# %%
# check if exist any element mislabeled in heat data
npheat = np.array(predict_heat)
print('Heat label:', np.unique(npheat))
unique, counts = np.unique(npheat, return_counts=True)

infor_heat = dict(zip(unique, counts))
for i in range(3):
  print(f'Number of sample in label {i}:', infor_heat[i], '||\t||', ' Account', counts[i]/data_len*100, '% of total data.')
# Out:
# Heat label: [0 1 2]
# Number of sample in label 0: 28427 ||	||  Account 84.60416666666667 % of total data.
# Number of sample in label 1: 2971 ||	||  Account 8.842261904761903 % of total data.
# Number of sample in label 2: 2202 ||	||  Account 6.553571428571428 % of total data.

# %%
# labeling cloud data
# less cloud => 0 || much cloud => 1
predict_cloud = []

for element in weather_data:
  cloud = element[8]
  cloud_label = -1
  if cloud < 50:
    cloud_label = 0
  else: cloud_label = 1
  predict_cloud.append(cloud_label)

# %%
# check if exist any element mislabeled in cloud data
npcloud = np.array(predict_cloud)
print('cloud label:', np.unique(npcloud))
unique, counts = np.unique(npcloud, return_counts=True)

infor_cloud = dict(zip(unique, counts))
for i in range(2):
  print(f'Number of sample in label {i}:', infor_cloud[i], '||\t||', ' Account', counts[i]/data_len*100, '% of total data.')
# Out:
# cloud label: [0 1]
# Number of sample in label 0: 22691 ||	||  Account 67.5327380952381 % of total data.
# Number of sample in label 1: 10909 ||	||  Account 32.467261904761905 % of total data.

# %%
hourly_dataframe['predict_rain'] = nprain
hourly_dataframe['predict_heat'] = npheat
hourly_dataframe['predict_cloud'] = npcloud

# %%
hourly_dataframe['date'] = hourly_dataframe['date'].astype('string')

# %%
datetime = datetime.fromisoformat(hourly_dataframe.iloc[15000, 0])

# %%
# define a function to get feature date and target date
def get_date(datetime):
  feature_date = []
  target_date = []
  date = str(datetime)
  for i in range(1, 169):
    # calculate time and add it to list
    last_year_before = datetime.fromisoformat(date) - timedelta(days=365, hours=i)
    last_year_after = datetime.fromisoformat(date) + timedelta(hours=i) - timedelta(days=365)
    last_week_time = datetime.fromisoformat(date) - timedelta(hours=i)
    next_week_time = datetime.fromisoformat(date) + timedelta(hours=i)
    feature_date.append(str(last_year_before))
    feature_date.append(str(last_year_after))
    feature_date.append(str(last_week_time))
    target_date.append(str(next_week_time))
  return feature_date, target_date

# %%
feature_date, target_date = get_date(datetime)

# %%
print(len(feature_date), len(target_date))
# Out:
# 504 168

# %%
datetime
# Out:
# datetime.datetime(2021, 9, 17, 0, 0)

# %%
print(feature_date[0],feature_date[1],feature_date[2])
# Out:
# 2020-09-16 23:00:00 2020-09-17 01:00:00 2021-09-16 23:00:00

# %%
columns_rain=['relative_humidity_2m', 'apparent_temperature', 'surface_pressure', 'rain', 'cloud_cover']
columns_heat=['relative_humidity_2m', 'wind_gusts_10m', 'apparent_temperature', 'temperature_2m']
columns_cloud=['rain', 'cloud_cover', 'cloud_cover_low', 'cloud_cover_mid', 'cloud_cover_high']
target_rain=['predict_rain']
target_heat=['predict_heat']
target_cloud=['predict_cloud']

# %% [markdown]
# tuần trước năm trước (168h) + tuần sau năm trước (168h) + tuần sau năm này (168h)</br>
# => 1 tuần sau năm này (168h)

# %%
def get_data(feature_time, target_time, feature, target):
  data_feat = []
  target_feat = []

  # iterate through feature_time
  for time in feature_time:
    # append found data in list (feature got include week before-later of last year, one week before of this year)
    data = hourly_dataframe[feature].to_numpy()[hourly_dataframe['date'].to_numpy() == time]
    data_feat.append(data)

  # iterate through target_time
  for time in target_time:
    # append found data in list (feature got include one week after of this year)
    data = hourly_dataframe[target].to_numpy()[hourly_dataframe['date'].to_numpy() == time]
    target_feat.append(data)

  # convert the two list to numpy array and flatten them
  data_feat = np.array(data_feat).flatten()
  target_feat = np.array(target_feat).flatten()

  return data_feat, target_feat

# %%
feature_data, target_data = get_data(feature_date, target_date, columns_heat, target_heat)

# %%
print(feature_data.shape) # 2016 mean 504*4 -> 504 hours total * 4 feature (because i flatten it)
print(target_data.shape)
# Out:
# (2016,)
# (168,)

# %%
def get_all_of_type(feature_type, target_type):
  feature = []
  target = []
  for i in range(len(hourly_dataframe)):
    date = datetime.fromisoformat(hourly_dataframe.iloc[i, 0])
    feature_date, target_date = get_date(date)
    feature_data, target_data = get_data(feature_date, target_date, feature_type, target_type)
    feature.append(feature_data)
    target.append(target_data)
  feature = np.array(feature)
  target = np.array(target)
  return feature, target

# %%
#heat_feature, heat_target = get_all_of_type(columns_heat, target_heat)

# %%
print(datetime.fromisoformat(hourly_dataframe.iloc[8784, 0]))
# Out:
# 2021-01-01 00:00:00

# %%
print(hourly_dataframe[columns_heat].iloc[8784-365*24-1:8784-365*24-169])
# Out:
#        relative_humidity_2m  wind_gusts_10m  apparent_temperature  \
# 23                80.390739       10.440001             25.081156
# 24                73.138367        9.720000             25.864468
# 25                66.515404       18.359999             27.638216
# 26                61.340786       19.440001             29.895203
# 27                54.054295       18.719999             32.404476
# ...                     ...             ...                   ...
# 33450             94.477852       10.799999             30.268993
# 33451             95.326515        9.360000             30.236565
# 33452             96.470146        8.640000             30.163628
# 33453             95.604889        6.120000             30.331520
# 33454             96.175339        5.400000             29.808720
#
#        temperature_2m
# 23          22.689499
# 24          23.789499
# 25          25.639500
# 26          27.489500
# 27          29.289499
# ...               ...
# 33450       25.089500
# 33451       24.939499
# 33452       24.689499
# 33453       24.689499
# 33454       24.489500
#
# [33432 rows x 4 columns]

# %%
hourly_dataframe.index[hourly_dataframe['date'].values == str(datetime.fromisoformat('2023-10-01 23:00:00') + timedelta(days=i))]
# Out:
# Int64Index([32903], dtype='int64')

# %%
def get_train_test_data(start, end, feature_type, target_type):
  feature = []
  target = []
  start = datetime.fromisoformat(start)
  end = datetime.fromisoformat(end)
  for i in range((end-start).days+1):
    print('----------------------------------')
    print(f'Get {i}...')
    date = start + timedelta(days=i)
    print(f'Checking date:', date)

    # get prev week
    last_week_end = date - timedelta(hours=1)
    last_week_start = date - timedelta(hours=24*7)

    # get prev year
    last_year_start = date - timedelta(days=365, hours=24*7)
    last_year_end = date - timedelta(days=365) + timedelta(hours=24*7)

    # get index of those feature
    last_week_start_index = np.where(hourly_dataframe['date'].values == str(last_week_start))
    last_week_end_index = np.where(hourly_dataframe['date'].values == str(last_week_end))
    last_year_start_index = np.where(hourly_dataframe['date'].values == str(last_year_start))
    last_year_end_index = np.where(hourly_dataframe['date'].values == str(last_year_end))

    # get index of those target
    next_week_index = np.where(hourly_dataframe['date'].values == str(date))

    # error checking
    print('Check indexing:', last_year_start_index[0],last_year_end_index[0],last_week_start_index[0],last_week_end_index[0],next_week_index[0])

    # get data of those feature
    feature_year = hourly_dataframe.loc[int(last_year_start_index[0]):int(last_year_end_index[0]), feature_type].to_numpy(copy=True).flatten()
    feature_week = hourly_dataframe.loc[int(last_week_start_index[0]):int(last_week_end_index[0]), feature_type].to_numpy(copy=True).flatten()

    # target
    target_week = hourly_dataframe.loc[int(next_week_index[0]), target_type].to_numpy(copy=True).flatten()

    feature_np = np.concatenate((feature_year, feature_week), axis=None)
    print('Feature shape:', feature_np.shape)
    print('Target shape:', target_week.shape)
    #target_temp.clear()
    feature.append(feature_np)
    target.append(target_week)
    print('Done!')

  return feature, target

# %%
x_heat, y_heat = get_train_test_data('2022-01-01 00:00:00', '2023-10-01 23:00:00', columns_heat, target_heat)
x_heat = np.array(x_heat)
y_heat = np.array(y_heat).astype('int')
# Out:
# ----------------------------------
# Get 0...
# Checking date: 2022-01-01 00:00:00
# Check indexing: [8616] [8952] [17376] [17543] [17544]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1...
# Checking date: 2022-01-02 00:00:00
# Check indexing: [8640] [8976] [17400] [17567] [17568]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2...
# Checking date: 2022-01-03 00:00:00
# Check indexing: [8664] [9000] [17424] [17591] [17592]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 3...
# Checking date: 2022-01-04 00:00:00
# Check indexing: [8688] [9024] [17448] [17615] [17616]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 4...
# Checking date: 2022-01-05 00:00:00
# Check indexing: [8712] [9048] [17472] [17639] [17640]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 5...
# Checking date: 2022-01-06 00:00:00
# Check indexing: [8736] [9072] [17496] [17663] [17664]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 6...
# Checking date: 2022-01-07 00:00:00
# Check indexing: [8760] [9096] [17520] [17687] [17688]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 7...
# Checking date: 2022-01-08 00:00:00
# Check indexing: [8784] [9120] [17544] [17711] [17712]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 8...
# Checking date: 2022-01-09 00:00:00
# Check indexing: [8808] [9144] [17568] [17735] [17736]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 9...
# Checking date: 2022-01-10 00:00:00
# Check indexing: [8832] [9168] [17592] [17759] [17760]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 10...
# Checking date: 2022-01-11 00:00:00
# Check indexing: [8856] [9192] [17616] [17783] [17784]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 11...
# Checking date: 2022-01-12 00:00:00
# Check indexing: [8880] [9216] [17640] [17807] [17808]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 12...
# Checking date: 2022-01-13 00:00:00
# Check indexing: [8904] [9240] [17664] [17831] [17832]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 13...
# Checking date: 2022-01-14 00:00:00
# Check indexing: [8928] [9264] [17688] [17855] [17856]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 14...
# Checking date: 2022-01-15 00:00:00
# Check indexing: [8952] [9288] [17712] [17879] [17880]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 15...
# Checking date: 2022-01-16 00:00:00
# Check indexing: [8976] [9312] [17736] [17903] [17904]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 16...
# Checking date: 2022-01-17 00:00:00
# Check indexing: [9000] [9336] [17760] [17927] [17928]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 17...
# Checking date: 2022-01-18 00:00:00
# Check indexing: [9024] [9360] [17784] [17951] [17952]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 18...
# Checking date: 2022-01-19 00:00:00
# Check indexing: [9048] [9384] [17808] [17975] [17976]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 19...
# Checking date: 2022-01-20 00:00:00
# Check indexing: [9072] [9408] [17832] [17999] [18000]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 20...
# Checking date: 2022-01-21 00:00:00
# Check indexing: [9096] [9432] [17856] [18023] [18024]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 21...
# Checking date: 2022-01-22 00:00:00
# Check indexing: [9120] [9456] [17880] [18047] [18048]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 22...
# Checking date: 2022-01-23 00:00:00
# Check indexing: [9144] [9480] [17904] [18071] [18072]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 23...
# Checking date: 2022-01-24 00:00:00
# Check indexing: [9168] [9504] [17928] [18095] [18096]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 24...
# Checking date: 2022-01-25 00:00:00
# Check indexing: [9192] [9528] [17952] [18119] [18120]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 25...
# Checking date: 2022-01-26 00:00:00
# Check indexing: [9216] [9552] [17976] [18143] [18144]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 26...
# Checking date: 2022-01-27 00:00:00
# Check indexing: [9240] [9576] [18000] [18167] [18168]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 27...
# Checking date: 2022-01-28 00:00:00
# Check indexing: [9264] [9600] [18024] [18191] [18192]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 28...
# Checking date: 2022-01-29 00:00:00
# Check indexing: [9288] [9624] [18048] [18215] [18216]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 29...
# Checking date: 2022-01-30 00:00:00
# Check indexing: [9312] [9648] [18072] [18239] [18240]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 30...
# Checking date: 2022-01-31 00:00:00
# Check indexing: [9336] [9672] [18096] [18263] [18264]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 31...
# Checking date: 2022-02-01 00:00:00
# Check indexing: [9360] [9696] [18120] [18287] [18288]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 32...
# Checking date: 2022-02-02 00:00:00
# Check indexing: [9384] [9720] [18144] [18311] [18312]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 33...
# Checking date: 2022-02-03 00:00:00
# Check indexing: [9408] [9744] [18168] [18335] [18336]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 34...
# Checking date: 2022-02-04 00:00:00
# Check indexing: [9432] [9768] [18192] [18359] [18360]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 35...
# Checking date: 2022-02-05 00:00:00
# Check indexing: [9456] [9792] [18216] [18383] [18384]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 36...
# Checking date: 2022-02-06 00:00:00
# Check indexing: [9480] [9816] [18240] [18407] [18408]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 37...
# Checking date: 2022-02-07 00:00:00
# Check indexing: [9504] [9840] [18264] [18431] [18432]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 38...
# Checking date: 2022-02-08 00:00:00
# Check indexing: [9528] [9864] [18288] [18455] [18456]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 39...
# Checking date: 2022-02-09 00:00:00
# Check indexing: [9552] [9888] [18312] [18479] [18480]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 40...
# Checking date: 2022-02-10 00:00:00
# Check indexing: [9576] [9912] [18336] [18503] [18504]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 41...
# Checking date: 2022-02-11 00:00:00
# Check indexing: [9600] [9936] [18360] [18527] [18528]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 42...
# Checking date: 2022-02-12 00:00:00
# Check indexing: [9624] [9960] [18384] [18551] [18552]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 43...
# Checking date: 2022-02-13 00:00:00
# Check indexing: [9648] [9984] [18408] [18575] [18576]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 44...
# Checking date: 2022-02-14 00:00:00
# Check indexing: [9672] [10008] [18432] [18599] [18600]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 45...
# Checking date: 2022-02-15 00:00:00
# Check indexing: [9696] [10032] [18456] [18623] [18624]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 46...
# Checking date: 2022-02-16 00:00:00
# Check indexing: [9720] [10056] [18480] [18647] [18648]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 47...
# Checking date: 2022-02-17 00:00:00
# Check indexing: [9744] [10080] [18504] [18671] [18672]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 48...
# Checking date: 2022-02-18 00:00:00
# Check indexing: [9768] [10104] [18528] [18695] [18696]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 49...
# Checking date: 2022-02-19 00:00:00
# Check indexing: [9792] [10128] [18552] [18719] [18720]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 50...
# Checking date: 2022-02-20 00:00:00
# Check indexing: [9816] [10152] [18576] [18743] [18744]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 51...
# Checking date: 2022-02-21 00:00:00
# Check indexing: [9840] [10176] [18600] [18767] [18768]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 52...
# Checking date: 2022-02-22 00:00:00
# Check indexing: [9864] [10200] [18624] [18791] [18792]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 53...
# Checking date: 2022-02-23 00:00:00
# Check indexing: [9888] [10224] [18648] [18815] [18816]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 54...
# Checking date: 2022-02-24 00:00:00
# Check indexing: [9912] [10248] [18672] [18839] [18840]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 55...
# Checking date: 2022-02-25 00:00:00
# Check indexing: [9936] [10272] [18696] [18863] [18864]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 56...
# Checking date: 2022-02-26 00:00:00
# Check indexing: [9960] [10296] [18720] [18887] [18888]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 57...
# Checking date: 2022-02-27 00:00:00
# Check indexing: [9984] [10320] [18744] [18911] [18912]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 58...
# Checking date: 2022-02-28 00:00:00
# Check indexing: [10008] [10344] [18768] [18935] [18936]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 59...
# Checking date: 2022-03-01 00:00:00
# Check indexing: [10032] [10368] [18792] [18959] [18960]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 60...
# Checking date: 2022-03-02 00:00:00
# Check indexing: [10056] [10392] [18816] [18983] [18984]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 61...
# Checking date: 2022-03-03 00:00:00
# Check indexing: [10080] [10416] [18840] [19007] [19008]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 62...
# Checking date: 2022-03-04 00:00:00
# Check indexing: [10104] [10440] [18864] [19031] [19032]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 63...
# Checking date: 2022-03-05 00:00:00
# Check indexing: [10128] [10464] [18888] [19055] [19056]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 64...
# Checking date: 2022-03-06 00:00:00
# Check indexing: [10152] [10488] [18912] [19079] [19080]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 65...
# Checking date: 2022-03-07 00:00:00
# Check indexing: [10176] [10512] [18936] [19103] [19104]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 66...
# Checking date: 2022-03-08 00:00:00
# Check indexing: [10200] [10536] [18960] [19127] [19128]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 67...
# Checking date: 2022-03-09 00:00:00
# Check indexing: [10224] [10560] [18984] [19151] [19152]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 68...
# Checking date: 2022-03-10 00:00:00
# Check indexing: [10248] [10584] [19008] [19175] [19176]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 69...
# Checking date: 2022-03-11 00:00:00
# Check indexing: [10272] [10608] [19032] [19199] [19200]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 70...
# Checking date: 2022-03-12 00:00:00
# Check indexing: [10296] [10632] [19056] [19223] [19224]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 71...
# Checking date: 2022-03-13 00:00:00
# Check indexing: [10320] [10656] [19080] [19247] [19248]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 72...
# Checking date: 2022-03-14 00:00:00
# Check indexing: [10344] [10680] [19104] [19271] [19272]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 73...
# Checking date: 2022-03-15 00:00:00
# Check indexing: [10368] [10704] [19128] [19295] [19296]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 74...
# Checking date: 2022-03-16 00:00:00
# Check indexing: [10392] [10728] [19152] [19319] [19320]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 75...
# Checking date: 2022-03-17 00:00:00
# Check indexing: [10416] [10752] [19176] [19343] [19344]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 76...
# Checking date: 2022-03-18 00:00:00
# Check indexing: [10440] [10776] [19200] [19367] [19368]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 77...
# Checking date: 2022-03-19 00:00:00
# Check indexing: [10464] [10800] [19224] [19391] [19392]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 78...
# Checking date: 2022-03-20 00:00:00
# Check indexing: [10488] [10824] [19248] [19415] [19416]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 79...
# Checking date: 2022-03-21 00:00:00
# Check indexing: [10512] [10848] [19272] [19439] [19440]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 80...
# Checking date: 2022-03-22 00:00:00
# Check indexing: [10536] [10872] [19296] [19463] [19464]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 81...
# Checking date: 2022-03-23 00:00:00
# Check indexing: [10560] [10896] [19320] [19487] [19488]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 82...
# Checking date: 2022-03-24 00:00:00
# Check indexing: [10584] [10920] [19344] [19511] [19512]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 83...
# Checking date: 2022-03-25 00:00:00
# Check indexing: [10608] [10944] [19368] [19535] [19536]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 84...
# Checking date: 2022-03-26 00:00:00
# Check indexing: [10632] [10968] [19392] [19559] [19560]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 85...
# Checking date: 2022-03-27 00:00:00
# Check indexing: [10656] [10992] [19416] [19583] [19584]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 86...
# Checking date: 2022-03-28 00:00:00
# Check indexing: [10680] [11016] [19440] [19607] [19608]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 87...
# Checking date: 2022-03-29 00:00:00
# Check indexing: [10704] [11040] [19464] [19631] [19632]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 88...
# Checking date: 2022-03-30 00:00:00
# Check indexing: [10728] [11064] [19488] [19655] [19656]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 89...
# Checking date: 2022-03-31 00:00:00
# Check indexing: [10752] [11088] [19512] [19679] [19680]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 90...
# Checking date: 2022-04-01 00:00:00
# Check indexing: [10776] [11112] [19536] [19703] [19704]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 91...
# Checking date: 2022-04-02 00:00:00
# Check indexing: [10800] [11136] [19560] [19727] [19728]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 92...
# Checking date: 2022-04-03 00:00:00
# Check indexing: [10824] [11160] [19584] [19751] [19752]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 93...
# Checking date: 2022-04-04 00:00:00
# Check indexing: [10848] [11184] [19608] [19775] [19776]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 94...
# Checking date: 2022-04-05 00:00:00
# Check indexing: [10872] [11208] [19632] [19799] [19800]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 95...
# Checking date: 2022-04-06 00:00:00
# Check indexing: [10896] [11232] [19656] [19823] [19824]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 96...
# Checking date: 2022-04-07 00:00:00
# Check indexing: [10920] [11256] [19680] [19847] [19848]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 97...
# Checking date: 2022-04-08 00:00:00
# Check indexing: [10944] [11280] [19704] [19871] [19872]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 98...
# Checking date: 2022-04-09 00:00:00
# Check indexing: [10968] [11304] [19728] [19895] [19896]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 99...
# Checking date: 2022-04-10 00:00:00
# Check indexing: [10992] [11328] [19752] [19919] [19920]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 100...
# Checking date: 2022-04-11 00:00:00
# Check indexing: [11016] [11352] [19776] [19943] [19944]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 101...
# Checking date: 2022-04-12 00:00:00
# Check indexing: [11040] [11376] [19800] [19967] [19968]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 102...
# Checking date: 2022-04-13 00:00:00
# Check indexing: [11064] [11400] [19824] [19991] [19992]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 103...
# Checking date: 2022-04-14 00:00:00
# Check indexing: [11088] [11424] [19848] [20015] [20016]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 104...
# Checking date: 2022-04-15 00:00:00
# Check indexing: [11112] [11448] [19872] [20039] [20040]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 105...
# Checking date: 2022-04-16 00:00:00
# Check indexing: [11136] [11472] [19896] [20063] [20064]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 106...
# Checking date: 2022-04-17 00:00:00
# Check indexing: [11160] [11496] [19920] [20087] [20088]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 107...
# Checking date: 2022-04-18 00:00:00
# Check indexing: [11184] [11520] [19944] [20111] [20112]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 108...
# Checking date: 2022-04-19 00:00:00
# Check indexing: [11208] [11544] [19968] [20135] [20136]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 109...
# Checking date: 2022-04-20 00:00:00
# Check indexing: [11232] [11568] [19992] [20159] [20160]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 110...
# Checking date: 2022-04-21 00:00:00
# Check indexing: [11256] [11592] [20016] [20183] [20184]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 111...
# Checking date: 2022-04-22 00:00:00
# Check indexing: [11280] [11616] [20040] [20207] [20208]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 112...
# Checking date: 2022-04-23 00:00:00
# Check indexing: [11304] [11640] [20064] [20231] [20232]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 113...
# Checking date: 2022-04-24 00:00:00
# Check indexing: [11328] [11664] [20088] [20255] [20256]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 114...
# Checking date: 2022-04-25 00:00:00
# Check indexing: [11352] [11688] [20112] [20279] [20280]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 115...
# Checking date: 2022-04-26 00:00:00
# Check indexing: [11376] [11712] [20136] [20303] [20304]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 116...
# Checking date: 2022-04-27 00:00:00
# Check indexing: [11400] [11736] [20160] [20327] [20328]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 117...
# Checking date: 2022-04-28 00:00:00
# Check indexing: [11424] [11760] [20184] [20351] [20352]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 118...
# Checking date: 2022-04-29 00:00:00
# Check indexing: [11448] [11784] [20208] [20375] [20376]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 119...
# Checking date: 2022-04-30 00:00:00
# Check indexing: [11472] [11808] [20232] [20399] [20400]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 120...
# Checking date: 2022-05-01 00:00:00
# Check indexing: [11496] [11832] [20256] [20423] [20424]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 121...
# Checking date: 2022-05-02 00:00:00
# Check indexing: [11520] [11856] [20280] [20447] [20448]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 122...
# Checking date: 2022-05-03 00:00:00
# Check indexing: [11544] [11880] [20304] [20471] [20472]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 123...
# Checking date: 2022-05-04 00:00:00
# Check indexing: [11568] [11904] [20328] [20495] [20496]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 124...
# Checking date: 2022-05-05 00:00:00
# Check indexing: [11592] [11928] [20352] [20519] [20520]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 125...
# Checking date: 2022-05-06 00:00:00
# Check indexing: [11616] [11952] [20376] [20543] [20544]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 126...
# Checking date: 2022-05-07 00:00:00
# Check indexing: [11640] [11976] [20400] [20567] [20568]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 127...
# Checking date: 2022-05-08 00:00:00
# Check indexing: [11664] [12000] [20424] [20591] [20592]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 128...
# Checking date: 2022-05-09 00:00:00
# Check indexing: [11688] [12024] [20448] [20615] [20616]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 129...
# Checking date: 2022-05-10 00:00:00
# Check indexing: [11712] [12048] [20472] [20639] [20640]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 130...
# Checking date: 2022-05-11 00:00:00
# Check indexing: [11736] [12072] [20496] [20663] [20664]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 131...
# Checking date: 2022-05-12 00:00:00
# Check indexing: [11760] [12096] [20520] [20687] [20688]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 132...
# Checking date: 2022-05-13 00:00:00
# Check indexing: [11784] [12120] [20544] [20711] [20712]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 133...
# Checking date: 2022-05-14 00:00:00
# Check indexing: [11808] [12144] [20568] [20735] [20736]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 134...
# Checking date: 2022-05-15 00:00:00
# Check indexing: [11832] [12168] [20592] [20759] [20760]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 135...
# Checking date: 2022-05-16 00:00:00
# Check indexing: [11856] [12192] [20616] [20783] [20784]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 136...
# Checking date: 2022-05-17 00:00:00
# Check indexing: [11880] [12216] [20640] [20807] [20808]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 137...
# Checking date: 2022-05-18 00:00:00
# Check indexing: [11904] [12240] [20664] [20831] [20832]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 138...
# Checking date: 2022-05-19 00:00:00
# Check indexing: [11928] [12264] [20688] [20855] [20856]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 139...
# Checking date: 2022-05-20 00:00:00
# Check indexing: [11952] [12288] [20712] [20879] [20880]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 140...
# Checking date: 2022-05-21 00:00:00
# Check indexing: [11976] [12312] [20736] [20903] [20904]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 141...
# Checking date: 2022-05-22 00:00:00
# Check indexing: [12000] [12336] [20760] [20927] [20928]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 142...
# Checking date: 2022-05-23 00:00:00
# Check indexing: [12024] [12360] [20784] [20951] [20952]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 143...
# Checking date: 2022-05-24 00:00:00
# Check indexing: [12048] [12384] [20808] [20975] [20976]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 144...
# Checking date: 2022-05-25 00:00:00
# Check indexing: [12072] [12408] [20832] [20999] [21000]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 145...
# Checking date: 2022-05-26 00:00:00
# Check indexing: [12096] [12432] [20856] [21023] [21024]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 146...
# Checking date: 2022-05-27 00:00:00
# Check indexing: [12120] [12456] [20880] [21047] [21048]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 147...
# Checking date: 2022-05-28 00:00:00
# Check indexing: [12144] [12480] [20904] [21071] [21072]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 148...
# Checking date: 2022-05-29 00:00:00
# Check indexing: [12168] [12504] [20928] [21095] [21096]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 149...
# Checking date: 2022-05-30 00:00:00
# Check indexing: [12192] [12528] [20952] [21119] [21120]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 150...
# Checking date: 2022-05-31 00:00:00
# Check indexing: [12216] [12552] [20976] [21143] [21144]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 151...
# Checking date: 2022-06-01 00:00:00
# Check indexing: [12240] [12576] [21000] [21167] [21168]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 152...
# Checking date: 2022-06-02 00:00:00
# Check indexing: [12264] [12600] [21024] [21191] [21192]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 153...
# Checking date: 2022-06-03 00:00:00
# Check indexing: [12288] [12624] [21048] [21215] [21216]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 154...
# Checking date: 2022-06-04 00:00:00
# Check indexing: [12312] [12648] [21072] [21239] [21240]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 155...
# Checking date: 2022-06-05 00:00:00
# Check indexing: [12336] [12672] [21096] [21263] [21264]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 156...
# Checking date: 2022-06-06 00:00:00
# Check indexing: [12360] [12696] [21120] [21287] [21288]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 157...
# Checking date: 2022-06-07 00:00:00
# Check indexing: [12384] [12720] [21144] [21311] [21312]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 158...
# Checking date: 2022-06-08 00:00:00
# Check indexing: [12408] [12744] [21168] [21335] [21336]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 159...
# Checking date: 2022-06-09 00:00:00
# Check indexing: [12432] [12768] [21192] [21359] [21360]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 160...
# Checking date: 2022-06-10 00:00:00
# Check indexing: [12456] [12792] [21216] [21383] [21384]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 161...
# Checking date: 2022-06-11 00:00:00
# Check indexing: [12480] [12816] [21240] [21407] [21408]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 162...
# Checking date: 2022-06-12 00:00:00
# Check indexing: [12504] [12840] [21264] [21431] [21432]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 163...
# Checking date: 2022-06-13 00:00:00
# Check indexing: [12528] [12864] [21288] [21455] [21456]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 164...
# Checking date: 2022-06-14 00:00:00
# Check indexing: [12552] [12888] [21312] [21479] [21480]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 165...
# Checking date: 2022-06-15 00:00:00
# Check indexing: [12576] [12912] [21336] [21503] [21504]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 166...
# Checking date: 2022-06-16 00:00:00
# Check indexing: [12600] [12936] [21360] [21527] [21528]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 167...
# Checking date: 2022-06-17 00:00:00
# Check indexing: [12624] [12960] [21384] [21551] [21552]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 168...
# Checking date: 2022-06-18 00:00:00
# Check indexing: [12648] [12984] [21408] [21575] [21576]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 169...
# Checking date: 2022-06-19 00:00:00
# Check indexing: [12672] [13008] [21432] [21599] [21600]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 170...
# Checking date: 2022-06-20 00:00:00
# Check indexing: [12696] [13032] [21456] [21623] [21624]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 171...
# Checking date: 2022-06-21 00:00:00
# Check indexing: [12720] [13056] [21480] [21647] [21648]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 172...
# Checking date: 2022-06-22 00:00:00
# Check indexing: [12744] [13080] [21504] [21671] [21672]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 173...
# Checking date: 2022-06-23 00:00:00
# Check indexing: [12768] [13104] [21528] [21695] [21696]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 174...
# Checking date: 2022-06-24 00:00:00
# Check indexing: [12792] [13128] [21552] [21719] [21720]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 175...
# Checking date: 2022-06-25 00:00:00
# Check indexing: [12816] [13152] [21576] [21743] [21744]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 176...
# Checking date: 2022-06-26 00:00:00
# Check indexing: [12840] [13176] [21600] [21767] [21768]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 177...
# Checking date: 2022-06-27 00:00:00
# Check indexing: [12864] [13200] [21624] [21791] [21792]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 178...
# Checking date: 2022-06-28 00:00:00
# Check indexing: [12888] [13224] [21648] [21815] [21816]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 179...
# Checking date: 2022-06-29 00:00:00
# Check indexing: [12912] [13248] [21672] [21839] [21840]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 180...
# Checking date: 2022-06-30 00:00:00
# Check indexing: [12936] [13272] [21696] [21863] [21864]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 181...
# Checking date: 2022-07-01 00:00:00
# Check indexing: [12960] [13296] [21720] [21887] [21888]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 182...
# Checking date: 2022-07-02 00:00:00
# Check indexing: [12984] [13320] [21744] [21911] [21912]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 183...
# Checking date: 2022-07-03 00:00:00
# Check indexing: [13008] [13344] [21768] [21935] [21936]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 184...
# Checking date: 2022-07-04 00:00:00
# Check indexing: [13032] [13368] [21792] [21959] [21960]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 185...
# Checking date: 2022-07-05 00:00:00
# Check indexing: [13056] [13392] [21816] [21983] [21984]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 186...
# Checking date: 2022-07-06 00:00:00
# Check indexing: [13080] [13416] [21840] [22007] [22008]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 187...
# Checking date: 2022-07-07 00:00:00
# Check indexing: [13104] [13440] [21864] [22031] [22032]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 188...
# Checking date: 2022-07-08 00:00:00
# Check indexing: [13128] [13464] [21888] [22055] [22056]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 189...
# Checking date: 2022-07-09 00:00:00
# Check indexing: [13152] [13488] [21912] [22079] [22080]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 190...
# Checking date: 2022-07-10 00:00:00
# Check indexing: [13176] [13512] [21936] [22103] [22104]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 191...
# Checking date: 2022-07-11 00:00:00
# Check indexing: [13200] [13536] [21960] [22127] [22128]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 192...
# Checking date: 2022-07-12 00:00:00
# Check indexing: [13224] [13560] [21984] [22151] [22152]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 193...
# Checking date: 2022-07-13 00:00:00
# Check indexing: [13248] [13584] [22008] [22175] [22176]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 194...
# Checking date: 2022-07-14 00:00:00
# Check indexing: [13272] [13608] [22032] [22199] [22200]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 195...
# Checking date: 2022-07-15 00:00:00
# Check indexing: [13296] [13632] [22056] [22223] [22224]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 196...
# Checking date: 2022-07-16 00:00:00
# Check indexing: [13320] [13656] [22080] [22247] [22248]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 197...
# Checking date: 2022-07-17 00:00:00
# Check indexing: [13344] [13680] [22104] [22271] [22272]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 198...
# Checking date: 2022-07-18 00:00:00
# Check indexing: [13368] [13704] [22128] [22295] [22296]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 199...
# Checking date: 2022-07-19 00:00:00
# Check indexing: [13392] [13728] [22152] [22319] [22320]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 200...
# Checking date: 2022-07-20 00:00:00
# Check indexing: [13416] [13752] [22176] [22343] [22344]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 201...
# Checking date: 2022-07-21 00:00:00
# Check indexing: [13440] [13776] [22200] [22367] [22368]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 202...
# Checking date: 2022-07-22 00:00:00
# Check indexing: [13464] [13800] [22224] [22391] [22392]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 203...
# Checking date: 2022-07-23 00:00:00
# Check indexing: [13488] [13824] [22248] [22415] [22416]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 204...
# Checking date: 2022-07-24 00:00:00
# Check indexing: [13512] [13848] [22272] [22439] [22440]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 205...
# Checking date: 2022-07-25 00:00:00
# Check indexing: [13536] [13872] [22296] [22463] [22464]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 206...
# Checking date: 2022-07-26 00:00:00
# Check indexing: [13560] [13896] [22320] [22487] [22488]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 207...
# Checking date: 2022-07-27 00:00:00
# Check indexing: [13584] [13920] [22344] [22511] [22512]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 208...
# Checking date: 2022-07-28 00:00:00
# Check indexing: [13608] [13944] [22368] [22535] [22536]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 209...
# Checking date: 2022-07-29 00:00:00
# Check indexing: [13632] [13968] [22392] [22559] [22560]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 210...
# Checking date: 2022-07-30 00:00:00
# Check indexing: [13656] [13992] [22416] [22583] [22584]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 211...
# Checking date: 2022-07-31 00:00:00
# Check indexing: [13680] [14016] [22440] [22607] [22608]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 212...
# Checking date: 2022-08-01 00:00:00
# Check indexing: [13704] [14040] [22464] [22631] [22632]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 213...
# Checking date: 2022-08-02 00:00:00
# Check indexing: [13728] [14064] [22488] [22655] [22656]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 214...
# Checking date: 2022-08-03 00:00:00
# Check indexing: [13752] [14088] [22512] [22679] [22680]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 215...
# Checking date: 2022-08-04 00:00:00
# Check indexing: [13776] [14112] [22536] [22703] [22704]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 216...
# Checking date: 2022-08-05 00:00:00
# Check indexing: [13800] [14136] [22560] [22727] [22728]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 217...
# Checking date: 2022-08-06 00:00:00
# Check indexing: [13824] [14160] [22584] [22751] [22752]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 218...
# Checking date: 2022-08-07 00:00:00
# Check indexing: [13848] [14184] [22608] [22775] [22776]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 219...
# Checking date: 2022-08-08 00:00:00
# Check indexing: [13872] [14208] [22632] [22799] [22800]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 220...
# Checking date: 2022-08-09 00:00:00
# Check indexing: [13896] [14232] [22656] [22823] [22824]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 221...
# Checking date: 2022-08-10 00:00:00
# Check indexing: [13920] [14256] [22680] [22847] [22848]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 222...
# Checking date: 2022-08-11 00:00:00
# Check indexing: [13944] [14280] [22704] [22871] [22872]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 223...
# Checking date: 2022-08-12 00:00:00
# Check indexing: [13968] [14304] [22728] [22895] [22896]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 224...
# Checking date: 2022-08-13 00:00:00
# Check indexing: [13992] [14328] [22752] [22919] [22920]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 225...
# Checking date: 2022-08-14 00:00:00
# Check indexing: [14016] [14352] [22776] [22943] [22944]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 226...
# Checking date: 2022-08-15 00:00:00
# Check indexing: [14040] [14376] [22800] [22967] [22968]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 227...
# Checking date: 2022-08-16 00:00:00
# Check indexing: [14064] [14400] [22824] [22991] [22992]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 228...
# Checking date: 2022-08-17 00:00:00
# Check indexing: [14088] [14424] [22848] [23015] [23016]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 229...
# Checking date: 2022-08-18 00:00:00
# Check indexing: [14112] [14448] [22872] [23039] [23040]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 230...
# Checking date: 2022-08-19 00:00:00
# Check indexing: [14136] [14472] [22896] [23063] [23064]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 231...
# Checking date: 2022-08-20 00:00:00
# Check indexing: [14160] [14496] [22920] [23087] [23088]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 232...
# Checking date: 2022-08-21 00:00:00
# Check indexing: [14184] [14520] [22944] [23111] [23112]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 233...
# Checking date: 2022-08-22 00:00:00
# Check indexing: [14208] [14544] [22968] [23135] [23136]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 234...
# Checking date: 2022-08-23 00:00:00
# Check indexing: [14232] [14568] [22992] [23159] [23160]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 235...
# Checking date: 2022-08-24 00:00:00
# Check indexing: [14256] [14592] [23016] [23183] [23184]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 236...
# Checking date: 2022-08-25 00:00:00
# Check indexing: [14280] [14616] [23040] [23207] [23208]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 237...
# Checking date: 2022-08-26 00:00:00
# Check indexing: [14304] [14640] [23064] [23231] [23232]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 238...
# Checking date: 2022-08-27 00:00:00
# Check indexing: [14328] [14664] [23088] [23255] [23256]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 239...
# Checking date: 2022-08-28 00:00:00
# Check indexing: [14352] [14688] [23112] [23279] [23280]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 240...
# Checking date: 2022-08-29 00:00:00
# Check indexing: [14376] [14712] [23136] [23303] [23304]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 241...
# Checking date: 2022-08-30 00:00:00
# Check indexing: [14400] [14736] [23160] [23327] [23328]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 242...
# Checking date: 2022-08-31 00:00:00
# Check indexing: [14424] [14760] [23184] [23351] [23352]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 243...
# Checking date: 2022-09-01 00:00:00
# Check indexing: [14448] [14784] [23208] [23375] [23376]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 244...
# Checking date: 2022-09-02 00:00:00
# Check indexing: [14472] [14808] [23232] [23399] [23400]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 245...
# Checking date: 2022-09-03 00:00:00
# Check indexing: [14496] [14832] [23256] [23423] [23424]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 246...
# Checking date: 2022-09-04 00:00:00
# Check indexing: [14520] [14856] [23280] [23447] [23448]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 247...
# Checking date: 2022-09-05 00:00:00
# Check indexing: [14544] [14880] [23304] [23471] [23472]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 248...
# Checking date: 2022-09-06 00:00:00
# Check indexing: [14568] [14904] [23328] [23495] [23496]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 249...
# Checking date: 2022-09-07 00:00:00
# Check indexing: [14592] [14928] [23352] [23519] [23520]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 250...
# Checking date: 2022-09-08 00:00:00
# Check indexing: [14616] [14952] [23376] [23543] [23544]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 251...
# Checking date: 2022-09-09 00:00:00
# Check indexing: [14640] [14976] [23400] [23567] [23568]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 252...
# Checking date: 2022-09-10 00:00:00
# Check indexing: [14664] [15000] [23424] [23591] [23592]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 253...
# Checking date: 2022-09-11 00:00:00
# Check indexing: [14688] [15024] [23448] [23615] [23616]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 254...
# Checking date: 2022-09-12 00:00:00
# Check indexing: [14712] [15048] [23472] [23639] [23640]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 255...
# Checking date: 2022-09-13 00:00:00
# Check indexing: [14736] [15072] [23496] [23663] [23664]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 256...
# Checking date: 2022-09-14 00:00:00
# Check indexing: [14760] [15096] [23520] [23687] [23688]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 257...
# Checking date: 2022-09-15 00:00:00
# Check indexing: [14784] [15120] [23544] [23711] [23712]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 258...
# Checking date: 2022-09-16 00:00:00
# Check indexing: [14808] [15144] [23568] [23735] [23736]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 259...
# Checking date: 2022-09-17 00:00:00
# Check indexing: [14832] [15168] [23592] [23759] [23760]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 260...
# Checking date: 2022-09-18 00:00:00
# ...
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 553...
# Checking date: 2023-07-08 00:00:00
# Check indexing: [21888] [22224] [30648] [30815] [30816]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 554...
# Checking date: 2023-07-09 00:00:00
# Check indexing: [21912] [22248] [30672] [30839] [30840]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 555...
# Checking date: 2023-07-10 00:00:00
# Check indexing: [21936] [22272] [30696] [30863] [30864]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 556...
# Checking date: 2023-07-11 00:00:00
# Check indexing: [21960] [22296] [30720] [30887] [30888]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 557...
# Checking date: 2023-07-12 00:00:00
# Check indexing: [21984] [22320] [30744] [30911] [30912]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 558...
# Checking date: 2023-07-13 00:00:00
# Check indexing: [22008] [22344] [30768] [30935] [30936]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 559...
# Checking date: 2023-07-14 00:00:00
# Check indexing: [22032] [22368] [30792] [30959] [30960]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 560...
# Checking date: 2023-07-15 00:00:00
# Check indexing: [22056] [22392] [30816] [30983] [30984]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 561...
# Checking date: 2023-07-16 00:00:00
# Check indexing: [22080] [22416] [30840] [31007] [31008]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 562...
# Checking date: 2023-07-17 00:00:00
# Check indexing: [22104] [22440] [30864] [31031] [31032]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 563...
# Checking date: 2023-07-18 00:00:00
# Check indexing: [22128] [22464] [30888] [31055] [31056]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 564...
# Checking date: 2023-07-19 00:00:00
# Check indexing: [22152] [22488] [30912] [31079] [31080]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 565...
# Checking date: 2023-07-20 00:00:00
# Check indexing: [22176] [22512] [30936] [31103] [31104]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 566...
# Checking date: 2023-07-21 00:00:00
# Check indexing: [22200] [22536] [30960] [31127] [31128]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 567...
# Checking date: 2023-07-22 00:00:00
# Check indexing: [22224] [22560] [30984] [31151] [31152]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 568...
# Checking date: 2023-07-23 00:00:00
# Check indexing: [22248] [22584] [31008] [31175] [31176]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 569...
# Checking date: 2023-07-24 00:00:00
# Check indexing: [22272] [22608] [31032] [31199] [31200]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 570...
# Checking date: 2023-07-25 00:00:00
# Check indexing: [22296] [22632] [31056] [31223] [31224]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 571...
# Checking date: 2023-07-26 00:00:00
# Check indexing: [22320] [22656] [31080] [31247] [31248]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 572...
# Checking date: 2023-07-27 00:00:00
# Check indexing: [22344] [22680] [31104] [31271] [31272]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 573...
# Checking date: 2023-07-28 00:00:00
# Check indexing: [22368] [22704] [31128] [31295] [31296]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 574...
# Checking date: 2023-07-29 00:00:00
# Check indexing: [22392] [22728] [31152] [31319] [31320]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 575...
# Checking date: 2023-07-30 00:00:00
# Check indexing: [22416] [22752] [31176] [31343] [31344]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 576...
# Checking date: 2023-07-31 00:00:00
# Check indexing: [22440] [22776] [31200] [31367] [31368]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 577...
# Checking date: 2023-08-01 00:00:00
# Check indexing: [22464] [22800] [31224] [31391] [31392]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 578...
# Checking date: 2023-08-02 00:00:00
# Check indexing: [22488] [22824] [31248] [31415] [31416]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 579...
# Checking date: 2023-08-03 00:00:00
# Check indexing: [22512] [22848] [31272] [31439] [31440]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 580...
# Checking date: 2023-08-04 00:00:00
# Check indexing: [22536] [22872] [31296] [31463] [31464]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 581...
# Checking date: 2023-08-05 00:00:00
# Check indexing: [22560] [22896] [31320] [31487] [31488]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 582...
# Checking date: 2023-08-06 00:00:00
# Check indexing: [22584] [22920] [31344] [31511] [31512]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 583...
# Checking date: 2023-08-07 00:00:00
# Check indexing: [22608] [22944] [31368] [31535] [31536]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 584...
# Checking date: 2023-08-08 00:00:00
# Check indexing: [22632] [22968] [31392] [31559] [31560]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 585...
# Checking date: 2023-08-09 00:00:00
# Check indexing: [22656] [22992] [31416] [31583] [31584]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 586...
# Checking date: 2023-08-10 00:00:00
# Check indexing: [22680] [23016] [31440] [31607] [31608]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 587...
# Checking date: 2023-08-11 00:00:00
# Check indexing: [22704] [23040] [31464] [31631] [31632]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 588...
# Checking date: 2023-08-12 00:00:00
# Check indexing: [22728] [23064] [31488] [31655] [31656]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 589...
# Checking date: 2023-08-13 00:00:00
# Check indexing: [22752] [23088] [31512] [31679] [31680]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 590...
# Checking date: 2023-08-14 00:00:00
# Check indexing: [22776] [23112] [31536] [31703] [31704]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 591...
# Checking date: 2023-08-15 00:00:00
# Check indexing: [22800] [23136] [31560] [31727] [31728]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 592...
# Checking date: 2023-08-16 00:00:00
# Check indexing: [22824] [23160] [31584] [31751] [31752]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 593...
# Checking date: 2023-08-17 00:00:00
# Check indexing: [22848] [23184] [31608] [31775] [31776]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 594...
# Checking date: 2023-08-18 00:00:00
# Check indexing: [22872] [23208] [31632] [31799] [31800]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 595...
# Checking date: 2023-08-19 00:00:00
# Check indexing: [22896] [23232] [31656] [31823] [31824]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 596...
# Checking date: 2023-08-20 00:00:00
# Check indexing: [22920] [23256] [31680] [31847] [31848]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 597...
# Checking date: 2023-08-21 00:00:00
# Check indexing: [22944] [23280] [31704] [31871] [31872]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 598...
# Checking date: 2023-08-22 00:00:00
# Check indexing: [22968] [23304] [31728] [31895] [31896]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 599...
# Checking date: 2023-08-23 00:00:00
# Check indexing: [22992] [23328] [31752] [31919] [31920]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 600...
# Checking date: 2023-08-24 00:00:00
# Check indexing: [23016] [23352] [31776] [31943] [31944]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 601...
# Checking date: 2023-08-25 00:00:00
# Check indexing: [23040] [23376] [31800] [31967] [31968]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 602...
# Checking date: 2023-08-26 00:00:00
# Check indexing: [23064] [23400] [31824] [31991] [31992]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 603...
# Checking date: 2023-08-27 00:00:00
# Check indexing: [23088] [23424] [31848] [32015] [32016]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 604...
# Checking date: 2023-08-28 00:00:00
# Check indexing: [23112] [23448] [31872] [32039] [32040]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 605...
# Checking date: 2023-08-29 00:00:00
# Check indexing: [23136] [23472] [31896] [32063] [32064]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 606...
# Checking date: 2023-08-30 00:00:00
# Check indexing: [23160] [23496] [31920] [32087] [32088]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 607...
# Checking date: 2023-08-31 00:00:00
# Check indexing: [23184] [23520] [31944] [32111] [32112]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 608...
# Checking date: 2023-09-01 00:00:00
# Check indexing: [23208] [23544] [31968] [32135] [32136]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 609...
# Checking date: 2023-09-02 00:00:00
# Check indexing: [23232] [23568] [31992] [32159] [32160]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 610...
# Checking date: 2023-09-03 00:00:00
# Check indexing: [23256] [23592] [32016] [32183] [32184]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 611...
# Checking date: 2023-09-04 00:00:00
# Check indexing: [23280] [23616] [32040] [32207] [32208]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 612...
# Checking date: 2023-09-05 00:00:00
# Check indexing: [23304] [23640] [32064] [32231] [32232]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 613...
# Checking date: 2023-09-06 00:00:00
# Check indexing: [23328] [23664] [32088] [32255] [32256]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 614...
# Checking date: 2023-09-07 00:00:00
# Check indexing: [23352] [23688] [32112] [32279] [32280]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 615...
# Checking date: 2023-09-08 00:00:00
# Check indexing: [23376] [23712] [32136] [32303] [32304]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 616...
# Checking date: 2023-09-09 00:00:00
# Check indexing: [23400] [23736] [32160] [32327] [32328]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 617...
# Checking date: 2023-09-10 00:00:00
# Check indexing: [23424] [23760] [32184] [32351] [32352]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 618...
# Checking date: 2023-09-11 00:00:00
# Check indexing: [23448] [23784] [32208] [32375] [32376]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 619...
# Checking date: 2023-09-12 00:00:00
# Check indexing: [23472] [23808] [32232] [32399] [32400]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 620...
# Checking date: 2023-09-13 00:00:00
# Check indexing: [23496] [23832] [32256] [32423] [32424]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 621...
# Checking date: 2023-09-14 00:00:00
# Check indexing: [23520] [23856] [32280] [32447] [32448]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 622...
# Checking date: 2023-09-15 00:00:00
# Check indexing: [23544] [23880] [32304] [32471] [32472]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 623...
# Checking date: 2023-09-16 00:00:00
# Check indexing: [23568] [23904] [32328] [32495] [32496]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 624...
# Checking date: 2023-09-17 00:00:00
# Check indexing: [23592] [23928] [32352] [32519] [32520]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 625...
# Checking date: 2023-09-18 00:00:00
# Check indexing: [23616] [23952] [32376] [32543] [32544]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 626...
# Checking date: 2023-09-19 00:00:00
# Check indexing: [23640] [23976] [32400] [32567] [32568]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 627...
# Checking date: 2023-09-20 00:00:00
# Check indexing: [23664] [24000] [32424] [32591] [32592]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 628...
# Checking date: 2023-09-21 00:00:00
# Check indexing: [23688] [24024] [32448] [32615] [32616]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 629...
# Checking date: 2023-09-22 00:00:00
# Check indexing: [23712] [24048] [32472] [32639] [32640]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 630...
# Checking date: 2023-09-23 00:00:00
# Check indexing: [23736] [24072] [32496] [32663] [32664]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 631...
# Checking date: 2023-09-24 00:00:00
# Check indexing: [23760] [24096] [32520] [32687] [32688]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 632...
# Checking date: 2023-09-25 00:00:00
# Check indexing: [23784] [24120] [32544] [32711] [32712]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 633...
# Checking date: 2023-09-26 00:00:00
# Check indexing: [23808] [24144] [32568] [32735] [32736]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 634...
# Checking date: 2023-09-27 00:00:00
# Check indexing: [23832] [24168] [32592] [32759] [32760]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 635...
# Checking date: 2023-09-28 00:00:00
# Check indexing: [23856] [24192] [32616] [32783] [32784]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 636...
# Checking date: 2023-09-29 00:00:00
# Check indexing: [23880] [24216] [32640] [32807] [32808]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 637...
# Checking date: 2023-09-30 00:00:00
# Check indexing: [23904] [24240] [32664] [32831] [32832]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 638...
# Checking date: 2023-10-01 00:00:00
# Check indexing: [23928] [24264] [32688] [32855] [32856]
# Feature shape: (2020,)
# Target shape: (1,)
# Done!

# %%
print(x_heat.shape)
print(y_heat.shape)
# Out:
# (639, 2020)
# (639, 1)

# %%
x_train_heat, x_test_heat, y_train_heat, y_test_heat = train_test_split(x_heat, y_heat, test_size=0.2, random_state=0)

# %%
heat_model = SVC()
heat_model.fit(x_train_heat, y_train_heat)
y_pred_heat = heat_model.predict(x_test_heat)
print(accuracy_score(y_test_heat, y_pred_heat))
print(f1_score(y_test_heat, y_pred_heat))
# Out:
# 1.0
# 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))

# %%
confusion_matrix(y_test_heat, y_pred_heat)
# Out:
# array([[128]])

# %%
x_rain, y_rain = get_train_test_data('2022-01-01 00:00:00', '2023-10-01 23:00:00', columns_rain, target_rain)
x_rain = np.array(x_rain)
y_rain = np.array(y_rain).astype('int')
x_train_rain, x_test_rain, y_train_rain, y_test_rain = train_test_split(x_rain, y_rain, test_size=0.2, random_state=0)
# Out:
# ----------------------------------
# Get 0...
# Checking date: 2022-01-01 00:00:00
# Check indexing: [8616] [8952] [17376] [17543] [17544]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1...
# Checking date: 2022-01-02 00:00:00
# Check indexing: [8640] [8976] [17400] [17567] [17568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2...
# Checking date: 2022-01-03 00:00:00
# Check indexing: [8664] [9000] [17424] [17591] [17592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 3...
# Checking date: 2022-01-04 00:00:00
# Check indexing: [8688] [9024] [17448] [17615] [17616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 4...
# Checking date: 2022-01-05 00:00:00
# Check indexing: [8712] [9048] [17472] [17639] [17640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 5...
# Checking date: 2022-01-06 00:00:00
# Check indexing: [8736] [9072] [17496] [17663] [17664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 6...
# Checking date: 2022-01-07 00:00:00
# Check indexing: [8760] [9096] [17520] [17687] [17688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 7...
# Checking date: 2022-01-08 00:00:00
# Check indexing: [8784] [9120] [17544] [17711] [17712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 8...
# Checking date: 2022-01-09 00:00:00
# Check indexing: [8808] [9144] [17568] [17735] [17736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 9...
# Checking date: 2022-01-10 00:00:00
# Check indexing: [8832] [9168] [17592] [17759] [17760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 10...
# Checking date: 2022-01-11 00:00:00
# Check indexing: [8856] [9192] [17616] [17783] [17784]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 11...
# Checking date: 2022-01-12 00:00:00
# Check indexing: [8880] [9216] [17640] [17807] [17808]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 12...
# Checking date: 2022-01-13 00:00:00
# Check indexing: [8904] [9240] [17664] [17831] [17832]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 13...
# Checking date: 2022-01-14 00:00:00
# Check indexing: [8928] [9264] [17688] [17855] [17856]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 14...
# Checking date: 2022-01-15 00:00:00
# Check indexing: [8952] [9288] [17712] [17879] [17880]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 15...
# Checking date: 2022-01-16 00:00:00
# Check indexing: [8976] [9312] [17736] [17903] [17904]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 16...
# Checking date: 2022-01-17 00:00:00
# Check indexing: [9000] [9336] [17760] [17927] [17928]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 17...
# Checking date: 2022-01-18 00:00:00
# Check indexing: [9024] [9360] [17784] [17951] [17952]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 18...
# Checking date: 2022-01-19 00:00:00
# Check indexing: [9048] [9384] [17808] [17975] [17976]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 19...
# Checking date: 2022-01-20 00:00:00
# Check indexing: [9072] [9408] [17832] [17999] [18000]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 20...
# Checking date: 2022-01-21 00:00:00
# Check indexing: [9096] [9432] [17856] [18023] [18024]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 21...
# Checking date: 2022-01-22 00:00:00
# Check indexing: [9120] [9456] [17880] [18047] [18048]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 22...
# Checking date: 2022-01-23 00:00:00
# Check indexing: [9144] [9480] [17904] [18071] [18072]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 23...
# Checking date: 2022-01-24 00:00:00
# Check indexing: [9168] [9504] [17928] [18095] [18096]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 24...
# Checking date: 2022-01-25 00:00:00
# Check indexing: [9192] [9528] [17952] [18119] [18120]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 25...
# Checking date: 2022-01-26 00:00:00
# Check indexing: [9216] [9552] [17976] [18143] [18144]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 26...
# Checking date: 2022-01-27 00:00:00
# Check indexing: [9240] [9576] [18000] [18167] [18168]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 27...
# Checking date: 2022-01-28 00:00:00
# Check indexing: [9264] [9600] [18024] [18191] [18192]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 28...
# Checking date: 2022-01-29 00:00:00
# Check indexing: [9288] [9624] [18048] [18215] [18216]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 29...
# Checking date: 2022-01-30 00:00:00
# Check indexing: [9312] [9648] [18072] [18239] [18240]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 30...
# Checking date: 2022-01-31 00:00:00
# Check indexing: [9336] [9672] [18096] [18263] [18264]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 31...
# Checking date: 2022-02-01 00:00:00
# Check indexing: [9360] [9696] [18120] [18287] [18288]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 32...
# Checking date: 2022-02-02 00:00:00
# Check indexing: [9384] [9720] [18144] [18311] [18312]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 33...
# Checking date: 2022-02-03 00:00:00
# Check indexing: [9408] [9744] [18168] [18335] [18336]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 34...
# Checking date: 2022-02-04 00:00:00
# Check indexing: [9432] [9768] [18192] [18359] [18360]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 35...
# Checking date: 2022-02-05 00:00:00
# Check indexing: [9456] [9792] [18216] [18383] [18384]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 36...
# Checking date: 2022-02-06 00:00:00
# Check indexing: [9480] [9816] [18240] [18407] [18408]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 37...
# Checking date: 2022-02-07 00:00:00
# Check indexing: [9504] [9840] [18264] [18431] [18432]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 38...
# Checking date: 2022-02-08 00:00:00
# Check indexing: [9528] [9864] [18288] [18455] [18456]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 39...
# Checking date: 2022-02-09 00:00:00
# Check indexing: [9552] [9888] [18312] [18479] [18480]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 40...
# Checking date: 2022-02-10 00:00:00
# Check indexing: [9576] [9912] [18336] [18503] [18504]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 41...
# Checking date: 2022-02-11 00:00:00
# Check indexing: [9600] [9936] [18360] [18527] [18528]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 42...
# Checking date: 2022-02-12 00:00:00
# Check indexing: [9624] [9960] [18384] [18551] [18552]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 43...
# Checking date: 2022-02-13 00:00:00
# Check indexing: [9648] [9984] [18408] [18575] [18576]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 44...
# Checking date: 2022-02-14 00:00:00
# Check indexing: [9672] [10008] [18432] [18599] [18600]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 45...
# Checking date: 2022-02-15 00:00:00
# Check indexing: [9696] [10032] [18456] [18623] [18624]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 46...
# Checking date: 2022-02-16 00:00:00
# Check indexing: [9720] [10056] [18480] [18647] [18648]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 47...
# Checking date: 2022-02-17 00:00:00
# Check indexing: [9744] [10080] [18504] [18671] [18672]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 48...
# Checking date: 2022-02-18 00:00:00
# Check indexing: [9768] [10104] [18528] [18695] [18696]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 49...
# Checking date: 2022-02-19 00:00:00
# Check indexing: [9792] [10128] [18552] [18719] [18720]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 50...
# Checking date: 2022-02-20 00:00:00
# Check indexing: [9816] [10152] [18576] [18743] [18744]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 51...
# Checking date: 2022-02-21 00:00:00
# Check indexing: [9840] [10176] [18600] [18767] [18768]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 52...
# Checking date: 2022-02-22 00:00:00
# Check indexing: [9864] [10200] [18624] [18791] [18792]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 53...
# Checking date: 2022-02-23 00:00:00
# Check indexing: [9888] [10224] [18648] [18815] [18816]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 54...
# Checking date: 2022-02-24 00:00:00
# Check indexing: [9912] [10248] [18672] [18839] [18840]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 55...
# Checking date: 2022-02-25 00:00:00
# Check indexing: [9936] [10272] [18696] [18863] [18864]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 56...
# Checking date: 2022-02-26 00:00:00
# Check indexing: [9960] [10296] [18720] [18887] [18888]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 57...
# Checking date: 2022-02-27 00:00:00
# Check indexing: [9984] [10320] [18744] [18911] [18912]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 58...
# Checking date: 2022-02-28 00:00:00
# Check indexing: [10008] [10344] [18768] [18935] [18936]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 59...
# Checking date: 2022-03-01 00:00:00
# Check indexing: [10032] [10368] [18792] [18959] [18960]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 60...
# Checking date: 2022-03-02 00:00:00
# Check indexing: [10056] [10392] [18816] [18983] [18984]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 61...
# Checking date: 2022-03-03 00:00:00
# Check indexing: [10080] [10416] [18840] [19007] [19008]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 62...
# Checking date: 2022-03-04 00:00:00
# Check indexing: [10104] [10440] [18864] [19031] [19032]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 63...
# Checking date: 2022-03-05 00:00:00
# Check indexing: [10128] [10464] [18888] [19055] [19056]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 64...
# Checking date: 2022-03-06 00:00:00
# Check indexing: [10152] [10488] [18912] [19079] [19080]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 65...
# Checking date: 2022-03-07 00:00:00
# Check indexing: [10176] [10512] [18936] [19103] [19104]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 66...
# Checking date: 2022-03-08 00:00:00
# Check indexing: [10200] [10536] [18960] [19127] [19128]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 67...
# Checking date: 2022-03-09 00:00:00
# Check indexing: [10224] [10560] [18984] [19151] [19152]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 68...
# Checking date: 2022-03-10 00:00:00
# Check indexing: [10248] [10584] [19008] [19175] [19176]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 69...
# Checking date: 2022-03-11 00:00:00
# Check indexing: [10272] [10608] [19032] [19199] [19200]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 70...
# Checking date: 2022-03-12 00:00:00
# Check indexing: [10296] [10632] [19056] [19223] [19224]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 71...
# Checking date: 2022-03-13 00:00:00
# Check indexing: [10320] [10656] [19080] [19247] [19248]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 72...
# Checking date: 2022-03-14 00:00:00
# Check indexing: [10344] [10680] [19104] [19271] [19272]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 73...
# Checking date: 2022-03-15 00:00:00
# Check indexing: [10368] [10704] [19128] [19295] [19296]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 74...
# Checking date: 2022-03-16 00:00:00
# Check indexing: [10392] [10728] [19152] [19319] [19320]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 75...
# Checking date: 2022-03-17 00:00:00
# Check indexing: [10416] [10752] [19176] [19343] [19344]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 76...
# Checking date: 2022-03-18 00:00:00
# Check indexing: [10440] [10776] [19200] [19367] [19368]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 77...
# Checking date: 2022-03-19 00:00:00
# Check indexing: [10464] [10800] [19224] [19391] [19392]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 78...
# Checking date: 2022-03-20 00:00:00
# Check indexing: [10488] [10824] [19248] [19415] [19416]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 79...
# Checking date: 2022-03-21 00:00:00
# Check indexing: [10512] [10848] [19272] [19439] [19440]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 80...
# Checking date: 2022-03-22 00:00:00
# Check indexing: [10536] [10872] [19296] [19463] [19464]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 81...
# Checking date: 2022-03-23 00:00:00
# Check indexing: [10560] [10896] [19320] [19487] [19488]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 82...
# Checking date: 2022-03-24 00:00:00
# Check indexing: [10584] [10920] [19344] [19511] [19512]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 83...
# Checking date: 2022-03-25 00:00:00
# Check indexing: [10608] [10944] [19368] [19535] [19536]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 84...
# Checking date: 2022-03-26 00:00:00
# Check indexing: [10632] [10968] [19392] [19559] [19560]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 85...
# Checking date: 2022-03-27 00:00:00
# Check indexing: [10656] [10992] [19416] [19583] [19584]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 86...
# Checking date: 2022-03-28 00:00:00
# Check indexing: [10680] [11016] [19440] [19607] [19608]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 87...
# Checking date: 2022-03-29 00:00:00
# Check indexing: [10704] [11040] [19464] [19631] [19632]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 88...
# Checking date: 2022-03-30 00:00:00
# Check indexing: [10728] [11064] [19488] [19655] [19656]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 89...
# Checking date: 2022-03-31 00:00:00
# Check indexing: [10752] [11088] [19512] [19679] [19680]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 90...
# Checking date: 2022-04-01 00:00:00
# Check indexing: [10776] [11112] [19536] [19703] [19704]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 91...
# Checking date: 2022-04-02 00:00:00
# Check indexing: [10800] [11136] [19560] [19727] [19728]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 92...
# Checking date: 2022-04-03 00:00:00
# Check indexing: [10824] [11160] [19584] [19751] [19752]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 93...
# Checking date: 2022-04-04 00:00:00
# Check indexing: [10848] [11184] [19608] [19775] [19776]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 94...
# Checking date: 2022-04-05 00:00:00
# Check indexing: [10872] [11208] [19632] [19799] [19800]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 95...
# Checking date: 2022-04-06 00:00:00
# Check indexing: [10896] [11232] [19656] [19823] [19824]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 96...
# Checking date: 2022-04-07 00:00:00
# Check indexing: [10920] [11256] [19680] [19847] [19848]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 97...
# Checking date: 2022-04-08 00:00:00
# Check indexing: [10944] [11280] [19704] [19871] [19872]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 98...
# Checking date: 2022-04-09 00:00:00
# Check indexing: [10968] [11304] [19728] [19895] [19896]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 99...
# Checking date: 2022-04-10 00:00:00
# Check indexing: [10992] [11328] [19752] [19919] [19920]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 100...
# Checking date: 2022-04-11 00:00:00
# Check indexing: [11016] [11352] [19776] [19943] [19944]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 101...
# Checking date: 2022-04-12 00:00:00
# Check indexing: [11040] [11376] [19800] [19967] [19968]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 102...
# Checking date: 2022-04-13 00:00:00
# Check indexing: [11064] [11400] [19824] [19991] [19992]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 103...
# Checking date: 2022-04-14 00:00:00
# Check indexing: [11088] [11424] [19848] [20015] [20016]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 104...
# Checking date: 2022-04-15 00:00:00
# Check indexing: [11112] [11448] [19872] [20039] [20040]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 105...
# Checking date: 2022-04-16 00:00:00
# Check indexing: [11136] [11472] [19896] [20063] [20064]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 106...
# Checking date: 2022-04-17 00:00:00
# Check indexing: [11160] [11496] [19920] [20087] [20088]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 107...
# Checking date: 2022-04-18 00:00:00
# Check indexing: [11184] [11520] [19944] [20111] [20112]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 108...
# Checking date: 2022-04-19 00:00:00
# Check indexing: [11208] [11544] [19968] [20135] [20136]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 109...
# Checking date: 2022-04-20 00:00:00
# Check indexing: [11232] [11568] [19992] [20159] [20160]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 110...
# Checking date: 2022-04-21 00:00:00
# Check indexing: [11256] [11592] [20016] [20183] [20184]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 111...
# Checking date: 2022-04-22 00:00:00
# Check indexing: [11280] [11616] [20040] [20207] [20208]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 112...
# Checking date: 2022-04-23 00:00:00
# Check indexing: [11304] [11640] [20064] [20231] [20232]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 113...
# Checking date: 2022-04-24 00:00:00
# Check indexing: [11328] [11664] [20088] [20255] [20256]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 114...
# Checking date: 2022-04-25 00:00:00
# Check indexing: [11352] [11688] [20112] [20279] [20280]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 115...
# Checking date: 2022-04-26 00:00:00
# Check indexing: [11376] [11712] [20136] [20303] [20304]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 116...
# Checking date: 2022-04-27 00:00:00
# Check indexing: [11400] [11736] [20160] [20327] [20328]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 117...
# Checking date: 2022-04-28 00:00:00
# Check indexing: [11424] [11760] [20184] [20351] [20352]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 118...
# Checking date: 2022-04-29 00:00:00
# Check indexing: [11448] [11784] [20208] [20375] [20376]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 119...
# Checking date: 2022-04-30 00:00:00
# Check indexing: [11472] [11808] [20232] [20399] [20400]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 120...
# Checking date: 2022-05-01 00:00:00
# Check indexing: [11496] [11832] [20256] [20423] [20424]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 121...
# Checking date: 2022-05-02 00:00:00
# Check indexing: [11520] [11856] [20280] [20447] [20448]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 122...
# Checking date: 2022-05-03 00:00:00
# Check indexing: [11544] [11880] [20304] [20471] [20472]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 123...
# Checking date: 2022-05-04 00:00:00
# Check indexing: [11568] [11904] [20328] [20495] [20496]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 124...
# Checking date: 2022-05-05 00:00:00
# Check indexing: [11592] [11928] [20352] [20519] [20520]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 125...
# Checking date: 2022-05-06 00:00:00
# Check indexing: [11616] [11952] [20376] [20543] [20544]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 126...
# Checking date: 2022-05-07 00:00:00
# Check indexing: [11640] [11976] [20400] [20567] [20568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 127...
# Checking date: 2022-05-08 00:00:00
# Check indexing: [11664] [12000] [20424] [20591] [20592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 128...
# Checking date: 2022-05-09 00:00:00
# Check indexing: [11688] [12024] [20448] [20615] [20616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 129...
# Checking date: 2022-05-10 00:00:00
# Check indexing: [11712] [12048] [20472] [20639] [20640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 130...
# Checking date: 2022-05-11 00:00:00
# Check indexing: [11736] [12072] [20496] [20663] [20664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 131...
# Checking date: 2022-05-12 00:00:00
# Check indexing: [11760] [12096] [20520] [20687] [20688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 132...
# Checking date: 2022-05-13 00:00:00
# Check indexing: [11784] [12120] [20544] [20711] [20712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 133...
# Checking date: 2022-05-14 00:00:00
# Check indexing: [11808] [12144] [20568] [20735] [20736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 134...
# Checking date: 2022-05-15 00:00:00
# Check indexing: [11832] [12168] [20592] [20759] [20760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 135...
# Checking date: 2022-05-16 00:00:00
# Check indexing: [11856] [12192] [20616] [20783] [20784]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 136...
# Checking date: 2022-05-17 00:00:00
# Check indexing: [11880] [12216] [20640] [20807] [20808]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 137...
# Checking date: 2022-05-18 00:00:00
# Check indexing: [11904] [12240] [20664] [20831] [20832]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 138...
# Checking date: 2022-05-19 00:00:00
# Check indexing: [11928] [12264] [20688] [20855] [20856]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 139...
# Checking date: 2022-05-20 00:00:00
# Check indexing: [11952] [12288] [20712] [20879] [20880]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 140...
# Checking date: 2022-05-21 00:00:00
# Check indexing: [11976] [12312] [20736] [20903] [20904]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 141...
# Checking date: 2022-05-22 00:00:00
# Check indexing: [12000] [12336] [20760] [20927] [20928]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 142...
# Checking date: 2022-05-23 00:00:00
# Check indexing: [12024] [12360] [20784] [20951] [20952]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 143...
# Checking date: 2022-05-24 00:00:00
# Check indexing: [12048] [12384] [20808] [20975] [20976]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 144...
# Checking date: 2022-05-25 00:00:00
# Check indexing: [12072] [12408] [20832] [20999] [21000]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 145...
# Checking date: 2022-05-26 00:00:00
# Check indexing: [12096] [12432] [20856] [21023] [21024]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 146...
# Checking date: 2022-05-27 00:00:00
# Check indexing: [12120] [12456] [20880] [21047] [21048]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 147...
# Checking date: 2022-05-28 00:00:00
# Check indexing: [12144] [12480] [20904] [21071] [21072]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 148...
# Checking date: 2022-05-29 00:00:00
# Check indexing: [12168] [12504] [20928] [21095] [21096]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 149...
# Checking date: 2022-05-30 00:00:00
# Check indexing: [12192] [12528] [20952] [21119] [21120]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 150...
# Checking date: 2022-05-31 00:00:00
# Check indexing: [12216] [12552] [20976] [21143] [21144]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 151...
# Checking date: 2022-06-01 00:00:00
# Check indexing: [12240] [12576] [21000] [21167] [21168]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 152...
# Checking date: 2022-06-02 00:00:00
# Check indexing: [12264] [12600] [21024] [21191] [21192]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 153...
# Checking date: 2022-06-03 00:00:00
# Check indexing: [12288] [12624] [21048] [21215] [21216]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 154...
# Checking date: 2022-06-04 00:00:00
# Check indexing: [12312] [12648] [21072] [21239] [21240]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 155...
# Checking date: 2022-06-05 00:00:00
# Check indexing: [12336] [12672] [21096] [21263] [21264]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 156...
# Checking date: 2022-06-06 00:00:00
# Check indexing: [12360] [12696] [21120] [21287] [21288]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 157...
# Checking date: 2022-06-07 00:00:00
# Check indexing: [12384] [12720] [21144] [21311] [21312]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 158...
# Checking date: 2022-06-08 00:00:00
# Check indexing: [12408] [12744] [21168] [21335] [21336]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 159...
# Checking date: 2022-06-09 00:00:00
# Check indexing: [12432] [12768] [21192] [21359] [21360]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 160...
# Checking date: 2022-06-10 00:00:00
# Check indexing: [12456] [12792] [21216] [21383] [21384]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 161...
# Checking date: 2022-06-11 00:00:00
# Check indexing: [12480] [12816] [21240] [21407] [21408]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 162...
# Checking date: 2022-06-12 00:00:00
# Check indexing: [12504] [12840] [21264] [21431] [21432]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 163...
# Checking date: 2022-06-13 00:00:00
# Check indexing: [12528] [12864] [21288] [21455] [21456]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 164...
# Checking date: 2022-06-14 00:00:00
# Check indexing: [12552] [12888] [21312] [21479] [21480]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 165...
# Checking date: 2022-06-15 00:00:00
# Check indexing: [12576] [12912] [21336] [21503] [21504]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 166...
# Checking date: 2022-06-16 00:00:00
# Check indexing: [12600] [12936] [21360] [21527] [21528]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 167...
# Checking date: 2022-06-17 00:00:00
# Check indexing: [12624] [12960] [21384] [21551] [21552]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 168...
# Checking date: 2022-06-18 00:00:00
# Check indexing: [12648] [12984] [21408] [21575] [21576]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 169...
# Checking date: 2022-06-19 00:00:00
# Check indexing: [12672] [13008] [21432] [21599] [21600]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 170...
# Checking date: 2022-06-20 00:00:00
# Check indexing: [12696] [13032] [21456] [21623] [21624]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 171...
# Checking date: 2022-06-21 00:00:00
# Check indexing: [12720] [13056] [21480] [21647] [21648]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 172...
# Checking date: 2022-06-22 00:00:00
# Check indexing: [12744] [13080] [21504] [21671] [21672]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 173...
# Checking date: 2022-06-23 00:00:00
# Check indexing: [12768] [13104] [21528] [21695] [21696]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 174...
# Checking date: 2022-06-24 00:00:00
# Check indexing: [12792] [13128] [21552] [21719] [21720]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 175...
# Checking date: 2022-06-25 00:00:00
# Check indexing: [12816] [13152] [21576] [21743] [21744]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 176...
# Checking date: 2022-06-26 00:00:00
# Check indexing: [12840] [13176] [21600] [21767] [21768]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 177...
# Checking date: 2022-06-27 00:00:00
# Check indexing: [12864] [13200] [21624] [21791] [21792]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 178...
# Checking date: 2022-06-28 00:00:00
# Check indexing: [12888] [13224] [21648] [21815] [21816]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 179...
# Checking date: 2022-06-29 00:00:00
# Check indexing: [12912] [13248] [21672] [21839] [21840]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 180...
# Checking date: 2022-06-30 00:00:00
# Check indexing: [12936] [13272] [21696] [21863] [21864]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 181...
# Checking date: 2022-07-01 00:00:00
# Check indexing: [12960] [13296] [21720] [21887] [21888]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 182...
# Checking date: 2022-07-02 00:00:00
# Check indexing: [12984] [13320] [21744] [21911] [21912]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 183...
# Checking date: 2022-07-03 00:00:00
# Check indexing: [13008] [13344] [21768] [21935] [21936]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 184...
# Checking date: 2022-07-04 00:00:00
# Check indexing: [13032] [13368] [21792] [21959] [21960]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 185...
# Checking date: 2022-07-05 00:00:00
# Check indexing: [13056] [13392] [21816] [21983] [21984]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 186...
# Checking date: 2022-07-06 00:00:00
# Check indexing: [13080] [13416] [21840] [22007] [22008]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 187...
# Checking date: 2022-07-07 00:00:00
# Check indexing: [13104] [13440] [21864] [22031] [22032]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 188...
# Checking date: 2022-07-08 00:00:00
# Check indexing: [13128] [13464] [21888] [22055] [22056]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 189...
# Checking date: 2022-07-09 00:00:00
# Check indexing: [13152] [13488] [21912] [22079] [22080]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 190...
# Checking date: 2022-07-10 00:00:00
# Check indexing: [13176] [13512] [21936] [22103] [22104]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 191...
# Checking date: 2022-07-11 00:00:00
# Check indexing: [13200] [13536] [21960] [22127] [22128]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 192...
# Checking date: 2022-07-12 00:00:00
# Check indexing: [13224] [13560] [21984] [22151] [22152]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 193...
# Checking date: 2022-07-13 00:00:00
# Check indexing: [13248] [13584] [22008] [22175] [22176]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 194...
# Checking date: 2022-07-14 00:00:00
# Check indexing: [13272] [13608] [22032] [22199] [22200]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 195...
# Checking date: 2022-07-15 00:00:00
# Check indexing: [13296] [13632] [22056] [22223] [22224]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 196...
# Checking date: 2022-07-16 00:00:00
# Check indexing: [13320] [13656] [22080] [22247] [22248]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 197...
# Checking date: 2022-07-17 00:00:00
# Check indexing: [13344] [13680] [22104] [22271] [22272]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 198...
# Checking date: 2022-07-18 00:00:00
# Check indexing: [13368] [13704] [22128] [22295] [22296]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 199...
# Checking date: 2022-07-19 00:00:00
# Check indexing: [13392] [13728] [22152] [22319] [22320]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 200...
# Checking date: 2022-07-20 00:00:00
# Check indexing: [13416] [13752] [22176] [22343] [22344]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 201...
# Checking date: 2022-07-21 00:00:00
# Check indexing: [13440] [13776] [22200] [22367] [22368]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 202...
# Checking date: 2022-07-22 00:00:00
# Check indexing: [13464] [13800] [22224] [22391] [22392]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 203...
# Checking date: 2022-07-23 00:00:00
# Check indexing: [13488] [13824] [22248] [22415] [22416]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 204...
# Checking date: 2022-07-24 00:00:00
# Check indexing: [13512] [13848] [22272] [22439] [22440]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 205...
# Checking date: 2022-07-25 00:00:00
# Check indexing: [13536] [13872] [22296] [22463] [22464]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 206...
# Checking date: 2022-07-26 00:00:00
# Check indexing: [13560] [13896] [22320] [22487] [22488]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 207...
# Checking date: 2022-07-27 00:00:00
# Check indexing: [13584] [13920] [22344] [22511] [22512]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 208...
# Checking date: 2022-07-28 00:00:00
# Check indexing: [13608] [13944] [22368] [22535] [22536]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 209...
# Checking date: 2022-07-29 00:00:00
# Check indexing: [13632] [13968] [22392] [22559] [22560]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 210...
# Checking date: 2022-07-30 00:00:00
# Check indexing: [13656] [13992] [22416] [22583] [22584]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 211...
# Checking date: 2022-07-31 00:00:00
# Check indexing: [13680] [14016] [22440] [22607] [22608]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 212...
# Checking date: 2022-08-01 00:00:00
# Check indexing: [13704] [14040] [22464] [22631] [22632]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 213...
# Checking date: 2022-08-02 00:00:00
# Check indexing: [13728] [14064] [22488] [22655] [22656]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 214...
# Checking date: 2022-08-03 00:00:00
# Check indexing: [13752] [14088] [22512] [22679] [22680]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 215...
# Checking date: 2022-08-04 00:00:00
# Check indexing: [13776] [14112] [22536] [22703] [22704]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 216...
# Checking date: 2022-08-05 00:00:00
# Check indexing: [13800] [14136] [22560] [22727] [22728]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 217...
# Checking date: 2022-08-06 00:00:00
# Check indexing: [13824] [14160] [22584] [22751] [22752]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 218...
# Checking date: 2022-08-07 00:00:00
# Check indexing: [13848] [14184] [22608] [22775] [22776]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 219...
# Checking date: 2022-08-08 00:00:00
# Check indexing: [13872] [14208] [22632] [22799] [22800]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 220...
# Checking date: 2022-08-09 00:00:00
# Check indexing: [13896] [14232] [22656] [22823] [22824]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 221...
# Checking date: 2022-08-10 00:00:00
# Check indexing: [13920] [14256] [22680] [22847] [22848]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 222...
# Checking date: 2022-08-11 00:00:00
# Check indexing: [13944] [14280] [22704] [22871] [22872]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 223...
# Checking date: 2022-08-12 00:00:00
# Check indexing: [13968] [14304] [22728] [22895] [22896]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 224...
# Checking date: 2022-08-13 00:00:00
# Check indexing: [13992] [14328] [22752] [22919] [22920]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 225...
# Checking date: 2022-08-14 00:00:00
# Check indexing: [14016] [14352] [22776] [22943] [22944]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 226...
# Checking date: 2022-08-15 00:00:00
# Check indexing: [14040] [14376] [22800] [22967] [22968]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 227...
# Checking date: 2022-08-16 00:00:00
# Check indexing: [14064] [14400] [22824] [22991] [22992]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 228...
# Checking date: 2022-08-17 00:00:00
# Check indexing: [14088] [14424] [22848] [23015] [23016]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 229...
# Checking date: 2022-08-18 00:00:00
# Check indexing: [14112] [14448] [22872] [23039] [23040]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 230...
# Checking date: 2022-08-19 00:00:00
# Check indexing: [14136] [14472] [22896] [23063] [23064]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 231...
# Checking date: 2022-08-20 00:00:00
# Check indexing: [14160] [14496] [22920] [23087] [23088]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 232...
# Checking date: 2022-08-21 00:00:00
# Check indexing: [14184] [14520] [22944] [23111] [23112]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 233...
# Checking date: 2022-08-22 00:00:00
# Check indexing: [14208] [14544] [22968] [23135] [23136]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 234...
# Checking date: 2022-08-23 00:00:00
# Check indexing: [14232] [14568] [22992] [23159] [23160]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 235...
# Checking date: 2022-08-24 00:00:00
# Check indexing: [14256] [14592] [23016] [23183] [23184]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 236...
# Checking date: 2022-08-25 00:00:00
# Check indexing: [14280] [14616] [23040] [23207] [23208]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 237...
# Checking date: 2022-08-26 00:00:00
# Check indexing: [14304] [14640] [23064] [23231] [23232]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 238...
# Checking date: 2022-08-27 00:00:00
# Check indexing: [14328] [14664] [23088] [23255] [23256]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 239...
# Checking date: 2022-08-28 00:00:00
# Check indexing: [14352] [14688] [23112] [23279] [23280]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 240...
# Checking date: 2022-08-29 00:00:00
# Check indexing: [14376] [14712] [23136] [23303] [23304]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 241...
# Checking date: 2022-08-30 00:00:00
# Check indexing: [14400] [14736] [23160] [23327] [23328]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 242...
# Checking date: 2022-08-31 00:00:00
# Check indexing: [14424] [14760] [23184] [23351] [23352]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 243...
# Checking date: 2022-09-01 00:00:00
# Check indexing: [14448] [14784] [23208] [23375] [23376]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 244...
# Checking date: 2022-09-02 00:00:00
# Check indexing: [14472] [14808] [23232] [23399] [23400]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 245...
# Checking date: 2022-09-03 00:00:00
# Check indexing: [14496] [14832] [23256] [23423] [23424]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 246...
# Checking date: 2022-09-04 00:00:00
# Check indexing: [14520] [14856] [23280] [23447] [23448]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 247...
# Checking date: 2022-09-05 00:00:00
# Check indexing: [14544] [14880] [23304] [23471] [23472]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 248...
# Checking date: 2022-09-06 00:00:00
# Check indexing: [14568] [14904] [23328] [23495] [23496]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 249...
# Checking date: 2022-09-07 00:00:00
# Check indexing: [14592] [14928] [23352] [23519] [23520]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 250...
# Checking date: 2022-09-08 00:00:00
# Check indexing: [14616] [14952] [23376] [23543] [23544]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 251...
# Checking date: 2022-09-09 00:00:00
# Check indexing: [14640] [14976] [23400] [23567] [23568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 252...
# Checking date: 2022-09-10 00:00:00
# Check indexing: [14664] [15000] [23424] [23591] [23592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 253...
# Checking date: 2022-09-11 00:00:00
# Check indexing: [14688] [15024] [23448] [23615] [23616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 254...
# Checking date: 2022-09-12 00:00:00
# Check indexing: [14712] [15048] [23472] [23639] [23640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 255...
# Checking date: 2022-09-13 00:00:00
# Check indexing: [14736] [15072] [23496] [23663] [23664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 256...
# Checking date: 2022-09-14 00:00:00
# Check indexing: [14760] [15096] [23520] [23687] [23688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 257...
# Checking date: 2022-09-15 00:00:00
# Check indexing: [14784] [15120] [23544] [23711] [23712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 258...
# Checking date: 2022-09-16 00:00:00
# Check indexing: [14808] [15144] [23568] [23735] [23736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 259...
# Checking date: 2022-09-17 00:00:00
# Check indexing: [14832] [15168] [23592] [23759] [23760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 260...
# Checking date: 2022-09-18 00:00:00
# ...
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 553...
# Checking date: 2023-07-08 00:00:00
# Check indexing: [21888] [22224] [30648] [30815] [30816]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 554...
# Checking date: 2023-07-09 00:00:00
# Check indexing: [21912] [22248] [30672] [30839] [30840]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 555...
# Checking date: 2023-07-10 00:00:00
# Check indexing: [21936] [22272] [30696] [30863] [30864]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 556...
# Checking date: 2023-07-11 00:00:00
# Check indexing: [21960] [22296] [30720] [30887] [30888]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 557...
# Checking date: 2023-07-12 00:00:00
# Check indexing: [21984] [22320] [30744] [30911] [30912]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 558...
# Checking date: 2023-07-13 00:00:00
# Check indexing: [22008] [22344] [30768] [30935] [30936]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 559...
# Checking date: 2023-07-14 00:00:00
# Check indexing: [22032] [22368] [30792] [30959] [30960]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 560...
# Checking date: 2023-07-15 00:00:00
# Check indexing: [22056] [22392] [30816] [30983] [30984]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 561...
# Checking date: 2023-07-16 00:00:00
# Check indexing: [22080] [22416] [30840] [31007] [31008]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 562...
# Checking date: 2023-07-17 00:00:00
# Check indexing: [22104] [22440] [30864] [31031] [31032]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 563...
# Checking date: 2023-07-18 00:00:00
# Check indexing: [22128] [22464] [30888] [31055] [31056]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 564...
# Checking date: 2023-07-19 00:00:00
# Check indexing: [22152] [22488] [30912] [31079] [31080]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 565...
# Checking date: 2023-07-20 00:00:00
# Check indexing: [22176] [22512] [30936] [31103] [31104]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 566...
# Checking date: 2023-07-21 00:00:00
# Check indexing: [22200] [22536] [30960] [31127] [31128]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 567...
# Checking date: 2023-07-22 00:00:00
# Check indexing: [22224] [22560] [30984] [31151] [31152]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 568...
# Checking date: 2023-07-23 00:00:00
# Check indexing: [22248] [22584] [31008] [31175] [31176]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 569...
# Checking date: 2023-07-24 00:00:00
# Check indexing: [22272] [22608] [31032] [31199] [31200]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 570...
# Checking date: 2023-07-25 00:00:00
# Check indexing: [22296] [22632] [31056] [31223] [31224]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 571...
# Checking date: 2023-07-26 00:00:00
# Check indexing: [22320] [22656] [31080] [31247] [31248]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 572...
# Checking date: 2023-07-27 00:00:00
# Check indexing: [22344] [22680] [31104] [31271] [31272]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 573...
# Checking date: 2023-07-28 00:00:00
# Check indexing: [22368] [22704] [31128] [31295] [31296]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 574...
# Checking date: 2023-07-29 00:00:00
# Check indexing: [22392] [22728] [31152] [31319] [31320]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 575...
# Checking date: 2023-07-30 00:00:00
# Check indexing: [22416] [22752] [31176] [31343] [31344]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 576...
# Checking date: 2023-07-31 00:00:00
# Check indexing: [22440] [22776] [31200] [31367] [31368]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 577...
# Checking date: 2023-08-01 00:00:00
# Check indexing: [22464] [22800] [31224] [31391] [31392]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 578...
# Checking date: 2023-08-02 00:00:00
# Check indexing: [22488] [22824] [31248] [31415] [31416]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 579...
# Checking date: 2023-08-03 00:00:00
# Check indexing: [22512] [22848] [31272] [31439] [31440]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 580...
# Checking date: 2023-08-04 00:00:00
# Check indexing: [22536] [22872] [31296] [31463] [31464]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 581...
# Checking date: 2023-08-05 00:00:00
# Check indexing: [22560] [22896] [31320] [31487] [31488]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 582...
# Checking date: 2023-08-06 00:00:00
# Check indexing: [22584] [22920] [31344] [31511] [31512]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 583...
# Checking date: 2023-08-07 00:00:00
# Check indexing: [22608] [22944] [31368] [31535] [31536]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 584...
# Checking date: 2023-08-08 00:00:00
# Check indexing: [22632] [22968] [31392] [31559] [31560]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 585...
# Checking date: 2023-08-09 00:00:00
# Check indexing: [22656] [22992] [31416] [31583] [31584]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 586...
# Checking date: 2023-08-10 00:00:00
# Check indexing: [22680] [23016] [31440] [31607] [31608]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 587...
# Checking date: 2023-08-11 00:00:00
# Check indexing: [22704] [23040] [31464] [31631] [31632]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 588...
# Checking date: 2023-08-12 00:00:00
# Check indexing: [22728] [23064] [31488] [31655] [31656]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 589...
# Checking date: 2023-08-13 00:00:00
# Check indexing: [22752] [23088] [31512] [31679] [31680]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 590...
# Checking date: 2023-08-14 00:00:00
# Check indexing: [22776] [23112] [31536] [31703] [31704]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 591...
# Checking date: 2023-08-15 00:00:00
# Check indexing: [22800] [23136] [31560] [31727] [31728]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 592...
# Checking date: 2023-08-16 00:00:00
# Check indexing: [22824] [23160] [31584] [31751] [31752]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 593...
# Checking date: 2023-08-17 00:00:00
# Check indexing: [22848] [23184] [31608] [31775] [31776]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 594...
# Checking date: 2023-08-18 00:00:00
# Check indexing: [22872] [23208] [31632] [31799] [31800]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 595...
# Checking date: 2023-08-19 00:00:00
# Check indexing: [22896] [23232] [31656] [31823] [31824]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 596...
# Checking date: 2023-08-20 00:00:00
# Check indexing: [22920] [23256] [31680] [31847] [31848]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 597...
# Checking date: 2023-08-21 00:00:00
# Check indexing: [22944] [23280] [31704] [31871] [31872]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 598...
# Checking date: 2023-08-22 00:00:00
# Check indexing: [22968] [23304] [31728] [31895] [31896]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 599...
# Checking date: 2023-08-23 00:00:00
# Check indexing: [22992] [23328] [31752] [31919] [31920]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 600...
# Checking date: 2023-08-24 00:00:00
# Check indexing: [23016] [23352] [31776] [31943] [31944]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 601...
# Checking date: 2023-08-25 00:00:00
# Check indexing: [23040] [23376] [31800] [31967] [31968]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 602...
# Checking date: 2023-08-26 00:00:00
# Check indexing: [23064] [23400] [31824] [31991] [31992]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 603...
# Checking date: 2023-08-27 00:00:00
# Check indexing: [23088] [23424] [31848] [32015] [32016]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 604...
# Checking date: 2023-08-28 00:00:00
# Check indexing: [23112] [23448] [31872] [32039] [32040]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 605...
# Checking date: 2023-08-29 00:00:00
# Check indexing: [23136] [23472] [31896] [32063] [32064]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 606...
# Checking date: 2023-08-30 00:00:00
# Check indexing: [23160] [23496] [31920] [32087] [32088]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 607...
# Checking date: 2023-08-31 00:00:00
# Check indexing: [23184] [23520] [31944] [32111] [32112]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 608...
# Checking date: 2023-09-01 00:00:00
# Check indexing: [23208] [23544] [31968] [32135] [32136]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 609...
# Checking date: 2023-09-02 00:00:00
# Check indexing: [23232] [23568] [31992] [32159] [32160]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 610...
# Checking date: 2023-09-03 00:00:00
# Check indexing: [23256] [23592] [32016] [32183] [32184]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 611...
# Checking date: 2023-09-04 00:00:00
# Check indexing: [23280] [23616] [32040] [32207] [32208]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 612...
# Checking date: 2023-09-05 00:00:00
# Check indexing: [23304] [23640] [32064] [32231] [32232]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 613...
# Checking date: 2023-09-06 00:00:00
# Check indexing: [23328] [23664] [32088] [32255] [32256]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 614...
# Checking date: 2023-09-07 00:00:00
# Check indexing: [23352] [23688] [32112] [32279] [32280]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 615...
# Checking date: 2023-09-08 00:00:00
# Check indexing: [23376] [23712] [32136] [32303] [32304]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 616...
# Checking date: 2023-09-09 00:00:00
# Check indexing: [23400] [23736] [32160] [32327] [32328]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 617...
# Checking date: 2023-09-10 00:00:00
# Check indexing: [23424] [23760] [32184] [32351] [32352]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 618...
# Checking date: 2023-09-11 00:00:00
# Check indexing: [23448] [23784] [32208] [32375] [32376]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 619...
# Checking date: 2023-09-12 00:00:00
# Check indexing: [23472] [23808] [32232] [32399] [32400]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 620...
# Checking date: 2023-09-13 00:00:00
# Check indexing: [23496] [23832] [32256] [32423] [32424]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 621...
# Checking date: 2023-09-14 00:00:00
# Check indexing: [23520] [23856] [32280] [32447] [32448]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 622...
# Checking date: 2023-09-15 00:00:00
# Check indexing: [23544] [23880] [32304] [32471] [32472]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 623...
# Checking date: 2023-09-16 00:00:00
# Check indexing: [23568] [23904] [32328] [32495] [32496]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 624...
# Checking date: 2023-09-17 00:00:00
# Check indexing: [23592] [23928] [32352] [32519] [32520]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 625...
# Checking date: 2023-09-18 00:00:00
# Check indexing: [23616] [23952] [32376] [32543] [32544]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 626...
# Checking date: 2023-09-19 00:00:00
# Check indexing: [23640] [23976] [32400] [32567] [32568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 627...
# Checking date: 2023-09-20 00:00:00
# Check indexing: [23664] [24000] [32424] [32591] [32592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 628...
# Checking date: 2023-09-21 00:00:00
# Check indexing: [23688] [24024] [32448] [32615] [32616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 629...
# Checking date: 2023-09-22 00:00:00
# Check indexing: [23712] [24048] [32472] [32639] [32640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 630...
# Checking date: 2023-09-23 00:00:00
# Check indexing: [23736] [24072] [32496] [32663] [32664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 631...
# Checking date: 2023-09-24 00:00:00
# Check indexing: [23760] [24096] [32520] [32687] [32688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 632...
# Checking date: 2023-09-25 00:00:00
# Check indexing: [23784] [24120] [32544] [32711] [32712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 633...
# Checking date: 2023-09-26 00:00:00
# Check indexing: [23808] [24144] [32568] [32735] [32736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 634...
# Checking date: 2023-09-27 00:00:00
# Check indexing: [23832] [24168] [32592] [32759] [32760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 635...
# Checking date: 2023-09-28 00:00:00
# Check indexing: [23856] [24192] [32616] [32783] [32784]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 636...
# Checking date: 2023-09-29 00:00:00
# Check indexing: [23880] [24216] [32640] [32807] [32808]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 637...
# Checking date: 2023-09-30 00:00:00
# Check indexing: [23904] [24240] [32664] [32831] [32832]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 638...
# Checking date: 2023-10-01 00:00:00
# Check indexing: [23928] [24264] [32688] [32855] [32856]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!

# %%
rain_model = SVC()
rain_model.fit(x_train_rain, y_train_rain)
y_pred_rain = rain_model.predict(x_test_rain)
print(accuracy_score(y_test_rain, y_pred_rain))
print(f1_score(y_test_rain, y_pred_rain))
# Out:
# 0.96875
# 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
confusion_matrix(y_test_rain, y_pred_rain)
# Out:
# array([[124,   0],
#        [  4,   0]])

# %%
x_cloud, y_cloud = get_train_test_data('2022-01-01 00:00:00', '2023-10-01 23:00:00', columns_cloud, target_cloud)
x_cloud = np.array(x_cloud)
y_cloud = np.array(y_cloud).astype('int')
x_train_cloud, x_test_cloud, y_train_cloud, y_test_cloud = train_test_split(x_cloud, y_cloud, test_size=0.2, random_state=0)
# Out:
# ----------------------------------
# Get 0...
# Checking date: 2022-01-01 00:00:00
# Check indexing: [8616] [8952] [17376] [17543] [17544]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 1...
# Checking date: 2022-01-02 00:00:00
# Check indexing: [8640] [8976] [17400] [17567] [17568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 2...
# Checking date: 2022-01-03 00:00:00
# Check indexing: [8664] [9000] [17424] [17591] [17592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 3...
# Checking date: 2022-01-04 00:00:00
# Check indexing: [8688] [9024] [17448] [17615] [17616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 4...
# Checking date: 2022-01-05 00:00:00
# Check indexing: [8712] [9048] [17472] [17639] [17640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 5...
# Checking date: 2022-01-06 00:00:00
# Check indexing: [8736] [9072] [17496] [17663] [17664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 6...
# Checking date: 2022-01-07 00:00:00
# Check indexing: [8760] [9096] [17520] [17687] [17688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 7...
# Checking date: 2022-01-08 00:00:00
# Check indexing: [8784] [9120] [17544] [17711] [17712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 8...
# Checking date: 2022-01-09 00:00:00
# Check indexing: [8808] [9144] [17568] [17735] [17736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 9...
# Checking date: 2022-01-10 00:00:00
# Check indexing: [8832] [9168] [17592] [17759] [17760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 10...
# Checking date: 2022-01-11 00:00:00
# Check indexing: [8856] [9192] [17616] [17783] [17784]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 11...
# Checking date: 2022-01-12 00:00:00
# Check indexing: [8880] [9216] [17640] [17807] [17808]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 12...
# Checking date: 2022-01-13 00:00:00
# Check indexing: [8904] [9240] [17664] [17831] [17832]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 13...
# Checking date: 2022-01-14 00:00:00
# Check indexing: [8928] [9264] [17688] [17855] [17856]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 14...
# Checking date: 2022-01-15 00:00:00
# Check indexing: [8952] [9288] [17712] [17879] [17880]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 15...
# Checking date: 2022-01-16 00:00:00
# Check indexing: [8976] [9312] [17736] [17903] [17904]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 16...
# Checking date: 2022-01-17 00:00:00
# Check indexing: [9000] [9336] [17760] [17927] [17928]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 17...
# Checking date: 2022-01-18 00:00:00
# Check indexing: [9024] [9360] [17784] [17951] [17952]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 18...
# Checking date: 2022-01-19 00:00:00
# Check indexing: [9048] [9384] [17808] [17975] [17976]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 19...
# Checking date: 2022-01-20 00:00:00
# Check indexing: [9072] [9408] [17832] [17999] [18000]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 20...
# Checking date: 2022-01-21 00:00:00
# Check indexing: [9096] [9432] [17856] [18023] [18024]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 21...
# Checking date: 2022-01-22 00:00:00
# Check indexing: [9120] [9456] [17880] [18047] [18048]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 22...
# Checking date: 2022-01-23 00:00:00
# Check indexing: [9144] [9480] [17904] [18071] [18072]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 23...
# Checking date: 2022-01-24 00:00:00
# Check indexing: [9168] [9504] [17928] [18095] [18096]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 24...
# Checking date: 2022-01-25 00:00:00
# Check indexing: [9192] [9528] [17952] [18119] [18120]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 25...
# Checking date: 2022-01-26 00:00:00
# Check indexing: [9216] [9552] [17976] [18143] [18144]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 26...
# Checking date: 2022-01-27 00:00:00
# Check indexing: [9240] [9576] [18000] [18167] [18168]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 27...
# Checking date: 2022-01-28 00:00:00
# Check indexing: [9264] [9600] [18024] [18191] [18192]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 28...
# Checking date: 2022-01-29 00:00:00
# Check indexing: [9288] [9624] [18048] [18215] [18216]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 29...
# Checking date: 2022-01-30 00:00:00
# Check indexing: [9312] [9648] [18072] [18239] [18240]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 30...
# Checking date: 2022-01-31 00:00:00
# Check indexing: [9336] [9672] [18096] [18263] [18264]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 31...
# Checking date: 2022-02-01 00:00:00
# Check indexing: [9360] [9696] [18120] [18287] [18288]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 32...
# Checking date: 2022-02-02 00:00:00
# Check indexing: [9384] [9720] [18144] [18311] [18312]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 33...
# Checking date: 2022-02-03 00:00:00
# Check indexing: [9408] [9744] [18168] [18335] [18336]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 34...
# Checking date: 2022-02-04 00:00:00
# Check indexing: [9432] [9768] [18192] [18359] [18360]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 35...
# Checking date: 2022-02-05 00:00:00
# Check indexing: [9456] [9792] [18216] [18383] [18384]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 36...
# Checking date: 2022-02-06 00:00:00
# Check indexing: [9480] [9816] [18240] [18407] [18408]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 37...
# Checking date: 2022-02-07 00:00:00
# Check indexing: [9504] [9840] [18264] [18431] [18432]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 38...
# Checking date: 2022-02-08 00:00:00
# Check indexing: [9528] [9864] [18288] [18455] [18456]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 39...
# Checking date: 2022-02-09 00:00:00
# Check indexing: [9552] [9888] [18312] [18479] [18480]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 40...
# Checking date: 2022-02-10 00:00:00
# Check indexing: [9576] [9912] [18336] [18503] [18504]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 41...
# Checking date: 2022-02-11 00:00:00
# Check indexing: [9600] [9936] [18360] [18527] [18528]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 42...
# Checking date: 2022-02-12 00:00:00
# Check indexing: [9624] [9960] [18384] [18551] [18552]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 43...
# Checking date: 2022-02-13 00:00:00
# Check indexing: [9648] [9984] [18408] [18575] [18576]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 44...
# Checking date: 2022-02-14 00:00:00
# Check indexing: [9672] [10008] [18432] [18599] [18600]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 45...
# Checking date: 2022-02-15 00:00:00
# Check indexing: [9696] [10032] [18456] [18623] [18624]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 46...
# Checking date: 2022-02-16 00:00:00
# Check indexing: [9720] [10056] [18480] [18647] [18648]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 47...
# Checking date: 2022-02-17 00:00:00
# Check indexing: [9744] [10080] [18504] [18671] [18672]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 48...
# Checking date: 2022-02-18 00:00:00
# Check indexing: [9768] [10104] [18528] [18695] [18696]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 49...
# Checking date: 2022-02-19 00:00:00
# Check indexing: [9792] [10128] [18552] [18719] [18720]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 50...
# Checking date: 2022-02-20 00:00:00
# Check indexing: [9816] [10152] [18576] [18743] [18744]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 51...
# Checking date: 2022-02-21 00:00:00
# Check indexing: [9840] [10176] [18600] [18767] [18768]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 52...
# Checking date: 2022-02-22 00:00:00
# Check indexing: [9864] [10200] [18624] [18791] [18792]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 53...
# Checking date: 2022-02-23 00:00:00
# Check indexing: [9888] [10224] [18648] [18815] [18816]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 54...
# Checking date: 2022-02-24 00:00:00
# Check indexing: [9912] [10248] [18672] [18839] [18840]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 55...
# Checking date: 2022-02-25 00:00:00
# Check indexing: [9936] [10272] [18696] [18863] [18864]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 56...
# Checking date: 2022-02-26 00:00:00
# Check indexing: [9960] [10296] [18720] [18887] [18888]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 57...
# Checking date: 2022-02-27 00:00:00
# Check indexing: [9984] [10320] [18744] [18911] [18912]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 58...
# Checking date: 2022-02-28 00:00:00
# Check indexing: [10008] [10344] [18768] [18935] [18936]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 59...
# Checking date: 2022-03-01 00:00:00
# Check indexing: [10032] [10368] [18792] [18959] [18960]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 60...
# Checking date: 2022-03-02 00:00:00
# Check indexing: [10056] [10392] [18816] [18983] [18984]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 61...
# Checking date: 2022-03-03 00:00:00
# Check indexing: [10080] [10416] [18840] [19007] [19008]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 62...
# Checking date: 2022-03-04 00:00:00
# Check indexing: [10104] [10440] [18864] [19031] [19032]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 63...
# Checking date: 2022-03-05 00:00:00
# Check indexing: [10128] [10464] [18888] [19055] [19056]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 64...
# Checking date: 2022-03-06 00:00:00
# Check indexing: [10152] [10488] [18912] [19079] [19080]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 65...
# Checking date: 2022-03-07 00:00:00
# Check indexing: [10176] [10512] [18936] [19103] [19104]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 66...
# Checking date: 2022-03-08 00:00:00
# Check indexing: [10200] [10536] [18960] [19127] [19128]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 67...
# Checking date: 2022-03-09 00:00:00
# Check indexing: [10224] [10560] [18984] [19151] [19152]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 68...
# Checking date: 2022-03-10 00:00:00
# Check indexing: [10248] [10584] [19008] [19175] [19176]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 69...
# Checking date: 2022-03-11 00:00:00
# Check indexing: [10272] [10608] [19032] [19199] [19200]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 70...
# Checking date: 2022-03-12 00:00:00
# Check indexing: [10296] [10632] [19056] [19223] [19224]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 71...
# Checking date: 2022-03-13 00:00:00
# Check indexing: [10320] [10656] [19080] [19247] [19248]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 72...
# Checking date: 2022-03-14 00:00:00
# Check indexing: [10344] [10680] [19104] [19271] [19272]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 73...
# Checking date: 2022-03-15 00:00:00
# Check indexing: [10368] [10704] [19128] [19295] [19296]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 74...
# Checking date: 2022-03-16 00:00:00
# Check indexing: [10392] [10728] [19152] [19319] [19320]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 75...
# Checking date: 2022-03-17 00:00:00
# Check indexing: [10416] [10752] [19176] [19343] [19344]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 76...
# Checking date: 2022-03-18 00:00:00
# Check indexing: [10440] [10776] [19200] [19367] [19368]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 77...
# Checking date: 2022-03-19 00:00:00
# Check indexing: [10464] [10800] [19224] [19391] [19392]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 78...
# Checking date: 2022-03-20 00:00:00
# Check indexing: [10488] [10824] [19248] [19415] [19416]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 79...
# Checking date: 2022-03-21 00:00:00
# Check indexing: [10512] [10848] [19272] [19439] [19440]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 80...
# Checking date: 2022-03-22 00:00:00
# Check indexing: [10536] [10872] [19296] [19463] [19464]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 81...
# Checking date: 2022-03-23 00:00:00
# Check indexing: [10560] [10896] [19320] [19487] [19488]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 82...
# Checking date: 2022-03-24 00:00:00
# Check indexing: [10584] [10920] [19344] [19511] [19512]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 83...
# Checking date: 2022-03-25 00:00:00
# Check indexing: [10608] [10944] [19368] [19535] [19536]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 84...
# Checking date: 2022-03-26 00:00:00
# Check indexing: [10632] [10968] [19392] [19559] [19560]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 85...
# Checking date: 2022-03-27 00:00:00
# Check indexing: [10656] [10992] [19416] [19583] [19584]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 86...
# Checking date: 2022-03-28 00:00:00
# Check indexing: [10680] [11016] [19440] [19607] [19608]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 87...
# Checking date: 2022-03-29 00:00:00
# Check indexing: [10704] [11040] [19464] [19631] [19632]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 88...
# Checking date: 2022-03-30 00:00:00
# Check indexing: [10728] [11064] [19488] [19655] [19656]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 89...
# Checking date: 2022-03-31 00:00:00
# Check indexing: [10752] [11088] [19512] [19679] [19680]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 90...
# Checking date: 2022-04-01 00:00:00
# Check indexing: [10776] [11112] [19536] [19703] [19704]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 91...
# Checking date: 2022-04-02 00:00:00
# Check indexing: [10800] [11136] [19560] [19727] [19728]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 92...
# Checking date: 2022-04-03 00:00:00
# Check indexing: [10824] [11160] [19584] [19751] [19752]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 93...
# Checking date: 2022-04-04 00:00:00
# Check indexing: [10848] [11184] [19608] [19775] [19776]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 94...
# Checking date: 2022-04-05 00:00:00
# Check indexing: [10872] [11208] [19632] [19799] [19800]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 95...
# Checking date: 2022-04-06 00:00:00
# Check indexing: [10896] [11232] [19656] [19823] [19824]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 96...
# Checking date: 2022-04-07 00:00:00
# Check indexing: [10920] [11256] [19680] [19847] [19848]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 97...
# Checking date: 2022-04-08 00:00:00
# Check indexing: [10944] [11280] [19704] [19871] [19872]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 98...
# Checking date: 2022-04-09 00:00:00
# Check indexing: [10968] [11304] [19728] [19895] [19896]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 99...
# Checking date: 2022-04-10 00:00:00
# Check indexing: [10992] [11328] [19752] [19919] [19920]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 100...
# Checking date: 2022-04-11 00:00:00
# Check indexing: [11016] [11352] [19776] [19943] [19944]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 101...
# Checking date: 2022-04-12 00:00:00
# Check indexing: [11040] [11376] [19800] [19967] [19968]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 102...
# Checking date: 2022-04-13 00:00:00
# Check indexing: [11064] [11400] [19824] [19991] [19992]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 103...
# Checking date: 2022-04-14 00:00:00
# Check indexing: [11088] [11424] [19848] [20015] [20016]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 104...
# Checking date: 2022-04-15 00:00:00
# Check indexing: [11112] [11448] [19872] [20039] [20040]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 105...
# Checking date: 2022-04-16 00:00:00
# Check indexing: [11136] [11472] [19896] [20063] [20064]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 106...
# Checking date: 2022-04-17 00:00:00
# Check indexing: [11160] [11496] [19920] [20087] [20088]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 107...
# Checking date: 2022-04-18 00:00:00
# Check indexing: [11184] [11520] [19944] [20111] [20112]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 108...
# Checking date: 2022-04-19 00:00:00
# Check indexing: [11208] [11544] [19968] [20135] [20136]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 109...
# Checking date: 2022-04-20 00:00:00
# Check indexing: [11232] [11568] [19992] [20159] [20160]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 110...
# Checking date: 2022-04-21 00:00:00
# Check indexing: [11256] [11592] [20016] [20183] [20184]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 111...
# Checking date: 2022-04-22 00:00:00
# Check indexing: [11280] [11616] [20040] [20207] [20208]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 112...
# Checking date: 2022-04-23 00:00:00
# Check indexing: [11304] [11640] [20064] [20231] [20232]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 113...
# Checking date: 2022-04-24 00:00:00
# Check indexing: [11328] [11664] [20088] [20255] [20256]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 114...
# Checking date: 2022-04-25 00:00:00
# Check indexing: [11352] [11688] [20112] [20279] [20280]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 115...
# Checking date: 2022-04-26 00:00:00
# Check indexing: [11376] [11712] [20136] [20303] [20304]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 116...
# Checking date: 2022-04-27 00:00:00
# Check indexing: [11400] [11736] [20160] [20327] [20328]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 117...
# Checking date: 2022-04-28 00:00:00
# Check indexing: [11424] [11760] [20184] [20351] [20352]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 118...
# Checking date: 2022-04-29 00:00:00
# Check indexing: [11448] [11784] [20208] [20375] [20376]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 119...
# Checking date: 2022-04-30 00:00:00
# Check indexing: [11472] [11808] [20232] [20399] [20400]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 120...
# Checking date: 2022-05-01 00:00:00
# Check indexing: [11496] [11832] [20256] [20423] [20424]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 121...
# Checking date: 2022-05-02 00:00:00
# Check indexing: [11520] [11856] [20280] [20447] [20448]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 122...
# Checking date: 2022-05-03 00:00:00
# Check indexing: [11544] [11880] [20304] [20471] [20472]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 123...
# Checking date: 2022-05-04 00:00:00
# Check indexing: [11568] [11904] [20328] [20495] [20496]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 124...
# Checking date: 2022-05-05 00:00:00
# Check indexing: [11592] [11928] [20352] [20519] [20520]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 125...
# Checking date: 2022-05-06 00:00:00
# Check indexing: [11616] [11952] [20376] [20543] [20544]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 126...
# Checking date: 2022-05-07 00:00:00
# Check indexing: [11640] [11976] [20400] [20567] [20568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 127...
# Checking date: 2022-05-08 00:00:00
# Check indexing: [11664] [12000] [20424] [20591] [20592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 128...
# Checking date: 2022-05-09 00:00:00
# Check indexing: [11688] [12024] [20448] [20615] [20616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 129...
# Checking date: 2022-05-10 00:00:00
# Check indexing: [11712] [12048] [20472] [20639] [20640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 130...
# Checking date: 2022-05-11 00:00:00
# Check indexing: [11736] [12072] [20496] [20663] [20664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 131...
# Checking date: 2022-05-12 00:00:00
# Check indexing: [11760] [12096] [20520] [20687] [20688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 132...
# Checking date: 2022-05-13 00:00:00
# Check indexing: [11784] [12120] [20544] [20711] [20712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 133...
# Checking date: 2022-05-14 00:00:00
# Check indexing: [11808] [12144] [20568] [20735] [20736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 134...
# Checking date: 2022-05-15 00:00:00
# Check indexing: [11832] [12168] [20592] [20759] [20760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 135...
# Checking date: 2022-05-16 00:00:00
# Check indexing: [11856] [12192] [20616] [20783] [20784]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 136...
# Checking date: 2022-05-17 00:00:00
# Check indexing: [11880] [12216] [20640] [20807] [20808]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 137...
# Checking date: 2022-05-18 00:00:00
# Check indexing: [11904] [12240] [20664] [20831] [20832]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 138...
# Checking date: 2022-05-19 00:00:00
# Check indexing: [11928] [12264] [20688] [20855] [20856]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 139...
# Checking date: 2022-05-20 00:00:00
# Check indexing: [11952] [12288] [20712] [20879] [20880]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 140...
# Checking date: 2022-05-21 00:00:00
# Check indexing: [11976] [12312] [20736] [20903] [20904]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 141...
# Checking date: 2022-05-22 00:00:00
# Check indexing: [12000] [12336] [20760] [20927] [20928]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 142...
# Checking date: 2022-05-23 00:00:00
# Check indexing: [12024] [12360] [20784] [20951] [20952]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 143...
# Checking date: 2022-05-24 00:00:00
# Check indexing: [12048] [12384] [20808] [20975] [20976]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 144...
# Checking date: 2022-05-25 00:00:00
# Check indexing: [12072] [12408] [20832] [20999] [21000]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 145...
# Checking date: 2022-05-26 00:00:00
# Check indexing: [12096] [12432] [20856] [21023] [21024]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 146...
# Checking date: 2022-05-27 00:00:00
# Check indexing: [12120] [12456] [20880] [21047] [21048]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 147...
# Checking date: 2022-05-28 00:00:00
# Check indexing: [12144] [12480] [20904] [21071] [21072]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 148...
# Checking date: 2022-05-29 00:00:00
# Check indexing: [12168] [12504] [20928] [21095] [21096]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 149...
# Checking date: 2022-05-30 00:00:00
# Check indexing: [12192] [12528] [20952] [21119] [21120]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 150...
# Checking date: 2022-05-31 00:00:00
# Check indexing: [12216] [12552] [20976] [21143] [21144]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 151...
# Checking date: 2022-06-01 00:00:00
# Check indexing: [12240] [12576] [21000] [21167] [21168]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 152...
# Checking date: 2022-06-02 00:00:00
# Check indexing: [12264] [12600] [21024] [21191] [21192]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 153...
# Checking date: 2022-06-03 00:00:00
# Check indexing: [12288] [12624] [21048] [21215] [21216]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 154...
# Checking date: 2022-06-04 00:00:00
# Check indexing: [12312] [12648] [21072] [21239] [21240]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 155...
# Checking date: 2022-06-05 00:00:00
# Check indexing: [12336] [12672] [21096] [21263] [21264]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 156...
# Checking date: 2022-06-06 00:00:00
# Check indexing: [12360] [12696] [21120] [21287] [21288]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 157...
# Checking date: 2022-06-07 00:00:00
# Check indexing: [12384] [12720] [21144] [21311] [21312]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 158...
# Checking date: 2022-06-08 00:00:00
# Check indexing: [12408] [12744] [21168] [21335] [21336]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 159...
# Checking date: 2022-06-09 00:00:00
# Check indexing: [12432] [12768] [21192] [21359] [21360]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 160...
# Checking date: 2022-06-10 00:00:00
# Check indexing: [12456] [12792] [21216] [21383] [21384]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 161...
# Checking date: 2022-06-11 00:00:00
# Check indexing: [12480] [12816] [21240] [21407] [21408]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 162...
# Checking date: 2022-06-12 00:00:00
# Check indexing: [12504] [12840] [21264] [21431] [21432]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 163...
# Checking date: 2022-06-13 00:00:00
# Check indexing: [12528] [12864] [21288] [21455] [21456]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 164...
# Checking date: 2022-06-14 00:00:00
# Check indexing: [12552] [12888] [21312] [21479] [21480]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 165...
# Checking date: 2022-06-15 00:00:00
# Check indexing: [12576] [12912] [21336] [21503] [21504]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 166...
# Checking date: 2022-06-16 00:00:00
# Check indexing: [12600] [12936] [21360] [21527] [21528]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 167...
# Checking date: 2022-06-17 00:00:00
# Check indexing: [12624] [12960] [21384] [21551] [21552]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 168...
# Checking date: 2022-06-18 00:00:00
# Check indexing: [12648] [12984] [21408] [21575] [21576]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 169...
# Checking date: 2022-06-19 00:00:00
# Check indexing: [12672] [13008] [21432] [21599] [21600]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 170...
# Checking date: 2022-06-20 00:00:00
# Check indexing: [12696] [13032] [21456] [21623] [21624]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 171...
# Checking date: 2022-06-21 00:00:00
# Check indexing: [12720] [13056] [21480] [21647] [21648]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 172...
# Checking date: 2022-06-22 00:00:00
# Check indexing: [12744] [13080] [21504] [21671] [21672]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 173...
# Checking date: 2022-06-23 00:00:00
# Check indexing: [12768] [13104] [21528] [21695] [21696]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 174...
# Checking date: 2022-06-24 00:00:00
# Check indexing: [12792] [13128] [21552] [21719] [21720]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 175...
# Checking date: 2022-06-25 00:00:00
# Check indexing: [12816] [13152] [21576] [21743] [21744]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 176...
# Checking date: 2022-06-26 00:00:00
# Check indexing: [12840] [13176] [21600] [21767] [21768]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 177...
# Checking date: 2022-06-27 00:00:00
# Check indexing: [12864] [13200] [21624] [21791] [21792]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 178...
# Checking date: 2022-06-28 00:00:00
# Check indexing: [12888] [13224] [21648] [21815] [21816]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 179...
# Checking date: 2022-06-29 00:00:00
# Check indexing: [12912] [13248] [21672] [21839] [21840]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 180...
# Checking date: 2022-06-30 00:00:00
# Check indexing: [12936] [13272] [21696] [21863] [21864]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 181...
# Checking date: 2022-07-01 00:00:00
# Check indexing: [12960] [13296] [21720] [21887] [21888]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 182...
# Checking date: 2022-07-02 00:00:00
# Check indexing: [12984] [13320] [21744] [21911] [21912]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 183...
# Checking date: 2022-07-03 00:00:00
# Check indexing: [13008] [13344] [21768] [21935] [21936]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 184...
# Checking date: 2022-07-04 00:00:00
# Check indexing: [13032] [13368] [21792] [21959] [21960]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 185...
# Checking date: 2022-07-05 00:00:00
# Check indexing: [13056] [13392] [21816] [21983] [21984]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 186...
# Checking date: 2022-07-06 00:00:00
# Check indexing: [13080] [13416] [21840] [22007] [22008]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 187...
# Checking date: 2022-07-07 00:00:00
# Check indexing: [13104] [13440] [21864] [22031] [22032]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 188...
# Checking date: 2022-07-08 00:00:00
# Check indexing: [13128] [13464] [21888] [22055] [22056]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 189...
# Checking date: 2022-07-09 00:00:00
# Check indexing: [13152] [13488] [21912] [22079] [22080]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 190...
# Checking date: 2022-07-10 00:00:00
# Check indexing: [13176] [13512] [21936] [22103] [22104]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 191...
# Checking date: 2022-07-11 00:00:00
# Check indexing: [13200] [13536] [21960] [22127] [22128]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 192...
# Checking date: 2022-07-12 00:00:00
# Check indexing: [13224] [13560] [21984] [22151] [22152]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 193...
# Checking date: 2022-07-13 00:00:00
# Check indexing: [13248] [13584] [22008] [22175] [22176]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 194...
# Checking date: 2022-07-14 00:00:00
# Check indexing: [13272] [13608] [22032] [22199] [22200]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 195...
# Checking date: 2022-07-15 00:00:00
# Check indexing: [13296] [13632] [22056] [22223] [22224]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 196...
# Checking date: 2022-07-16 00:00:00
# Check indexing: [13320] [13656] [22080] [22247] [22248]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 197...
# Checking date: 2022-07-17 00:00:00
# Check indexing: [13344] [13680] [22104] [22271] [22272]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 198...
# Checking date: 2022-07-18 00:00:00
# Check indexing: [13368] [13704] [22128] [22295] [22296]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 199...
# Checking date: 2022-07-19 00:00:00
# Check indexing: [13392] [13728] [22152] [22319] [22320]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 200...
# Checking date: 2022-07-20 00:00:00
# Check indexing: [13416] [13752] [22176] [22343] [22344]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 201...
# Checking date: 2022-07-21 00:00:00
# Check indexing: [13440] [13776] [22200] [22367] [22368]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 202...
# Checking date: 2022-07-22 00:00:00
# Check indexing: [13464] [13800] [22224] [22391] [22392]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 203...
# Checking date: 2022-07-23 00:00:00
# Check indexing: [13488] [13824] [22248] [22415] [22416]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 204...
# Checking date: 2022-07-24 00:00:00
# Check indexing: [13512] [13848] [22272] [22439] [22440]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 205...
# Checking date: 2022-07-25 00:00:00
# Check indexing: [13536] [13872] [22296] [22463] [22464]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 206...
# Checking date: 2022-07-26 00:00:00
# Check indexing: [13560] [13896] [22320] [22487] [22488]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 207...
# Checking date: 2022-07-27 00:00:00
# Check indexing: [13584] [13920] [22344] [22511] [22512]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 208...
# Checking date: 2022-07-28 00:00:00
# Check indexing: [13608] [13944] [22368] [22535] [22536]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 209...
# Checking date: 2022-07-29 00:00:00
# Check indexing: [13632] [13968] [22392] [22559] [22560]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 210...
# Checking date: 2022-07-30 00:00:00
# Check indexing: [13656] [13992] [22416] [22583] [22584]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 211...
# Checking date: 2022-07-31 00:00:00
# Check indexing: [13680] [14016] [22440] [22607] [22608]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 212...
# Checking date: 2022-08-01 00:00:00
# Check indexing: [13704] [14040] [22464] [22631] [22632]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 213...
# Checking date: 2022-08-02 00:00:00
# Check indexing: [13728] [14064] [22488] [22655] [22656]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 214...
# Checking date: 2022-08-03 00:00:00
# Check indexing: [13752] [14088] [22512] [22679] [22680]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 215...
# Checking date: 2022-08-04 00:00:00
# Check indexing: [13776] [14112] [22536] [22703] [22704]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 216...
# Checking date: 2022-08-05 00:00:00
# Check indexing: [13800] [14136] [22560] [22727] [22728]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 217...
# Checking date: 2022-08-06 00:00:00
# Check indexing: [13824] [14160] [22584] [22751] [22752]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 218...
# Checking date: 2022-08-07 00:00:00
# Check indexing: [13848] [14184] [22608] [22775] [22776]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 219...
# Checking date: 2022-08-08 00:00:00
# Check indexing: [13872] [14208] [22632] [22799] [22800]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 220...
# Checking date: 2022-08-09 00:00:00
# Check indexing: [13896] [14232] [22656] [22823] [22824]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 221...
# Checking date: 2022-08-10 00:00:00
# Check indexing: [13920] [14256] [22680] [22847] [22848]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 222...
# Checking date: 2022-08-11 00:00:00
# Check indexing: [13944] [14280] [22704] [22871] [22872]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 223...
# Checking date: 2022-08-12 00:00:00
# Check indexing: [13968] [14304] [22728] [22895] [22896]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 224...
# Checking date: 2022-08-13 00:00:00
# Check indexing: [13992] [14328] [22752] [22919] [22920]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 225...
# Checking date: 2022-08-14 00:00:00
# Check indexing: [14016] [14352] [22776] [22943] [22944]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 226...
# Checking date: 2022-08-15 00:00:00
# Check indexing: [14040] [14376] [22800] [22967] [22968]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 227...
# Checking date: 2022-08-16 00:00:00
# Check indexing: [14064] [14400] [22824] [22991] [22992]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 228...
# Checking date: 2022-08-17 00:00:00
# Check indexing: [14088] [14424] [22848] [23015] [23016]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 229...
# Checking date: 2022-08-18 00:00:00
# Check indexing: [14112] [14448] [22872] [23039] [23040]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 230...
# Checking date: 2022-08-19 00:00:00
# Check indexing: [14136] [14472] [22896] [23063] [23064]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 231...
# Checking date: 2022-08-20 00:00:00
# Check indexing: [14160] [14496] [22920] [23087] [23088]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 232...
# Checking date: 2022-08-21 00:00:00
# Check indexing: [14184] [14520] [22944] [23111] [23112]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 233...
# Checking date: 2022-08-22 00:00:00
# Check indexing: [14208] [14544] [22968] [23135] [23136]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 234...
# Checking date: 2022-08-23 00:00:00
# Check indexing: [14232] [14568] [22992] [23159] [23160]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 235...
# Checking date: 2022-08-24 00:00:00
# Check indexing: [14256] [14592] [23016] [23183] [23184]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 236...
# Checking date: 2022-08-25 00:00:00
# Check indexing: [14280] [14616] [23040] [23207] [23208]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 237...
# Checking date: 2022-08-26 00:00:00
# Check indexing: [14304] [14640] [23064] [23231] [23232]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 238...
# Checking date: 2022-08-27 00:00:00
# Check indexing: [14328] [14664] [23088] [23255] [23256]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 239...
# Checking date: 2022-08-28 00:00:00
# Check indexing: [14352] [14688] [23112] [23279] [23280]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 240...
# Checking date: 2022-08-29 00:00:00
# Check indexing: [14376] [14712] [23136] [23303] [23304]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 241...
# Checking date: 2022-08-30 00:00:00
# Check indexing: [14400] [14736] [23160] [23327] [23328]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 242...
# Checking date: 2022-08-31 00:00:00
# Check indexing: [14424] [14760] [23184] [23351] [23352]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 243...
# Checking date: 2022-09-01 00:00:00
# Check indexing: [14448] [14784] [23208] [23375] [23376]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 244...
# Checking date: 2022-09-02 00:00:00
# Check indexing: [14472] [14808] [23232] [23399] [23400]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 245...
# Checking date: 2022-09-03 00:00:00
# Check indexing: [14496] [14832] [23256] [23423] [23424]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 246...
# Checking date: 2022-09-04 00:00:00
# Check indexing: [14520] [14856] [23280] [23447] [23448]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 247...
# Checking date: 2022-09-05 00:00:00
# Check indexing: [14544] [14880] [23304] [23471] [23472]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 248...
# Checking date: 2022-09-06 00:00:00
# Check indexing: [14568] [14904] [23328] [23495] [23496]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 249...
# Checking date: 2022-09-07 00:00:00
# Check indexing: [14592] [14928] [23352] [23519] [23520]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 250...
# Checking date: 2022-09-08 00:00:00
# Check indexing: [14616] [14952] [23376] [23543] [23544]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 251...
# Checking date: 2022-09-09 00:00:00
# Check indexing: [14640] [14976] [23400] [23567] [23568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 252...
# Checking date: 2022-09-10 00:00:00
# Check indexing: [14664] [15000] [23424] [23591] [23592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 253...
# Checking date: 2022-09-11 00:00:00
# Check indexing: [14688] [15024] [23448] [23615] [23616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 254...
# Checking date: 2022-09-12 00:00:00
# Check indexing: [14712] [15048] [23472] [23639] [23640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 255...
# Checking date: 2022-09-13 00:00:00
# Check indexing: [14736] [15072] [23496] [23663] [23664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 256...
# Checking date: 2022-09-14 00:00:00
# Check indexing: [14760] [15096] [23520] [23687] [23688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 257...
# Checking date: 2022-09-15 00:00:00
# Check indexing: [14784] [15120] [23544] [23711] [23712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 258...
# Checking date: 2022-09-16 00:00:00
# Check indexing: [14808] [15144] [23568] [23735] [23736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 259...
# Checking date: 2022-09-17 00:00:00
# Check indexing: [14832] [15168] [23592] [23759] [23760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 260...
# Checking date: 2022-09-18 00:00:00
# ...
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 553...
# Checking date: 2023-07-08 00:00:00
# Check indexing: [21888] [22224] [30648] [30815] [30816]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 554...
# Checking date: 2023-07-09 00:00:00
# Check indexing: [21912] [22248] [30672] [30839] [30840]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 555...
# Checking date: 2023-07-10 00:00:00
# Check indexing: [21936] [22272] [30696] [30863] [30864]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 556...
# Checking date: 2023-07-11 00:00:00
# Check indexing: [21960] [22296] [30720] [30887] [30888]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 557...
# Checking date: 2023-07-12 00:00:00
# Check indexing: [21984] [22320] [30744] [30911] [30912]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 558...
# Checking date: 2023-07-13 00:00:00
# Check indexing: [22008] [22344] [30768] [30935] [30936]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 559...
# Checking date: 2023-07-14 00:00:00
# Check indexing: [22032] [22368] [30792] [30959] [30960]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 560...
# Checking date: 2023-07-15 00:00:00
# Check indexing: [22056] [22392] [30816] [30983] [30984]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 561...
# Checking date: 2023-07-16 00:00:00
# Check indexing: [22080] [22416] [30840] [31007] [31008]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 562...
# Checking date: 2023-07-17 00:00:00
# Check indexing: [22104] [22440] [30864] [31031] [31032]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 563...
# Checking date: 2023-07-18 00:00:00
# Check indexing: [22128] [22464] [30888] [31055] [31056]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 564...
# Checking date: 2023-07-19 00:00:00
# Check indexing: [22152] [22488] [30912] [31079] [31080]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 565...
# Checking date: 2023-07-20 00:00:00
# Check indexing: [22176] [22512] [30936] [31103] [31104]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 566...
# Checking date: 2023-07-21 00:00:00
# Check indexing: [22200] [22536] [30960] [31127] [31128]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 567...
# Checking date: 2023-07-22 00:00:00
# Check indexing: [22224] [22560] [30984] [31151] [31152]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 568...
# Checking date: 2023-07-23 00:00:00
# Check indexing: [22248] [22584] [31008] [31175] [31176]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 569...
# Checking date: 2023-07-24 00:00:00
# Check indexing: [22272] [22608] [31032] [31199] [31200]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 570...
# Checking date: 2023-07-25 00:00:00
# Check indexing: [22296] [22632] [31056] [31223] [31224]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 571...
# Checking date: 2023-07-26 00:00:00
# Check indexing: [22320] [22656] [31080] [31247] [31248]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 572...
# Checking date: 2023-07-27 00:00:00
# Check indexing: [22344] [22680] [31104] [31271] [31272]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 573...
# Checking date: 2023-07-28 00:00:00
# Check indexing: [22368] [22704] [31128] [31295] [31296]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 574...
# Checking date: 2023-07-29 00:00:00
# Check indexing: [22392] [22728] [31152] [31319] [31320]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 575...
# Checking date: 2023-07-30 00:00:00
# Check indexing: [22416] [22752] [31176] [31343] [31344]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 576...
# Checking date: 2023-07-31 00:00:00
# Check indexing: [22440] [22776] [31200] [31367] [31368]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 577...
# Checking date: 2023-08-01 00:00:00
# Check indexing: [22464] [22800] [31224] [31391] [31392]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 578...
# Checking date: 2023-08-02 00:00:00
# Check indexing: [22488] [22824] [31248] [31415] [31416]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 579...
# Checking date: 2023-08-03 00:00:00
# Check indexing: [22512] [22848] [31272] [31439] [31440]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 580...
# Checking date: 2023-08-04 00:00:00
# Check indexing: [22536] [22872] [31296] [31463] [31464]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 581...
# Checking date: 2023-08-05 00:00:00
# Check indexing: [22560] [22896] [31320] [31487] [31488]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 582...
# Checking date: 2023-08-06 00:00:00
# Check indexing: [22584] [22920] [31344] [31511] [31512]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 583...
# Checking date: 2023-08-07 00:00:00
# Check indexing: [22608] [22944] [31368] [31535] [31536]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 584...
# Checking date: 2023-08-08 00:00:00
# Check indexing: [22632] [22968] [31392] [31559] [31560]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 585...
# Checking date: 2023-08-09 00:00:00
# Check indexing: [22656] [22992] [31416] [31583] [31584]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 586...
# Checking date: 2023-08-10 00:00:00
# Check indexing: [22680] [23016] [31440] [31607] [31608]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 587...
# Checking date: 2023-08-11 00:00:00
# Check indexing: [22704] [23040] [31464] [31631] [31632]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 588...
# Checking date: 2023-08-12 00:00:00
# Check indexing: [22728] [23064] [31488] [31655] [31656]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 589...
# Checking date: 2023-08-13 00:00:00
# Check indexing: [22752] [23088] [31512] [31679] [31680]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 590...
# Checking date: 2023-08-14 00:00:00
# Check indexing: [22776] [23112] [31536] [31703] [31704]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 591...
# Checking date: 2023-08-15 00:00:00
# Check indexing: [22800] [23136] [31560] [31727] [31728]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 592...
# Checking date: 2023-08-16 00:00:00
# Check indexing: [22824] [23160] [31584] [31751] [31752]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 593...
# Checking date: 2023-08-17 00:00:00
# Check indexing: [22848] [23184] [31608] [31775] [31776]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 594...
# Checking date: 2023-08-18 00:00:00
# Check indexing: [22872] [23208] [31632] [31799] [31800]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 595...
# Checking date: 2023-08-19 00:00:00
# Check indexing: [22896] [23232] [31656] [31823] [31824]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 596...
# Checking date: 2023-08-20 00:00:00
# Check indexing: [22920] [23256] [31680] [31847] [31848]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 597...
# Checking date: 2023-08-21 00:00:00
# Check indexing: [22944] [23280] [31704] [31871] [31872]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 598...
# Checking date: 2023-08-22 00:00:00
# Check indexing: [22968] [23304] [31728] [31895] [31896]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 599...
# Checking date: 2023-08-23 00:00:00
# Check indexing: [22992] [23328] [31752] [31919] [31920]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 600...
# Checking date: 2023-08-24 00:00:00
# Check indexing: [23016] [23352] [31776] [31943] [31944]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 601...
# Checking date: 2023-08-25 00:00:00
# Check indexing: [23040] [23376] [31800] [31967] [31968]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 602...
# Checking date: 2023-08-26 00:00:00
# Check indexing: [23064] [23400] [31824] [31991] [31992]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 603...
# Checking date: 2023-08-27 00:00:00
# Check indexing: [23088] [23424] [31848] [32015] [32016]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 604...
# Checking date: 2023-08-28 00:00:00
# Check indexing: [23112] [23448] [31872] [32039] [32040]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 605...
# Checking date: 2023-08-29 00:00:00
# Check indexing: [23136] [23472] [31896] [32063] [32064]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 606...
# Checking date: 2023-08-30 00:00:00
# Check indexing: [23160] [23496] [31920] [32087] [32088]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 607...
# Checking date: 2023-08-31 00:00:00
# Check indexing: [23184] [23520] [31944] [32111] [32112]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 608...
# Checking date: 2023-09-01 00:00:00
# Check indexing: [23208] [23544] [31968] [32135] [32136]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 609...
# Checking date: 2023-09-02 00:00:00
# Check indexing: [23232] [23568] [31992] [32159] [32160]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 610...
# Checking date: 2023-09-03 00:00:00
# Check indexing: [23256] [23592] [32016] [32183] [32184]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 611...
# Checking date: 2023-09-04 00:00:00
# Check indexing: [23280] [23616] [32040] [32207] [32208]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 612...
# Checking date: 2023-09-05 00:00:00
# Check indexing: [23304] [23640] [32064] [32231] [32232]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 613...
# Checking date: 2023-09-06 00:00:00
# Check indexing: [23328] [23664] [32088] [32255] [32256]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 614...
# Checking date: 2023-09-07 00:00:00
# Check indexing: [23352] [23688] [32112] [32279] [32280]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 615...
# Checking date: 2023-09-08 00:00:00
# Check indexing: [23376] [23712] [32136] [32303] [32304]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 616...
# Checking date: 2023-09-09 00:00:00
# Check indexing: [23400] [23736] [32160] [32327] [32328]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 617...
# Checking date: 2023-09-10 00:00:00
# Check indexing: [23424] [23760] [32184] [32351] [32352]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 618...
# Checking date: 2023-09-11 00:00:00
# Check indexing: [23448] [23784] [32208] [32375] [32376]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 619...
# Checking date: 2023-09-12 00:00:00
# Check indexing: [23472] [23808] [32232] [32399] [32400]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 620...
# Checking date: 2023-09-13 00:00:00
# Check indexing: [23496] [23832] [32256] [32423] [32424]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 621...
# Checking date: 2023-09-14 00:00:00
# Check indexing: [23520] [23856] [32280] [32447] [32448]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 622...
# Checking date: 2023-09-15 00:00:00
# Check indexing: [23544] [23880] [32304] [32471] [32472]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 623...
# Checking date: 2023-09-16 00:00:00
# Check indexing: [23568] [23904] [32328] [32495] [32496]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 624...
# Checking date: 2023-09-17 00:00:00
# Check indexing: [23592] [23928] [32352] [32519] [32520]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 625...
# Checking date: 2023-09-18 00:00:00
# Check indexing: [23616] [23952] [32376] [32543] [32544]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 626...
# Checking date: 2023-09-19 00:00:00
# Check indexing: [23640] [23976] [32400] [32567] [32568]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 627...
# Checking date: 2023-09-20 00:00:00
# Check indexing: [23664] [24000] [32424] [32591] [32592]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 628...
# Checking date: 2023-09-21 00:00:00
# Check indexing: [23688] [24024] [32448] [32615] [32616]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 629...
# Checking date: 2023-09-22 00:00:00
# Check indexing: [23712] [24048] [32472] [32639] [32640]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 630...
# Checking date: 2023-09-23 00:00:00
# Check indexing: [23736] [24072] [32496] [32663] [32664]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 631...
# Checking date: 2023-09-24 00:00:00
# Check indexing: [23760] [24096] [32520] [32687] [32688]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 632...
# Checking date: 2023-09-25 00:00:00
# Check indexing: [23784] [24120] [32544] [32711] [32712]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 633...
# Checking date: 2023-09-26 00:00:00
# Check indexing: [23808] [24144] [32568] [32735] [32736]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 634...
# Checking date: 2023-09-27 00:00:00
# Check indexing: [23832] [24168] [32592] [32759] [32760]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 635...
# Checking date: 2023-09-28 00:00:00
# Check indexing: [23856] [24192] [32616] [32783] [32784]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 636...
# Checking date: 2023-09-29 00:00:00
# Check indexing: [23880] [24216] [32640] [32807] [32808]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 637...
# Checking date: 2023-09-30 00:00:00
# Check indexing: [23904] [24240] [32664] [32831] [32832]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!
# ----------------------------------
# Get 638...
# Checking date: 2023-10-01 00:00:00
# Check indexing: [23928] [24264] [32688] [32855] [32856]
# Feature shape: (2525,)
# Target shape: (1,)
# Done!

# %%
cloud_model = SVC()
cloud_model.fit(x_train_cloud, y_train_cloud)
y_pred_cloud = cloud_model.predict(x_test_cloud)
print(accuracy_score(y_test_cloud, y_pred_cloud))
print(f1_score(y_test_cloud,y_pred_cloud))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.7734375
# 0.06451612903225806

# %%
confusion_matrix(y_test_cloud, y_pred_cloud)
# Out:
# array([[98,  0],
#        [29,  1]])
